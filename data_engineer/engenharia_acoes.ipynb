# %% [markdown]
# # Extraindo empresas

# %% [markdown]
# ## Extraindo todas empresas do Brazil da categoria BESST

# %%
import requests
import yfinance as yf
import pandas as pd
import os

# --- PASSO 1: DEFINIR OS SETORES-MÃE DE INTERESSE ---
# A regra para buscar empresas destes setores permanece.
setores_alvo = [
    "Finance",
    "Utilities",
    "Communications"
]

# --- FUNÇÃO PRINCIPAL COM A LÓGICA ATUALIZADA ---
def scanner_sem_filtro_marketcap(setores):
    """
    Busca todas as empresas dos setores-alvo, sem descartar ativos
    com base no valor de mercado (market cap).
    """
    print("Iniciando scanner (sem filtro de market cap)...")
    try:
        url = "https://brapi.dev/api/quote/list"
        lista_completa_brapi = requests.get(url).json().get('stocks', [])
    except Exception as e:
        print(f"❌ Erro fatal ao buscar a lista da brapi: {e}")
        return {}

    # Etapa 1: Coleta Ampla
    print("Mapeando todos os ativos dos setores alvo...")
    tickers_para_analisar = {}
    for stock in lista_completa_brapi:
        setor_brapi = stock.get('sector')
        if setor_brapi in setores:
            ticker = f"{stock.get('stock')}.SA"
            tickers_para_analisar[ticker] = setor_brapi
    
    total = len(tickers_para_analisar)
    print(f"✅ Mapeamento concluído. {total} ativos serão analisados em detalhe.")

    # Etapa 2: Enriquecimento de Dados
    dados_finais = {}
    print("\nIniciando coleta detalhada de dados no yfinance...")
    for i, (ticker, setor_brapi) in enumerate(tickers_para_analisar.items()):
        try:
            print(f"Analisando [{i+1}/{total}]: {ticker}...")

            stock = yf.Ticker(ticker)
            info = stock.info
            
            # Filtro de País permanece
            if info.get("country") != "Brazil":
                print(f"  -> DESCARTADO: {ticker} não é do Brasil.")
                continue
            
            # <<< REGRA 7 REMOVIDA DAQUI >>>
            # O filtro de Market Cap foi completamente removido conforme solicitado.
            
            # Coleta dos dados
            dados_finais[ticker] = {
                "Empresa": info.get("longName", "N/A"),
                "Setor (brapi)": setor_brapi,
                "Subsetor (yfinance)": info.get("industry", "N/A"),
                "País": info.get("country", "N/A"),
                "Market Cap": info.get("marketCap"), # Coleta o valor, mesmo que seja nulo
            }
            print(f"  -> ✅ INCLUÍDO: {ticker}")

        except Exception as e:
            print(f"  -> ERRO: Falha ao processar {ticker}. Erro: {e}")
            continue
                
    return dados_finais

# --- EXECUÇÃO E APRESENTAÇÃO DOS RESULTADOS ---
resultados = scanner_sem_filtro_marketcap(setores_alvo)

if resultados:
    print("\n✅ Análise finalizada.")
    df_resultado = pd.DataFrame.from_dict(resultados, orient="index")
    
    df_resultado.reset_index(inplace=True)
    df_resultado.rename(columns={'index': 'Ticker'}, inplace=True)
    
    # A lógica de formatação e ordenação lida com valores nulos de Market Cap.
    # Empresas sem Market Cap serão convertidas para NaN e listadas no final da ordenação.
    if "Market Cap" in df_resultado.columns:
         df_resultado["Market Cap Num"] = pd.to_numeric(df_resultado["Market Cap"], errors='coerce')
         df_resultado["Market Cap"] = df_resultado["Market Cap Num"].apply(
             lambda x: f"R$ {x/1_000_000_000:.2f} Bi" if pd.notna(x) and x > 0 else "N/A"
         )

    # Ordena pelo Setor principal e depois pelo Market Cap (empresas sem valor por último)
    df_ordenado = df_resultado.sort_values(by=['Setor (brapi)', 'Market Cap Num'], ascending=[True, False])
    
    colunas_finais = ['Ticker', 'Empresa', 'Setor (brapi)', 'Subsetor (yfinance)', 'País', 'Market Cap']
    df_final = df_ordenado[colunas_finais]
    
    print("\n--- Relatório Amplo com Subsetores (Inclusivo) ---")
    print(df_final.to_string(index=False))

    # --- SALVANDO O ARQUIVO NO CAMINHO ESPECÍFICO ---
    try:
        output_folder = r"E:\Github\finance-manager\datasets"
        output_filename = "scanner_amplo_inclusivo_b3.xlsx" # Nome atualizado para refletir a nova regra
        full_path = os.path.join(output_folder, output_filename)
        
        os.makedirs(output_folder, exist_ok=True)
        
        df_final.to_excel(full_path, index=False)
        print(f"\n✅ Resultados salvos com sucesso no caminho: {full_path}")
    except Exception as e:
        print(f"\n❌ Erro ao salvar o arquivo Excel: {e}")
else:
    print("\nNenhuma empresa foi encontrada para os critérios especificados.")
# Out:
# Iniciando scanner (sem filtro de market cap)...
# Mapeando todos os ativos dos setores alvo...
# ✅ Mapeamento concluído. 358 ativos serão analisados em detalhe.
#
# Iniciando coleta detalhada de dados no yfinance...
# Analisando [1/358]: BBDC4.SA...
#   -> ✅ INCLUÍDO: BBDC4.SA
# Analisando [2/358]: BBAS3.SA...
#   -> ✅ INCLUÍDO: BBAS3.SA
# Analisando [3/358]: VAMO3.SA...
#   -> ✅ INCLUÍDO: VAMO3.SA
# Analisando [4/358]: B3SA3.SA...
#   -> ✅ INCLUÍDO: B3SA3.SA
# Analisando [5/358]: ITSA4.SA...
#   -> ✅ INCLUÍDO: ITSA4.SA
# Analisando [6/358]: CSAN3.SA...
#   -> ✅ INCLUÍDO: CSAN3.SA
# Analisando [7/358]: CPLE6.SA...
#   -> ✅ INCLUÍDO: CPLE6.SA
# Analisando [8/358]: RENT3.SA...
#   -> ✅ INCLUÍDO: RENT3.SA
# Analisando [9/358]: ITUB4.SA...
#   -> ✅ INCLUÍDO: ITUB4.SA
# Analisando [10/358]: MOVI3.SA...
#   -> ✅ INCLUÍDO: MOVI3.SA
# Analisando [11/358]: CMIG4.SA...
#   -> ✅ INCLUÍDO: CMIG4.SA
# Analisando [12/358]: CPLE3.SA...
#   -> ✅ INCLUÍDO: CPLE3.SA
# Analisando [13/358]: BBDC3.SA...
#   -> ✅ INCLUÍDO: BBDC3.SA
# Analisando [14/358]: ENEV3.SA...
#   -> ✅ INCLUÍDO: ENEV3.SA
# Analisando [15/358]: BBSE3.SA...
#   -> ✅ INCLUÍDO: BBSE3.SA
# Analisando [16/358]: EQTL3.SA...
#   -> ✅ INCLUÍDO: EQTL3.SA
# Analisando [17/358]: TIMS3.SA...
#   -> ✅ INCLUÍDO: TIMS3.SA
# Analisando [18/358]: BRAP4.SA...
#   -> ✅ INCLUÍDO: BRAP4.SA
# Analisando [19/358]: SRNA3.SA...
#   -> ✅ INCLUÍDO: SRNA3.SA
# Analisando [20/358]: BPAC11.SA...
#   -> ✅ INCLUÍDO: BPAC11.SA
# Analisando [21/358]: CXSE3.SA...
#   -> ✅ INCLUÍDO: CXSE3.SA
# Analisando [22/358]: INBR32.SA...
#   -> ✅ INCLUÍDO: INBR32.SA
# Analisando [23/358]: ELET3.SA...
#   -> ✅ INCLUÍDO: ELET3.SA
# Analisando [24/358]: VIVT3.SA...
#   -> ✅ INCLUÍDO: VIVT3.SA
# Analisando [25/358]: MULT3.SA...
#   -> ✅ INCLUÍDO: MULT3.SA
# Analisando [26/358]: AURE3.SA...
#   -> ✅ INCLUÍDO: AURE3.SA
# Analisando [27/358]: ROXO34.SA...
#   -> ✅ INCLUÍDO: ROXO34.SA
# Analisando [28/358]: PSSA3.SA...
#   -> ✅ INCLUÍDO: PSSA3.SA
# Analisando [29/358]: ALOS3.SA...
#   -> ✅ INCLUÍDO: ALOS3.SA
# Analisando [30/358]: CYRE3.SA...
#   -> ✅ INCLUÍDO: CYRE3.SA
# Analisando [31/358]: SANB11.SA...
#   -> ✅ INCLUÍDO: SANB11.SA
# Analisando [32/358]: IGTI11.SA...
#   -> ✅ INCLUÍDO: IGTI11.SA
# Analisando [33/358]: SAPR4.SA...
#   -> ✅ INCLUÍDO: SAPR4.SA
# Analisando [34/358]: EGIE3.SA...
#   -> ✅ INCLUÍDO: EGIE3.SA
# Analisando [35/358]: SBSP3.SA...
#   -> ✅ INCLUÍDO: SBSP3.SA
# Analisando [36/358]: SAPR11.SA...
#   -> ✅ INCLUÍDO: SAPR11.SA
# Analisando [37/358]: ENGI11.SA...
#   -> ✅ INCLUÍDO: ENGI11.SA
# Analisando [38/358]: JHSF3.SA...
#   -> ✅ INCLUÍDO: JHSF3.SA
# Analisando [39/358]: PDGR3.SA...
#   -> ✅ INCLUÍDO: PDGR3.SA
# Analisando [40/358]: DIRR3.SA...
#   -> ✅ INCLUÍDO: DIRR3.SA
# Analisando [41/358]: CSMG3.SA...
#   -> ✅ INCLUÍDO: CSMG3.SA
# Analisando [42/358]: MILS3.SA...
#   -> ✅ INCLUÍDO: MILS3.SA
# Analisando [43/358]: LIGT3.SA...
#   -> ✅ INCLUÍDO: LIGT3.SA
# Analisando [44/358]: BRSR6.SA...
#   -> ✅ INCLUÍDO: BRSR6.SA
# Analisando [45/358]: ARML3.SA...
#   -> ✅ INCLUÍDO: ARML3.SA
# Analisando [46/358]: ISAE4.SA...
#   -> ✅ INCLUÍDO: ISAE4.SA
# Analisando [47/358]: CURY3.SA...
#   -> ✅ INCLUÍDO: CURY3.SA
# Analisando [48/358]: BMGB4.SA...
#   -> ✅ INCLUÍDO: BMGB4.SA
# Analisando [49/358]: OIBR3.SA...
#   -> ✅ INCLUÍDO: OIBR3.SA
# Analisando [50/358]: EZTC3.SA...
#   -> ✅ INCLUÍDO: EZTC3.SA
# Analisando [51/358]: TEND3.SA...
#   -> ✅ INCLUÍDO: TEND3.SA
# Analisando [52/358]: ABCB4.SA...
#   -> ✅ INCLUÍDO: ABCB4.SA
# Analisando [53/358]: BPAN4.SA...
#   -> ✅ INCLUÍDO: BPAN4.SA
# Analisando [54/358]: ELET6.SA...
#   -> ✅ INCLUÍDO: ELET6.SA
# Analisando [55/358]: IRBR3.SA...
#   -> ✅ INCLUÍDO: IRBR3.SA
# Analisando [56/358]: SYNE3.SA...
#   -> ✅ INCLUÍDO: SYNE3.SA
# Analisando [57/358]: CPFE3.SA...
#   -> ✅ INCLUÍDO: CPFE3.SA
# Analisando [58/358]: ALUP11.SA...
#   -> ✅ INCLUÍDO: ALUP11.SA
# Analisando [59/358]: NEOE3.SA...
#   -> ✅ INCLUÍDO: NEOE3.SA
# Analisando [60/358]: LAVV3.SA...
#   -> ✅ INCLUÍDO: LAVV3.SA
# Analisando [61/358]: PLPL3.SA...
#   -> ✅ INCLUÍDO: PLPL3.SA
# Analisando [62/358]: ORVR3.SA...
#   -> ✅ INCLUÍDO: ORVR3.SA
# Analisando [63/358]: BBAS3F.SA...
#   -> DESCARTADO: BBAS3F.SA não é do Brasil.
# Analisando [64/358]: XPBR31.SA...
#   -> DESCARTADO: XPBR31.SA não é do Brasil.
# Analisando [65/358]: ITUB3.SA...
#   -> ✅ INCLUÍDO: ITUB3.SA
# Analisando [66/358]: MDNE3.SA...
#   -> ✅ INCLUÍDO: MDNE3.SA
# Analisando [67/358]: SAPR3.SA...
#   -> ✅ INCLUÍDO: SAPR3.SA
# Analisando [68/358]: FIQE3.SA...
#   -> ✅ INCLUÍDO: FIQE3.SA
# Analisando [69/358]: EVEN3.SA...
#   -> ✅ INCLUÍDO: EVEN3.SA
# Analisando [70/358]: MTRE3.SA...
#   -> ✅ INCLUÍDO: MTRE3.SA
# Analisando [71/358]: BRBI11.SA...
#   -> ✅ INCLUÍDO: BRBI11.SA
# Analisando [72/358]: WIZC3.SA...
#   -> ✅ INCLUÍDO: WIZC3.SA
# Analisando [73/358]: GFSA3.SA...
#   -> ✅ INCLUÍDO: GFSA3.SA
# Analisando [74/358]: RNEW4.SA...
#   -> ✅ INCLUÍDO: RNEW4.SA
# Analisando [75/358]: PINE4.SA...
#   -> ✅ INCLUÍDO: PINE4.SA
# Analisando [76/358]: BRST3.SA...
#   -> ✅ INCLUÍDO: BRST3.SA
# Analisando [77/358]: BBSE3F.SA...
#   -> DESCARTADO: BBSE3F.SA não é do Brasil.
# Analisando [78/358]: C2OI34.SA...
#   -> DESCARTADO: C2OI34.SA não é do Brasil.
# Analisando [79/358]: HBRE3.SA...
#   -> ✅ INCLUÍDO: HBRE3.SA
# Analisando [80/358]: RNEW3.SA...
#   -> ✅ INCLUÍDO: RNEW3.SA
# Analisando [81/358]: AGRO3.SA...
#   -> ✅ INCLUÍDO: AGRO3.SA
# Analisando [82/358]: TCSA3.SA...
#   -> ✅ INCLUÍDO: TCSA3.SA
# Analisando [83/358]: CMIG4F.SA...
#   -> DESCARTADO: CMIG4F.SA não é do Brasil.
# Analisando [84/358]: CXSE3F.SA...
#   -> DESCARTADO: CXSE3F.SA não é do Brasil.
# Analisando [85/358]: VISA34.SA...
#   -> DESCARTADO: VISA34.SA não é do Brasil.
# Analisando [86/358]: ITSA3.SA...
#   -> ✅ INCLUÍDO: ITSA3.SA
# Analisando [87/358]: DESK3.SA...
#   -> ✅ INCLUÍDO: DESK3.SA
# Analisando [88/358]: SANB3.SA...
#   -> ✅ INCLUÍDO: SANB3.SA
# Analisando [89/358]: CMIG3.SA...
#   -> ✅ INCLUÍDO: CMIG3.SA
# Analisando [90/358]: ITSA4F.SA...
#   -> DESCARTADO: ITSA4F.SA não é do Brasil.
# Analisando [91/358]: CSAN3F.SA...
#   -> DESCARTADO: CSAN3F.SA não é do Brasil.
# Analisando [92/358]: ISAE4F.SA...
#   -> DESCARTADO: ISAE4F.SA não é do Brasil.
# Analisando [93/358]: BERK34.SA...
#   -> DESCARTADO: BERK34.SA não é do Brasil.
# Analisando [94/358]: G2DI33.SA...
#   -> DESCARTADO: G2DI33.SA não é do Brasil.
# Analisando [95/358]: SANB4.SA...
#   -> ✅ INCLUÍDO: SANB4.SA
# Analisando [96/358]: VAMO3F.SA...
#   -> DESCARTADO: VAMO3F.SA não é do Brasil.
# Analisando [97/358]: SAPR4F.SA...
#   -> DESCARTADO: SAPR4F.SA não é do Brasil.
# Analisando [98/358]: EGIE3F.SA...
#   -> DESCARTADO: EGIE3F.SA não é do Brasil.
# Analisando [99/358]: BRAP3.SA...
#   -> ✅ INCLUÍDO: BRAP3.SA
# Analisando [100/358]: BBDC4F.SA...
#   -> DESCARTADO: BBDC4F.SA não é do Brasil.
# Analisando [101/358]: ITUB4F.SA...
#   -> DESCARTADO: ITUB4F.SA não é do Brasil.
# Analisando [102/358]: CPLE6F.SA...
#   -> DESCARTADO: CPLE6F.SA não é do Brasil.
# Analisando [103/358]: B3SA3F.SA...
#   -> DESCARTADO: B3SA3F.SA não é do Brasil.
# Analisando [104/358]: OIBR4.SA...
#   -> ✅ INCLUÍDO: OIBR4.SA
# Analisando [105/358]: LAND3.SA...
#   -> ✅ INCLUÍDO: LAND3.SA
# Analisando [106/358]: JPMC34.SA...
#   -> DESCARTADO: JPMC34.SA não é do Brasil.
# Analisando [107/358]: BOAC34.SA...
#   -> DESCARTADO: BOAC34.SA não é do Brasil.
# Analisando [108/358]: BMGB4F.SA...
#   -> DESCARTADO: BMGB4F.SA não é do Brasil.
# Analisando [109/358]: CSMG3F.SA...
#   -> DESCARTADO: CSMG3F.SA não é do Brasil.
# Analisando [110/358]: BBDC3F.SA...
#   -> DESCARTADO: BBDC3F.SA não é do Brasil.
# Analisando [111/358]: BRAP4F.SA...
#   -> DESCARTADO: BRAP4F.SA não é do Brasil.
# Analisando [112/358]: DIRR3F.SA...
#   -> DESCARTADO: DIRR3F.SA não é do Brasil.
# Analisando [113/358]: RENT3F.SA...
#   -> DESCARTADO: RENT3F.SA não é do Brasil.
# Analisando [114/358]: VIVT3F.SA...
#   -> DESCARTADO: VIVT3F.SA não é do Brasil.
# Analisando [115/358]: SAPR11F.SA...
#   -> DESCARTADO: SAPR11F.SA não é do Brasil.
# Analisando [116/358]: SCAR3.SA...
#   -> ✅ INCLUÍDO: SCAR3.SA
# Analisando [117/358]: AURE3F.SA...
#   -> DESCARTADO: AURE3F.SA não é do Brasil.
# Analisando [118/358]: ABCB4F.SA...
#   -> DESCARTADO: ABCB4F.SA não é do Brasil.
# Analisando [119/358]: CEBR6.SA...
#   -> ✅ INCLUÍDO: CEBR6.SA
# Analisando [120/358]: BMEB4.SA...
#   -> ✅ INCLUÍDO: BMEB4.SA
# Analisando [121/358]: ELET3F.SA...
#   -> DESCARTADO: ELET3F.SA não é do Brasil.
# Analisando [122/358]: B1AM34.SA...
#   -> DESCARTADO: B1AM34.SA não é do Brasil.
# Analisando [123/358]: MOVI3F.SA...
#   -> DESCARTADO: MOVI3F.SA não é do Brasil.
# Analisando [124/358]: ITUB3F.SA...
#   -> DESCARTADO: ITUB3F.SA não é do Brasil.
# Analisando [125/358]: SYNE3F.SA...
#   -> DESCARTADO: SYNE3F.SA não é do Brasil.
# Analisando [126/358]: PSSA3F.SA...
#   -> DESCARTADO: PSSA3F.SA não é do Brasil.
# Analisando [127/358]: JHSF3F.SA...
#   -> DESCARTADO: JHSF3F.SA não é do Brasil.
# Analisando [128/358]: TIMS3F.SA...
#   -> DESCARTADO: TIMS3F.SA não é do Brasil.
# Analisando [129/358]: BRBI11F.SA...
#   -> DESCARTADO: BRBI11F.SA não é do Brasil.
# Analisando [130/358]: SAPR3F.SA...
#   -> DESCARTADO: SAPR3F.SA não é do Brasil.
# Analisando [131/358]: CPFE3F.SA...
#   -> DESCARTADO: CPFE3F.SA não é do Brasil.
# Analisando [132/358]: BPAC11F.SA...
#   -> DESCARTADO: BPAC11F.SA não é do Brasil.
# Analisando [133/358]: FIQE3F.SA...
#   -> DESCARTADO: FIQE3F.SA não é do Brasil.
# Analisando [134/358]: BRSR6F.SA...
#   -> DESCARTADO: BRSR6F.SA não é do Brasil.
# Analisando [135/358]: SBSP3F.SA...
#   -> DESCARTADO: SBSP3F.SA não é do Brasil.
# Analisando [136/358]: ITSA3F.SA...
#   -> DESCARTADO: ITSA3F.SA não é do Brasil.
# Analisando [137/358]: AGRO3F.SA...
#   -> DESCARTADO: AGRO3F.SA não é do Brasil.
# Analisando [138/358]: IRBR3F.SA...
#   -> DESCARTADO: IRBR3F.SA não é do Brasil.
# Analisando [139/358]: EQTL3F.SA...
#   -> DESCARTADO: EQTL3F.SA não é do Brasil.
# Analisando [140/358]: CMIG3F.SA...
#   -> DESCARTADO: CMIG3F.SA não é do Brasil.
# Analisando [141/358]: RDNI3.SA...
#   -> ✅ INCLUÍDO: RDNI3.SA
# Analisando [142/358]: CURY3F.SA...
#   -> DESCARTADO: CURY3F.SA não é do Brasil.
# Analisando [143/358]: CYRE3F.SA...
#   -> DESCARTADO: CYRE3F.SA não é do Brasil.
# Analisando [144/358]: MTRE3F.SA...
#   -> DESCARTADO: MTRE3F.SA não é do Brasil.
# Analisando [145/358]: WIZC3F.SA...
#   -> DESCARTADO: WIZC3F.SA não é do Brasil.
# Analisando [146/358]: ALUP11F.SA...
#   -> DESCARTADO: ALUP11F.SA não é do Brasil.
# Analisando [147/358]: SNCI11.SA...
#   -> ✅ INCLUÍDO: SNCI11.SA
# Analisando [148/358]: CEBR3.SA...
#   -> ✅ INCLUÍDO: CEBR3.SA
# Analisando [149/358]: CPLE3F.SA...
#   -> DESCARTADO: CPLE3F.SA não é do Brasil.
# Analisando [150/358]: OIBR3F.SA...
#   -> DESCARTADO: OIBR3F.SA não é do Brasil.
# Analisando [151/358]: IGTI3.SA...
#   -> ✅ INCLUÍDO: IGTI3.SA
# Analisando [152/358]: ELET6F.SA...
#   -> DESCARTADO: ELET6F.SA não é do Brasil.
# Analisando [153/358]: ENGI11F.SA...
#   -> DESCARTADO: ENGI11F.SA não é do Brasil.
# Analisando [154/358]: EZTC3F.SA...
#   -> DESCARTADO: EZTC3F.SA não é do Brasil.
# Analisando [155/358]: SANB11F.SA...
#   -> DESCARTADO: SANB11F.SA não é do Brasil.
# Analisando [156/358]: GPIV33.SA...
#   -> DESCARTADO: GPIV33.SA não é do Brasil.
# Analisando [157/358]: GFSA3F.SA...
#   -> DESCARTADO: GFSA3F.SA não é do Brasil.
# Analisando [158/358]: MULT3F.SA...
#   -> DESCARTADO: MULT3F.SA não é do Brasil.
# Analisando [159/358]: BLAK34.SA...
#   -> DESCARTADO: BLAK34.SA não é do Brasil.
# Analisando [160/358]: ENEV3F.SA...
#   -> DESCARTADO: ENEV3F.SA não é do Brasil.
# Analisando [161/358]: ALOS3F.SA...
#   -> DESCARTADO: ALOS3F.SA não é do Brasil.
# Analisando [162/358]: ARML3F.SA...
#   -> DESCARTADO: ARML3F.SA não é do Brasil.
# Analisando [163/358]: IGTI11F.SA...
#   -> DESCARTADO: IGTI11F.SA não é do Brasil.
# Analisando [164/358]: OIBR4F.SA...
#   -> DESCARTADO: OIBR4F.SA não é do Brasil.
# Analisando [165/358]: BEES3.SA...
#   -> ✅ INCLUÍDO: BEES3.SA
# Analisando [166/358]: ALUP3.SA...
#   -> ✅ INCLUÍDO: ALUP3.SA
# Analisando [167/358]: BPAC3.SA...
#   -> ✅ INCLUÍDO: BPAC3.SA
# Analisando [168/358]: RNEW11.SA...
#   -> ✅ INCLUÍDO: RNEW11.SA
# Analisando [169/358]: NEOE3F.SA...
#   -> DESCARTADO: NEOE3F.SA não é do Brasil.
# Analisando [170/358]: MDNE3F.SA...
#   -> DESCARTADO: MDNE3F.SA não é do Brasil.
# Analisando [171/358]: ALUP4.SA...
#   -> ✅ INCLUÍDO: ALUP4.SA
# Analisando [172/358]: ENGI4.SA...
#   -> ✅ INCLUÍDO: ENGI4.SA
# Analisando [173/358]: SANB3F.SA...
#   -> DESCARTADO: SANB3F.SA não é do Brasil.
# Analisando [174/358]: PLPL3F.SA...
#   -> DESCARTADO: PLPL3F.SA não é do Brasil.
# Analisando [175/358]: SANB4F.SA...
#   -> DESCARTADO: SANB4F.SA não é do Brasil.
# Analisando [176/358]: BAZA3.SA...
#   -> ✅ INCLUÍDO: BAZA3.SA
# Analisando [177/358]: LAVV3F.SA...
#   -> DESCARTADO: LAVV3F.SA não é do Brasil.
# Analisando [178/358]: BPAN4F.SA...
#   -> DESCARTADO: BPAN4F.SA não é do Brasil.
# Analisando [179/358]: ORVR3F.SA...
#   -> DESCARTADO: ORVR3F.SA não é do Brasil.
# Analisando [180/358]: CTGP34.SA...
#   -> DESCARTADO: CTGP34.SA não é do Brasil.
# Analisando [181/358]: TEND3F.SA...
#   -> DESCARTADO: TEND3F.SA não é do Brasil.
# Analisando [182/358]: EVEN3F.SA...
#   -> DESCARTADO: EVEN3F.SA não é do Brasil.
# Analisando [183/358]: LIGT3F.SA...
#   -> DESCARTADO: LIGT3F.SA não é do Brasil.
# Analisando [184/358]: BRSR3.SA...
#   -> ✅ INCLUÍDO: BRSR3.SA
# Analisando [185/358]: L1MN34.SA...
#   -> DESCARTADO: L1MN34.SA não é do Brasil.
# Analisando [186/358]: BRAP3F.SA...
#   -> DESCARTADO: BRAP3F.SA não é do Brasil.
# Analisando [187/358]: EQIX34.SA...
#   -> DESCARTADO: EQIX34.SA não é do Brasil.
# Analisando [188/358]: ATTB34.SA...
#   -> DESCARTADO: ATTB34.SA não é do Brasil.
# Analisando [189/358]: R2DF34.SA...
#   -> DESCARTADO: R2DF34.SA não é do Brasil.
# Analisando [190/358]: PDGR3F.SA...
#   -> DESCARTADO: PDGR3F.SA não é do Brasil.
# Analisando [191/358]: AVLL3.SA...
#   -> ✅ INCLUÍDO: AVLL3.SA
# Analisando [192/358]: BEES3F.SA...
#   -> DESCARTADO: BEES3F.SA não é do Brasil.
# Analisando [193/358]: RNEW4F.SA...
#   -> DESCARTADO: RNEW4F.SA não é do Brasil.
# Analisando [194/358]: COCE5.SA...
#   -> ✅ INCLUÍDO: COCE5.SA
# Analisando [195/358]: BGIP4.SA...
#   -> ✅ INCLUÍDO: BGIP4.SA
# Analisando [196/358]: CLOV34.SA...
#   -> DESCARTADO: CLOV34.SA não é do Brasil.
# Analisando [197/358]: BCSA34.SA...
#   -> DESCARTADO: BCSA34.SA não é do Brasil.
# Analisando [198/358]: PINE4F.SA...
#   -> DESCARTADO: PINE4F.SA não é do Brasil.
# Analisando [199/358]: ALUP4F.SA...
#   -> DESCARTADO: ALUP4F.SA não é do Brasil.
# Analisando [200/358]: EMAE4.SA...
#   -> ✅ INCLUÍDO: EMAE4.SA
# Analisando [201/358]: EQPA3.SA...
#   -> ✅ INCLUÍDO: EQPA3.SA
# Analisando [202/358]: ISAE3.SA...
#   -> ✅ INCLUÍDO: ISAE3.SA
# Analisando [203/358]: MILS3F.SA...
#   -> DESCARTADO: MILS3F.SA não é do Brasil.
# Analisando [204/358]: GSGI34.SA...
#   -> DESCARTADO: GSGI34.SA não é do Brasil.
# Analisando [205/358]: IGTI3F.SA...
#   -> DESCARTADO: IGTI3F.SA não é do Brasil.
# Analisando [206/358]: SRNA3F.SA...
#   -> DESCARTADO: SRNA3F.SA não é do Brasil.
# Analisando [207/358]: VERZ34.SA...
#   -> DESCARTADO: VERZ34.SA não é do Brasil.
# Analisando [208/358]: MSCD34.SA...
#   -> DESCARTADO: MSCD34.SA não é do Brasil.
# Analisando [209/358]: BSLI3.SA...
#   -> ✅ INCLUÍDO: BSLI3.SA
# Analisando [210/358]: TELB3.SA...
#   -> ✅ INCLUÍDO: TELB3.SA
# Analisando [211/358]: AXPB34.SA...
#   -> DESCARTADO: AXPB34.SA não é do Brasil.
# Analisando [212/358]: BEES4F.SA...
#   -> DESCARTADO: BEES4F.SA não é do Brasil.
# Analisando [213/358]: ISAE3F.SA...
#   -> DESCARTADO: ISAE3F.SA não é do Brasil.
# Analisando [214/358]: BRSR3F.SA...
#   -> DESCARTADO: BRSR3F.SA não é do Brasil.
# Analisando [215/358]: U2PS34.SA...
#   -> DESCARTADO: U2PS34.SA não é do Brasil.
# Analisando [216/358]: BPAC5.SA...
#   -> ✅ INCLUÍDO: BPAC5.SA
# Analisando [217/358]: GEPA4.SA...
#   -> ✅ INCLUÍDO: GEPA4.SA
# Analisando [218/358]: TCSA3F.SA...
#   -> DESCARTADO: TCSA3F.SA não é do Brasil.
# Analisando [219/358]: BRST3F.SA...
#   -> DESCARTADO: BRST3F.SA não é do Brasil.
# Analisando [220/358]: RBIF11.SA...
#   -> ✅ INCLUÍDO: RBIF11.SA
# Analisando [221/358]: BPAC3F.SA...
#   -> DESCARTADO: BPAC3F.SA não é do Brasil.
# Analisando [222/358]: BEES4.SA...
#   -> ✅ INCLUÍDO: BEES4.SA
# Analisando [223/358]: ENGI3.SA...
#   -> ✅ INCLUÍDO: ENGI3.SA
# Analisando [224/358]: DESK3F.SA...
#   -> DESCARTADO: DESK3F.SA não é do Brasil.
# Analisando [225/358]: BMEB4F.SA...
#   -> DESCARTADO: BMEB4F.SA não é do Brasil.
# Analisando [226/358]: RNEW3F.SA...
#   -> DESCARTADO: RNEW3F.SA não é do Brasil.
# Analisando [227/358]: BAZA3F.SA...
#   -> DESCARTADO: BAZA3F.SA não é do Brasil.
# Analisando [228/358]: ENGI3F.SA...
#   -> DESCARTADO: ENGI3F.SA não é do Brasil.
# Analisando [229/358]: PINE3.SA...
#   -> ✅ INCLUÍDO: PINE3.SA
# Analisando [230/358]: CLSC4.SA...
#   -> ✅ INCLUÍDO: CLSC4.SA
# Analisando [231/358]: TELB4.SA...
#   -> ✅ INCLUÍDO: TELB4.SA
# Analisando [232/358]: CEBR5.SA...
#   -> ✅ INCLUÍDO: CEBR5.SA
# Analisando [233/358]: ENGI4F.SA...
#   -> DESCARTADO: ENGI4F.SA não é do Brasil.
# Analisando [234/358]: CEBR6F.SA...
#   -> DESCARTADO: CEBR6F.SA não é do Brasil.
# Analisando [235/358]: CEBR3F.SA...
#   -> DESCARTADO: CEBR3F.SA não é do Brasil.
# Analisando [236/358]: IRIM11.SA...
#   -> ✅ INCLUÍDO: IRIM11.SA
# Analisando [237/358]: WFCO34.SA...
#   -> DESCARTADO: WFCO34.SA não é do Brasil.
# Analisando [238/358]: COCE5F.SA...
#   -> DESCARTADO: COCE5F.SA não é do Brasil.
# Analisando [239/358]: LBRD34.SA...
#   -> DESCARTADO: LBRD34.SA não é do Brasil.
# Analisando [240/358]: BNBR3.SA...
#   -> ✅ INCLUÍDO: BNBR3.SA
# Analisando [241/358]: REDE3.SA...
#   -> ✅ INCLUÍDO: REDE3.SA
# Analisando [242/358]: EQPA3F.SA...
#   -> DESCARTADO: EQPA3F.SA não é do Brasil.
# Analisando [243/358]: LAND3F.SA...
#   -> DESCARTADO: LAND3F.SA não é do Brasil.
# Analisando [244/358]: M2PW34.SA...
#   -> DESCARTADO: M2PW34.SA não é do Brasil.
# Analisando [245/358]: SCAR3F.SA...
#   -> DESCARTADO: SCAR3F.SA não é do Brasil.
# Analisando [246/358]: REDE3F.SA...
#   -> DESCARTADO: REDE3F.SA não é do Brasil.
# Analisando [247/358]: ALUP3F.SA...
#   -> DESCARTADO: ALUP3F.SA não é do Brasil.
# Analisando [248/358]: C2OL34.SA...
#   -> DESCARTADO: C2OL34.SA não é do Brasil.
# Analisando [249/358]: HBTS5.SA...
#   -> ✅ INCLUÍDO: HBTS5.SA
# Analisando [250/358]: BSLI4.SA...
#   -> ✅ INCLUÍDO: BSLI4.SA
# Analisando [251/358]: ENMT3.SA...
#   -> ✅ INCLUÍDO: ENMT3.SA
# Analisando [252/358]: ADMF3.SA...
#   -> ✅ INCLUÍDO: ADMF3.SA
# Analisando [253/358]: EKTR4.SA...
#   -> ✅ INCLUÍDO: EKTR4.SA
# Analisando [254/358]: N1IS34.SA...
#   -> DESCARTADO: N1IS34.SA não é do Brasil.
# Analisando [255/358]: RNEW11F.SA...
#   -> DESCARTADO: RNEW11F.SA não é do Brasil.
# Analisando [256/358]: A1EG34.SA...
#   -> DESCARTADO: A1EG34.SA não é do Brasil.
# Analisando [257/358]: HBRE3F.SA...
#   -> DESCARTADO: HBRE3F.SA não é do Brasil.
# Analisando [258/358]: O2HI34.SA...
#   -> DESCARTADO: O2HI34.SA não é do Brasil.
# Analisando [259/358]: H1SB34.SA...
#   -> DESCARTADO: H1SB34.SA não é do Brasil.
# Analisando [260/358]: BGIP4F.SA...
#   -> DESCARTADO: BGIP4F.SA não é do Brasil.
# Analisando [261/358]: P1LD34.SA...
#   -> DESCARTADO: P1LD34.SA não é do Brasil.
# Analisando [262/358]: RENV11.SA...
#   -> ✅ INCLUÍDO: RENV11.SA
# Analisando [263/358]: CEEB3.SA...
#   -> ✅ INCLUÍDO: CEEB3.SA
# Analisando [264/358]: DTCY3.SA...
#   -> ✅ INCLUÍDO: DTCY3.SA
# Analisando [265/358]: C1HT34.SA...
#   -> DESCARTADO: C1HT34.SA não é do Brasil.
# Analisando [266/358]: EMAE4F.SA...
#   -> DESCARTADO: EMAE4F.SA não é do Brasil.
# Analisando [267/358]: BSLI3F.SA...
#   -> DESCARTADO: BSLI3F.SA não é do Brasil.
# Analisando [268/358]: MOAR3F.SA...
#   -> DESCARTADO: MOAR3F.SA não é do Brasil.
# Analisando [269/358]: EGYR11.SA...
#   -> ✅ INCLUÍDO: EGYR11.SA
# Analisando [270/358]: S1YF34.SA...
#   -> DESCARTADO: S1YF34.SA não é do Brasil.
# Analisando [271/358]: GEPA4F.SA...
#   -> DESCARTADO: GEPA4F.SA não é do Brasil.
# Analisando [272/358]: CGAS5F.SA...
#   -> DESCARTADO: CGAS5F.SA não é do Brasil.
# Analisando [273/358]: BRSR5F.SA...
#   -> DESCARTADO: BRSR5F.SA não é do Brasil.
# Analisando [274/358]: EKTR4F.SA...
#   -> DESCARTADO: EKTR4F.SA não é do Brasil.
# Analisando [275/358]: V1OD34.SA...
#   -> DESCARTADO: V1OD34.SA não é do Brasil.
# Analisando [276/358]: AVLL3F.SA...
#   -> DESCARTADO: AVLL3F.SA não é do Brasil.
# Analisando [277/358]: FSPE11F.SA...
#   -> DESCARTADO: FSPE11F.SA não é do Brasil.
# Analisando [278/358]: BPAC5F.SA...
#   -> DESCARTADO: BPAC5F.SA não é do Brasil.
# Analisando [279/358]: P2AX34.SA...
#   -> DESCARTADO: P2AX34.SA não é do Brasil.
# Analisando [280/358]: B2AP34.SA...
#   -> DESCARTADO: B2AP34.SA não é do Brasil.
# Analisando [281/358]: RDNI3F.SA...
#   -> DESCARTADO: RDNI3F.SA não é do Brasil.
# Analisando [282/358]: AFLT3.SA...
#   -> ✅ INCLUÍDO: AFLT3.SA
# Analisando [283/358]: BMEB3.SA...
#   -> ✅ INCLUÍDO: BMEB3.SA
# Analisando [284/358]: BRSR5.SA...
#   -> ✅ INCLUÍDO: BRSR5.SA
# Analisando [285/358]: RPAD6.SA...
#   -> ✅ INCLUÍDO: RPAD6.SA
# Analisando [286/358]: NEXP3.SA...
#   -> ✅ INCLUÍDO: NEXP3.SA
# Analisando [287/358]: CLSC4F.SA...
#   -> DESCARTADO: CLSC4F.SA não é do Brasil.
# Analisando [288/358]: CGAS3F.SA...
#   -> DESCARTADO: CGAS3F.SA não é do Brasil.
# Analisando [289/358]: ENMT3F.SA...
#   -> DESCARTADO: ENMT3F.SA não é do Brasil.
# Analisando [290/358]: L1YG34.SA...
#   -> DESCARTADO: L1YG34.SA não é do Brasil.
# Analisando [291/358]: DBAG34.SA...
#   -> DESCARTADO: DBAG34.SA não é do Brasil.
# Analisando [292/358]: TELB3F.SA...
#   -> DESCARTADO: TELB3F.SA não é do Brasil.
# Analisando [293/358]: BNBR3F.SA...
#   -> DESCARTADO: BNBR3F.SA não é do Brasil.
# Analisando [294/358]: N2LY34.SA...
#   -> DESCARTADO: N2LY34.SA não é do Brasil.
# Analisando [295/358]: MSBR34.SA...
#   -> DESCARTADO: MSBR34.SA não é do Brasil.
# Analisando [296/358]: TELB4F.SA...
#   -> DESCARTADO: TELB4F.SA não é do Brasil.
# Analisando [297/358]: FSTU11F.SA...
#   -> DESCARTADO: FSTU11F.SA não é do Brasil.
# Analisando [298/358]: DTCY3F.SA...
#   -> DESCARTADO: DTCY3F.SA não é do Brasil.
# Analisando [299/358]: P1GR34.SA...
#   -> DESCARTADO: P1GR34.SA não é do Brasil.
# Analisando [300/358]: NEXT34.SA...
#   -> DESCARTADO: NEXT34.SA não é do Brasil.
# Analisando [301/358]: CLSC3F.SA...
#   -> DESCARTADO: CLSC3F.SA não é do Brasil.
# Analisando [302/358]: U1RI34.SA...
#   -> DESCARTADO: U1RI34.SA não é do Brasil.
# Analisando [303/358]: GSHP3F.SA...
#   -> DESCARTADO: GSHP3F.SA não é do Brasil.
# Analisando [304/358]: M1MC34.SA...
#   -> DESCARTADO: M1MC34.SA não é do Brasil.
# Analisando [305/358]: TRVC34.SA...
#   -> DESCARTADO: TRVC34.SA não é do Brasil.
# Analisando [306/358]: PINE3F.SA...
#   -> DESCARTADO: PINE3F.SA não é do Brasil.
# Analisando [307/358]: CPLE5F.SA...
#   -> DESCARTADO: CPLE5F.SA não é do Brasil.
# Analisando [308/358]: BSLI4F.SA...
#   -> DESCARTADO: BSLI4F.SA não é do Brasil.
# Analisando [309/358]: S1BA34.SA...
#   -> DESCARTADO: S1BA34.SA não é do Brasil.
# Analisando [310/358]: R1IN34.SA...
#   -> DESCARTADO: R1IN34.SA não é do Brasil.
# Analisando [311/358]: GEPA3F.SA...
#   -> DESCARTADO: GEPA3F.SA não é do Brasil.
# Analisando [312/358]: CEEB3F.SA...
#   -> DESCARTADO: CEEB3F.SA não é do Brasil.
# Analisando [313/358]: SCHW34.SA...
#   -> DESCARTADO: SCHW34.SA não é do Brasil.
# Analisando [314/358]: SIMN34.SA...
#   -> DESCARTADO: SIMN34.SA não é do Brasil.
# Analisando [315/358]: AFLT3F.SA...
#   -> DESCARTADO: AFLT3F.SA não é do Brasil.
# Analisando [316/358]: W1YC34.SA...
#   -> DESCARTADO: W1YC34.SA não é do Brasil.
# Analisando [317/358]: N1RG34.SA...
#   -> DESCARTADO: N1RG34.SA não é do Brasil.
# Analisando [318/358]: BMEB3F.SA...
#   -> DESCARTADO: BMEB3F.SA não é do Brasil.
# Analisando [319/358]: N1DA34.SA...
#   -> DESCARTADO: N1DA34.SA não é do Brasil.
# Analisando [320/358]: CEBR5F.SA...
#   -> DESCARTADO: CEBR5F.SA não é do Brasil.
# Analisando [321/358]: S1RE34.SA...
#   -> DESCARTADO: S1RE34.SA não é do Brasil.
# Analisando [322/358]: UBSG34.SA...
#   -> DESCARTADO: UBSG34.SA não é do Brasil.
# Analisando [323/358]: L2PL34.SA...
#   -> DESCARTADO: L2PL34.SA não é do Brasil.
# Analisando [324/358]: USBC34.SA...
#   -> DESCARTADO: USBC34.SA não é do Brasil.
# Analisando [325/358]: BMIN3F.SA...
#   -> DESCARTADO: BMIN3F.SA não é do Brasil.
# Analisando [326/358]: TLNC34.SA...
#   -> DESCARTADO: TLNC34.SA não é do Brasil.
# Analisando [327/358]: S2TA34.SA...
#   -> DESCARTADO: S2TA34.SA não é do Brasil.
# Analisando [328/358]: A2RE34.SA...
#   -> DESCARTADO: A2RE34.SA não é do Brasil.
# Analisando [329/358]: PPLA11.SA...
#   -> ✅ INCLUÍDO: PPLA11.SA
# Analisando [330/358]: A1ES34.SA...
#   -> DESCARTADO: A1ES34.SA não é do Brasil.
# Analisando [331/358]: NMRH34.SA...
#   -> DESCARTADO: NMRH34.SA não é do Brasil.
# Analisando [332/358]: ADMF3F.SA...
#   -> DESCARTADO: ADMF3F.SA não é do Brasil.
# Analisando [333/358]: BMIN4F.SA...
#   -> DESCARTADO: BMIN4F.SA não é do Brasil.
# Analisando [334/358]: A1RE34.SA...
#   -> DESCARTADO: A1RE34.SA não é do Brasil.
# Analisando [335/358]: W1EL34.SA...
#   -> DESCARTADO: W1EL34.SA não é do Brasil.
# Analisando [336/358]: NEXP3F.SA...
#   -> DESCARTADO: NEXP3F.SA não é do Brasil.
# Analisando [337/358]: A1WK34.SA...
#   -> DESCARTADO: A1WK34.SA não é do Brasil.
# Analisando [338/358]: HBTS5F.SA...
#   -> DESCARTADO: HBTS5F.SA não é do Brasil.
# Analisando [339/358]: C1BR34.SA...
#   -> DESCARTADO: C1BR34.SA não é do Brasil.
# Analisando [340/358]: BGIP3F.SA...
#   -> DESCARTADO: BGIP3F.SA não é do Brasil.
# Analisando [341/358]: CBEE3F.SA...
#   -> DESCARTADO: CBEE3F.SA não é do Brasil.
# Analisando [342/358]: BONY34.SA...
#   -> DESCARTADO: BONY34.SA não é do Brasil.
# Analisando [343/358]: EQMA3BF.SA...
#   -> DESCARTADO: EQMA3BF.SA não é do Brasil.
# Analisando [344/358]: I1VZ34.SA...
#   -> DESCARTADO: I1VZ34.SA não é do Brasil.
# Analisando [345/358]: M1UF34.SA...
#   -> DESCARTADO: M1UF34.SA não é do Brasil.
# Analisando [346/358]: A1MP34.SA...
#   -> DESCARTADO: A1MP34.SA não é do Brasil.
# Analisando [347/358]: PEAB3F.SA...
#   -> DESCARTADO: PEAB3F.SA não é do Brasil.
# Analisando [348/358]: CEED4F.SA...
#   -> DESCARTADO: CEED4F.SA não é do Brasil.
# Analisando [349/358]: WUNI34.SA...
#   -> DESCARTADO: WUNI34.SA não é do Brasil.
# Analisando [350/358]: N1GG34.SA...
#   -> DESCARTADO: N1GG34.SA não é do Brasil.
# Analisando [351/358]: T1OW34.SA...
#   -> DESCARTADO: T1OW34.SA não é do Brasil.
# Analisando [352/358]: J1EF34.SA...
#   -> DESCARTADO: J1EF34.SA não é do Brasil.
# Analisando [353/358]: CHME34.SA...
#   -> DESCARTADO: CHME34.SA não é do Brasil.
# Analisando [354/358]: M1AA34.SA...
#   -> DESCARTADO: M1AA34.SA não é do Brasil.
# Analisando [355/358]: A1LL34.SA...
#   -> DESCARTADO: A1LL34.SA não é do Brasil.
# Analisando [356/358]: T1MU34.SA...
#   -> DESCARTADO: T1MU34.SA não é do Brasil.
# Analisando [357/358]: EKTR3F.SA...
#   -> DESCARTADO: EKTR3F.SA não é do Brasil.
# Analisando [358/358]: ELET5F.SA...
#   -> DESCARTADO: ELET5F.SA não é do Brasil.
#
# ✅ Análise finalizada.
#
# --- Relatório Amplo com Subsetores (Inclusivo) ---
#    Ticker                                                                 Empresa  Setor (brapi)                     Subsetor (yfinance)   País   Market Cap
#  CEBR3.SA                                  Companhia Energética de Brasília - CEB      Utilities          Utilities - Regulated Electric Brazil   R$ 1.42 Bi
#  CEBR6.SA                                  Companhia Energética de Brasília - CEB      Utilities          Utilities - Regulated Electric Brazil   R$ 1.42 Bi
#  EMAE4.SA                           Empresa Metropolitana de Águas e Energia S.A.      Utilities                 Utilities - Diversified Brazil   R$ 0.67 Bi
# RNEW11.SA                                                     Renova Energia S.A.      Utilities                   Utilities - Renewable Brazil   R$ 0.48 Bi
#  AFLT3.SA                           Afluente Transmissão de Energia Elétrica S.A.      Utilities          Utilities - Regulated Electric Brazil   R$ 0.44 Bi
#  RNEW4.SA                                                     Renova Energia S.A.      Utilities                   Utilities - Renewable Brazil   R$ 0.34 Bi
#  RNEW3.SA                                                     Renova Energia S.A.      Utilities                   Utilities - Renewable Brazil   R$ 0.34 Bi
#
# ✅ Resultados salvos com sucesso no caminho: E:\Github\finance-manager\datasets\scanner_amplo_inclusivo_b3.xlsx

# %% [markdown]
# ## Scanner completo

# %%
import requests
import yfinance as yf
import pandas as pd
import os

# --- FUNÇÃO PRINCIPAL SEM FILTROS ---
def scanner_completo():
    """
    Busca TODOS os ativos da API brapi e coleta suas informações detalhadas
    no yfinance, sem aplicar filtros de setor, país ou market cap.
    """
    print("Iniciando scanner COMPLETO da B3 (sem filtros)...")
    print("AVISO: Este processo pode ser demorado.")
    try:
        url = "https://brapi.dev/api/quote/list"
        lista_completa_brapi = requests.get(url).json().get('stocks', [])
    except Exception as e:
        print(f"❌ Erro fatal ao buscar a lista da brapi: {e}")
        return {}

    # Etapa 1: Mapear TODOS os tickers para seus setores
    print("Mapeando todos os ativos encontrados...")
    tickers_para_analisar = {}
    for stock in lista_completa_brapi:
        ticker = f"{stock.get('stock')}.SA"
        # Usamos 'N/A' se o setor não for informado na brapi
        setor_brapi = stock.get('sector', 'N/A')
        tickers_para_analisar[ticker] = setor_brapi
    
    total = len(tickers_para_analisar)
    print(f"✅ Mapeamento concluído. {total} ativos serão analisados em detalhe.")

    # Etapa 2: Coleta de Dados Detalhada
    dados_finais = {}
    print("\nIniciando coleta detalhada de dados no yfinance...")
    for i, (ticker, setor_brapi) in enumerate(tickers_para_analisar.items()):
        try:
            # Imprime o progresso a cada 10 tickers para não poluir a tela
            if (i + 1) % 10 == 0:
                print(f"Analisando [{i+1}/{total}]: {ticker}...")

            stock = yf.Ticker(ticker)
            info = stock.info
            
            # Todos os filtros foram removidos conforme solicitado.
            # Apenas o try/except permanece para lidar com erros de tickers inválidos.

            dados_finais[ticker] = {
                "Empresa": info.get("longName", "N/A"),
                "Setor (brapi)": setor_brapi,
                "Subsetor (yfinance)": info.get("industry", "N/A"),
                "País": info.get("country", "N/A"),
                "Market Cap": info.get("marketCap"),
                # <<< NOVA COLUNA ADICIONADA AQUI >>>
                "Logo": info.get("logo_url", "N/A"),
            }
        except Exception:
            # Ignora silenciosamente qualquer erro para um ticker específico e continua
            continue
                
    return dados_finais

# --- EXECUÇÃO E APRESENTAÇÃO DOS RESULTADOS ---
resultados = scanner_completo()

if resultados:
    print("\n✅ Análise completa finalizada.")
    df_resultado = pd.DataFrame.from_dict(resultados, orient="index")
    
    df_resultado.reset_index(inplace=True)
    df_resultado.rename(columns={'index': 'Ticker'}, inplace=True)
    
    if "Market Cap" in df_resultado.columns:
         df_resultado["Market Cap Num"] = pd.to_numeric(df_resultado["Market Cap"], errors='coerce')
         df_resultado["Market Cap"] = df_resultado["Market Cap Num"].apply(
             lambda x: f"R$ {x/1_000_000_000:.2f} Bi" if pd.notna(x) and x > 0 else "N/A"
         )

    # Ordena pelo Market Cap do maior para o menor como critério principal
    df_ordenado = df_resultado.sort_values(by=['Market Cap Num'], ascending=False)
    
    # Define a ordem final das colunas para o relatório
    colunas_finais = ['Ticker', 'Empresa', 'Setor (brapi)', 'Subsetor (yfinance)', 'País', 'Market Cap', 'Logo']
    df_final = df_ordenado[colunas_finais]
    
    print("\n--- Relatório Completo da B3 ---")
    print(df_final.to_string(index=False))

    # --- SALVANDO O ARQUIVO NO CAMINHO ESPECÍFICO ---
    try:
        output_folder = r"E:\Github\finance-manager\datasets"
        output_filename = "scanner_completo.xlsx" # Novo nome do arquivo
        full_path = os.path.join(output_folder, output_filename)
        
        os.makedirs(output_folder, exist_ok=True)
        
        df_final.to_excel(full_path, index=False)
        print(f"\n✅ Resultados salvos com sucesso no caminho: {full_path}")
    except Exception as e:
        print(f"\n❌ Erro ao salvar o arquivo Excel: {e}")
else:
    print("\nNenhuma empresa foi encontrada ou processada com sucesso.")
# Out:
# Iniciando scanner COMPLETO da B3 (sem filtros)...
# AVISO: Este processo pode ser demorado.
# Mapeando todos os ativos encontrados...
# ✅ Mapeamento concluído. 1705 ativos serão analisados em detalhe.
#
# Iniciando coleta detalhada de dados no yfinance...
# Analisando [10/1705]: PETR4.SA...
# Analisando [20/1705]: LREN3.SA...
# Analisando [30/1705]: PRIO3.SA...
# Analisando [40/1705]: BBDC3.SA...
# Analisando [50/1705]: EQTL3.SA...
# Analisando [60/1705]: HAPV3.SA...
# Analisando [70/1705]: ELET3.SA...
# Analisando [80/1705]: VIVA3.SA...
# Analisando [90/1705]: YDUQ3.SA...
# Analisando [100/1705]: FLRY3.SA...
# Analisando [110/1705]: SAPR11.SA...
# Analisando [120/1705]: LIGT3.SA...
# Analisando [130/1705]: AZEV3.SA...
# Analisando [140/1705]: EZTC3.SA...
# Analisando [150/1705]: GRND3.SA...
# Analisando [160/1705]: ELET6.SA...
# Analisando [170/1705]: SHUL4.SA...
# Analisando [180/1705]: CSED3.SA...
# Analisando [190/1705]: AURA33.SA...
# Analisando [200/1705]: NASD11.SA...
# Analisando [210/1705]: MELI34.SA...
# Analisando [220/1705]: ZAMP3.SA...
# Analisando [230/1705]: AURB11.SA...
# Analisando [240/1705]: FGAA11.SA...
# Analisando [250/1705]: LEVE3.SA...
# Analisando [260/1705]: VGIA11.SA...
# Analisando [270/1705]: TOKY3.SA...
# Analisando [280/1705]: VGRI11.SA...
# Analisando [290/1705]: RNEW3.SA...
# Analisando [300/1705]: GOLL54F.SA...
# Analisando [310/1705]: CXSE3F.SA...
# Analisando [320/1705]: TRXF11.SA...
# Analisando [330/1705]: ALUG11.SA...
# Analisando [340/1705]: CSAN3F.SA...
# Analisando [350/1705]: TECK11.SA...
# Analisando [360/1705]: KISU11.SA...
# Analisando [370/1705]: KNHY11.SA...
# Analisando [380/1705]: AAZQ11.SA...
# Analisando [390/1705]: KNUQ11.SA...
# Analisando [400/1705]: JSCR11.SA...
# Analisando [410/1705]: KLBN11F.SA...
# Analisando [420/1705]: XPLG11.SA...
# Analisando [430/1705]: WHGR11.SA...
# Analisando [440/1705]: DEVA11.SA...
# Analisando [450/1705]: RECV3F.SA...
# Analisando [460/1705]: CPTI11.SA...
# Analisando [470/1705]: MGLU3F.SA...
# Analisando [480/1705]: BSLV39.SA...
# Analisando [490/1705]: RENT3F.SA...
# Analisando [500/1705]: SAPR11F.SA...
# Analisando [510/1705]: ABCB4F.SA...
# Analisando [520/1705]: B1AM34.SA...
# Analisando [530/1705]: IRIF11.SA...
# Analisando [540/1705]: RANI3F.SA...
# Analisando [550/1705]: DGCO34.SA...
# Analisando [560/1705]: JHSF3F.SA...
# Analisando [570/1705]: VIVR3.SA...
# Analisando [580/1705]: TASA4F.SA...
# Analisando [590/1705]: TVRI11.SA...
# Analisando [600/1705]: FIVN11.SA...
# Analisando [610/1705]: EQTL3F.SA...
# Analisando [620/1705]: LEVE3F.SA...
# Analisando [630/1705]: VPPR11.SA...
# Analisando [640/1705]: TAEE3F.SA...
# Analisando [650/1705]: MELK3F.SA...
# Analisando [660/1705]: U1BE34.SA...
# Analisando [670/1705]: AMER3F.SA...
# Analisando [680/1705]: HYPE3F.SA...
# Analisando [690/1705]: SPGI34.SA...
# Analisando [700/1705]: NGRD3.SA...
# Analisando [710/1705]: PNVL3F.SA...
# Analisando [720/1705]: ALPK3F.SA...
# Analisando [730/1705]: COPN11.SA...
# Analisando [740/1705]: RYTT34.SA...
# Analisando [750/1705]: ALUP3.SA...
# Analisando [760/1705]: LWSA3F.SA...
# Analisando [770/1705]: S2EA34.SA...
# Analisando [780/1705]: M2RV34.SA...
# Analisando [790/1705]: CPUR11.SA...
# Analisando [800/1705]: DVFF11.SA...
# Analisando [810/1705]: RPRI11.SA...
# Analisando [820/1705]: LAVV3F.SA...
# Analisando [830/1705]: SMRE11.SA...
# Analisando [840/1705]: INEP3.SA...
# Analisando [850/1705]: MGEL4.SA...
# Analisando [860/1705]: HBSA3F.SA...
# Analisando [870/1705]: BRAP3F.SA...
# Analisando [880/1705]: BHEW39.SA...
# Analisando [890/1705]: ETHA39.SA...
# Analisando [900/1705]: ALPA4F.SA...
# Analisando [910/1705]: CXCO11.SA...
# Analisando [920/1705]: PINE4F.SA...
# Analisando [930/1705]: EMAE4.SA...
# Analisando [940/1705]: T2ER34.SA...
# Analisando [950/1705]: CXCI11.SA...
# Analisando [960/1705]: TRXY11.SA...
# Analisando [970/1705]: TRIG11.SA...
# Analisando [980/1705]: G1DS34.SA...
# Analisando [990/1705]: TECN3F.SA...
# Analisando [1000/1705]: BRSR3F.SA...
# Analisando [1010/1705]: BPAC5.SA...
# Analisando [1020/1705]: VTLT11.SA...
# Analisando [1030/1705]: DEXP3F.SA...
# Analisando [1040/1705]: L1VS34.SA...
# Analisando [1050/1705]: JPPA11.SA...
# Analisando [1060/1705]: JOGO11.SA...
# Analisando [1070/1705]: ZAVI11.SA...
# Analisando [1080/1705]: CEBR5.SA...
# Analisando [1090/1705]: GCRI11.SA...
# Analisando [1100/1705]: FIXX11.SA...
# Analisando [1110/1705]: FDES11F.SA...
# Analisando [1120/1705]: EXES11.SA...
# Analisando [1130/1705]: B1IL34.SA...
# Analisando [1140/1705]: SNEC34.SA...
# Analisando [1150/1705]: BTAG11.SA...
# Analisando [1160/1705]: RNGO11.SA...
# Analisando [1170/1705]: DIVS11.SA...
# Analisando [1180/1705]: ENMT3.SA...
# Analisando [1190/1705]: R2BL34.SA...
# Analisando [1200/1705]: HBRE3F.SA...
# Analisando [1210/1705]: MAXR11.SA...
# Analisando [1220/1705]: CCTY3F.SA...
# Analisando [1230/1705]: TJKB11.SA...
# Analisando [1240/1705]: RENV11.SA...
# Analisando [1250/1705]: BQUA39.SA...
# Analisando [1260/1705]: BIYT39.SA...
# Analisando [1270/1705]: S1PO34.SA...
# Analisando [1280/1705]: MATD3F.SA...
# Analisando [1290/1705]: BBOV11.SA...
# Analisando [1300/1705]: BMMT11.SA...
# Analisando [1310/1705]: CGAS5F.SA...
# Analisando [1320/1705]: R1CL34.SA...
# Analisando [1330/1705]: RDNI3F.SA...
# Analisando [1340/1705]: BCIC11.SA...
# Analisando [1350/1705]: JDCO34.SA...
# Analisando [1360/1705]: B2YN34.SA...
# Analisando [1370/1705]: R1SG34.SA...
# Analisando [1380/1705]: R1KU34.SA...
# Analisando [1390/1705]: EVTC31.SA...
# Analisando [1400/1705]: P1KG34.SA...
# Analisando [1410/1705]: E2XA34.SA...
# Analisando [1420/1705]: SNSY5F.SA...
# Analisando [1430/1705]: B1SX34.SA...
# Analisando [1440/1705]: REAG3F.SA...
# Analisando [1450/1705]: BIED3F.SA...
# Analisando [1460/1705]: BRAZ11.SA...
# Analisando [1470/1705]: M1CH34.SA...
# Analisando [1480/1705]: C1PB34.SA...
# Analisando [1490/1705]: PACC11.SA...
# Analisando [1500/1705]: UBSG34.SA...
# Analisando [1510/1705]: IBMB34.SA...
# Analisando [1520/1705]: BMIN3F.SA...
# Analisando [1530/1705]: FRIO3F.SA...
# Analisando [1540/1705]: A1DM34.SA...
# Analisando [1550/1705]: S2CH34.SA...
# Analisando [1560/1705]: HAGA3F.SA...
# Analisando [1570/1705]: FAMB11.SA...
# Analisando [1580/1705]: MOOO34.SA...
# Analisando [1590/1705]: NEXP3F.SA...
# Analisando [1600/1705]: BUSR39.SA...
# Analisando [1610/1705]: S1HW34.SA...
# Analisando [1620/1705]: A1WK34.SA...
# Analisando [1630/1705]: EQMA3BF.SA...
# Analisando [1640/1705]: M1UF34.SA...
#  DOHL3F.SA                                                                                                  N/A     Process Industries                                      N/A            N/A            N/A  N/A
#  BIYE39.SA                                                              iShares Trust - iShares U.S. Energy ETF          Miscellaneous                                      N/A            N/A            N/A  N/A
#  BALM3F.SA                                                                                                  N/A      Health Technology                                      N/A            N/A            N/A  N/A
#  C2OU34.SA                                                                                       Coursera, Inc.    Technology Services                                           United States            N/A  N/A
#  PEAB3F.SA                                                                      Nasdaq North America Chemicals                 Finance                                      N/A            N/A            N/A  N/A
#  DTCR39.SA                                                                                                  N/A                   None                                      N/A            N/A            N/A  N/A
#  T2YL34.SA                                                                             Tyler Technologies, Inc.    Technology Services                                           United States            N/A  N/A
#  Q2SC34.SA                                                                             QuantumScape Corporation Producer Manufacturing                                           United States            N/A  N/A
#  BEWL39.SA                                                         iShares, Inc. - iShares MSCI Switzerland ETF          Miscellaneous                                      N/A            N/A            N/A  N/A
#  BDAP11.SA                                                                Bb Etf Indice Dap5 B3 Fundo De Indice                   None                                                  Brazil            N/A  N/A
#  LLFT11.SA                                                       BTG Pactual Teva Tesouro Selic Fundo De Indice                   None                                                  Brazil            N/A  N/A
#  CEED4F.SA                                                                                                  N/A              Utilities                                      N/A            N/A            N/A  N/A
#  SOND6F.SA                                                                                                  N/A    Industrial Services                                      N/A            N/A            N/A  N/A
#  SNSY3F.SA                                                                                                  N/A Producer Manufacturing                                      N/A            N/A            N/A  N/A
#  BIEI39.SA                                                                                                  N/A          Miscellaneous                                      N/A            N/A            N/A  N/A
#  BLPX39.SA                                                                                       Global X Funds          Miscellaneous                                      N/A            N/A            N/A  N/A
#  CEDO4F.SA                                                                                                  N/A     Process Industries                                      N/A            N/A            N/A  N/A
#  ESGB11.SA                                                       Btg Pactual Esg Fundo De Indice S P Brazil Esg          Miscellaneous                                                  Brazil            N/A  N/A
#  RSUL4F.SA                                                                      MSCI EAFE MID/INDUSTRIA NETR US Producer Manufacturing                                      N/A            N/A            N/A  N/A
#  BRXC11.SA                                                                                                  N/A                   None                                                  Brazil            N/A  N/A
#  EKTR3F.SA                                                                                                  N/A              Utilities                                      N/A            N/A            N/A  N/A
#  ELET5F.SA                                                                                                  N/A              Utilities                                      N/A            N/A            N/A  N/A
#
# ✅ Resultados salvos com sucesso no caminho: E:\Github\finance-manager\datasets\scanner_completo.xlsx

# %%
df_dados = pd.read_excel(r'E:\Github\finance-manager\datasets\scanner_completo.xlsx')


df_dados = df_dados[df_dados['Ticker'] == 'TAEE4.SA']

# Filter rows where 'Setor (brapi)' is one of the specified values
df_dados = df_dados[df_dados['Setor (brapi)'].isin(["Finance", "Utilities", "Communications", "Industrial Services"])]

# Filter rows where País equals 'Brazil'
# df_dados = df_dados[df_dados['País'] == 'Brazil']


print(df_dados)
# Out:
#        Ticker                                        Empresa  \
# 408  TAEE4.SA  Transmissora Aliança de Energia Elétrica S.A.
#
#            Setor (brapi)             Subsetor (yfinance)    País   Market Cap  \
# 408  Industrial Services  Utilities - Regulated Electric  Brazil  R$ 11.87 Bi
#
#      Logo
# 408   NaN

# %% [markdown]
# # Extração filtrada

# %%
import requests
import yfinance as yf
import pandas as pd
import os

# --- PASSO 1: REATIVANDO O FILTRO DE SETORES ---
# A busca volta a ser focada nestes setores-mãe.
setores_alvo = [
    "Finance",
    "Utilities",
    "Communications",
    "Industrial Services"
]

# --- FUNÇÃO PRINCIPAL COM A LÓGICA FINAL ---
def scanner_final(setores):
    """
    Busca empresas dos setores-alvo, filtrando por país e corrigindo
    a busca pelo logo, mas sem filtrar por market cap.
    """
    print("Iniciando scanner final focado...")
    try:
        url = "https://brapi.dev/api/quote/list"
        lista_completa_brapi = requests.get(url).json().get('stocks', [])
    except Exception as e:
        print(f"❌ Erro fatal ao buscar a lista da brapi: {e}")
        return {}

    # Etapa 1: Mapear tickers, seus setores E O LOGO da brapi
    print("Mapeando ativos dos setores alvo...")
    tickers_para_analisar = {}
    for stock in lista_completa_brapi:
        setor_brapi = stock.get('sector')
        # Reativa o filtro de setor
        if setor_brapi in setores:
            ticker = f"{stock.get('stock')}.SA"
            # <<< CORREÇÃO DO LOGO APLICADA AQUI >>>
            # Armazenamos o setor e o logo da brapi para uso posterior
            tickers_para_analisar[ticker] = {
                'setor': setor_brapi,
                'logo': stock.get('logo') 
            }
    
    total = len(tickers_para_analisar)
    print(f"✅ Mapeamento concluído. {total} ativos serão analisados em detalhe.")

    # Etapa 2: Coleta de Dados Detalhada
    dados_finais = {}
    print("\nIniciando coleta detalhada de dados no yfinance...")
    for i, (ticker, brapi_data) in enumerate(tickers_para_analisar.items()):
        try:
            print(f"Analisando [{i+1}/{total}]: {ticker}...")

            stock = yf.Ticker(ticker)
            info = stock.info
            
            # <<< FILTRO DE PAÍS REATIVADO >>>
            if info.get("country") != "Brazil":
                print(f"  -> DESCARTADO: {ticker} não é do Brasil.")
                continue
            
            # Filtro de Market Cap continua desativado para garantir a inclusão da Taesa

            dados_finais[ticker] = {
                "Empresa": info.get("longName", "N/A"),
                "Setor (brapi)": brapi_data['setor'],
                "Subsetor (yfinance)": info.get("industry", "N/A"),
                "País": info.get("country", "N/A"),
                "Market Cap": info.get("marketCap"),
                "Tipo": info.get("type"),
                "Logo": brapi_data['logo'],
            }
            print(f"  -> ✅ INCLUÍDO: {ticker}")

        except Exception as e:
            print(f"  -> ERRO: Falha ao processar {ticker}. Erro: {e}")
            continue
                
    return dados_finais

# --- EXECUÇÃO E APRESENTAÇÃO DOS RESULTADOS ---
resultados = scanner_final(setores_alvo)

if resultados:
    print("\n✅ Análise finalizada.")
    df_resultado = pd.DataFrame.from_dict(resultados, orient="index")
    
    df_resultado.reset_index(inplace=True)
    df_resultado.rename(columns={'index': 'Ticker'}, inplace=True)
    
    if "Market Cap" in df_resultado.columns:
         df_resultado["Market Cap Num"] = pd.to_numeric(df_resultado["Market Cap"], errors='coerce')
         df_resultado["Market Cap"] = df_resultado["Market Cap Num"].apply(
             lambda x: f"R$ {x/1_000_000_000:.2f} Bi" if pd.notna(x) and x > 0 else "N/A"
         )

    df_ordenado = df_resultado.sort_values(by=['Setor (brapi)', 'Market Cap Num'], ascending=[True, False])
    
    colunas_finais = ['Ticker', 'Empresa', 'Setor (brapi)', 'Subsetor (yfinance)', 'País', 'Market Cap', 'Logo']
    df_final = df_ordenado[colunas_finais]
    
    print("\n--- Relatório Filtrado e Inclusivo ---")
    print(df_final.to_string(index=False))

    # --- SALVANDO O ARQUIVO NO CAMINHO ESPECÍFICO ---
    try:
        output_folder = r"E:\Github\finance-manager\datasets"
        output_filename = "scanner_filtrado_final.xlsx" # Novo nome
        full_path = os.path.join(output_folder, output_filename)
        
        os.makedirs(output_folder, exist_ok=True)
        
        df_final.to_excel(full_path, index=False)
        print(f"\n✅ Resultados salvos com sucesso no caminho: {full_path}")
    except Exception as e:
        print(f"\n❌ Erro ao salvar o arquivo Excel: {e}")
else:
    print("\nNenhuma empresa foi encontrada para os critérios especificados.")
# Out:
# Iniciando scanner final focado...
# Mapeando ativos dos setores alvo...
# ✅ Mapeamento concluído. 389 ativos serão analisados em detalhe.
#
# Iniciando coleta detalhada de dados no yfinance...
# Analisando [1/389]: BBDC4.SA...
#   -> ✅ INCLUÍDO: BBDC4.SA
# Analisando [2/389]: BBAS3.SA...
#   -> ✅ INCLUÍDO: BBAS3.SA
# Analisando [3/389]: VAMO3.SA...
#   -> ✅ INCLUÍDO: VAMO3.SA
# Analisando [4/389]: B3SA3.SA...
#   -> ✅ INCLUÍDO: B3SA3.SA
# Analisando [5/389]: ITSA4.SA...
#   -> ✅ INCLUÍDO: ITSA4.SA
# Analisando [6/389]: CSAN3.SA...
#   -> ✅ INCLUÍDO: CSAN3.SA
# Analisando [7/389]: CPLE6.SA...
#   -> ✅ INCLUÍDO: CPLE6.SA
# Analisando [8/389]: RENT3.SA...
#   -> ✅ INCLUÍDO: RENT3.SA
# Analisando [9/389]: ITUB4.SA...
#   -> ✅ INCLUÍDO: ITUB4.SA
# Analisando [10/389]: MOVI3.SA...
#   -> ✅ INCLUÍDO: MOVI3.SA
# Analisando [11/389]: CMIG4.SA...
#   -> ✅ INCLUÍDO: CMIG4.SA
# Analisando [12/389]: CPLE3.SA...
#   -> ✅ INCLUÍDO: CPLE3.SA
# Analisando [13/389]: BBDC3.SA...
#   -> ✅ INCLUÍDO: BBDC3.SA
# Analisando [14/389]: ENEV3.SA...
#   -> ✅ INCLUÍDO: ENEV3.SA
# Analisando [15/389]: BBSE3.SA...
#   -> ✅ INCLUÍDO: BBSE3.SA
# Analisando [16/389]: EQTL3.SA...
#   -> ✅ INCLUÍDO: EQTL3.SA
# Analisando [17/389]: TIMS3.SA...
#   -> ✅ INCLUÍDO: TIMS3.SA
# Analisando [18/389]: BRAP4.SA...
#   -> ✅ INCLUÍDO: BRAP4.SA
# Analisando [19/389]: SRNA3.SA...
#   -> ✅ INCLUÍDO: SRNA3.SA
# Analisando [20/389]: BPAC11.SA...
#   -> ✅ INCLUÍDO: BPAC11.SA
# Analisando [21/389]: CXSE3.SA...
#   -> ✅ INCLUÍDO: CXSE3.SA
# Analisando [22/389]: INBR32.SA...
#   -> ✅ INCLUÍDO: INBR32.SA
# Analisando [23/389]: ELET3.SA...
#   -> ✅ INCLUÍDO: ELET3.SA
# Analisando [24/389]: AZTE3.SA...
#   -> ✅ INCLUÍDO: AZTE3.SA
# Analisando [25/389]: VIVT3.SA...
#   -> ✅ INCLUÍDO: VIVT3.SA
# Analisando [26/389]: MULT3.SA...
#   -> ✅ INCLUÍDO: MULT3.SA
# Analisando [27/389]: AURE3.SA...
#   -> ✅ INCLUÍDO: AURE3.SA
# Analisando [28/389]: ROXO34.SA...
#   -> ✅ INCLUÍDO: ROXO34.SA
# Analisando [29/389]: PSSA3.SA...
#   -> ✅ INCLUÍDO: PSSA3.SA
# Analisando [30/389]: ALOS3.SA...
#   -> ✅ INCLUÍDO: ALOS3.SA
# Analisando [31/389]: CYRE3.SA...
#   -> ✅ INCLUÍDO: CYRE3.SA
# Analisando [32/389]: SANB11.SA...
#   -> ✅ INCLUÍDO: SANB11.SA
# Analisando [33/389]: IGTI11.SA...
#   -> ✅ INCLUÍDO: IGTI11.SA
# Analisando [34/389]: SAPR4.SA...
#   -> ✅ INCLUÍDO: SAPR4.SA
# Analisando [35/389]: EGIE3.SA...
#   -> ✅ INCLUÍDO: EGIE3.SA
# Analisando [36/389]: TAEE11.SA...
#   -> ✅ INCLUÍDO: TAEE11.SA
# Analisando [37/389]: SBSP3.SA...
#   -> ✅ INCLUÍDO: SBSP3.SA
# Analisando [38/389]: SAPR11.SA...
#   -> ✅ INCLUÍDO: SAPR11.SA
# Analisando [39/389]: ENGI11.SA...
#   -> ✅ INCLUÍDO: ENGI11.SA
# Analisando [40/389]: JHSF3.SA...
#   -> ✅ INCLUÍDO: JHSF3.SA
# Analisando [41/389]: PDGR3.SA...
#   -> ✅ INCLUÍDO: PDGR3.SA
# Analisando [42/389]: DIRR3.SA...
#   -> ✅ INCLUÍDO: DIRR3.SA
# Analisando [43/389]: CSMG3.SA...
#   -> ✅ INCLUÍDO: CSMG3.SA
# Analisando [44/389]: MILS3.SA...
#   -> ✅ INCLUÍDO: MILS3.SA
# Analisando [45/389]: LIGT3.SA...
#   -> ✅ INCLUÍDO: LIGT3.SA
# Analisando [46/389]: BRSR6.SA...
#   -> ✅ INCLUÍDO: BRSR6.SA
# Analisando [47/389]: ARML3.SA...
#   -> ✅ INCLUÍDO: ARML3.SA
# Analisando [48/389]: ISAE4.SA...
#   -> ✅ INCLUÍDO: ISAE4.SA
# Analisando [49/389]: CURY3.SA...
#   -> ✅ INCLUÍDO: CURY3.SA
# Analisando [50/389]: AZEV3.SA...
#   -> ✅ INCLUÍDO: AZEV3.SA
# Analisando [51/389]: BMGB4.SA...
#   -> ✅ INCLUÍDO: BMGB4.SA
# Analisando [52/389]: OIBR3.SA...
#   -> ✅ INCLUÍDO: OIBR3.SA
# Analisando [53/389]: EZTC3.SA...
#   -> ✅ INCLUÍDO: EZTC3.SA
# Analisando [54/389]: TEND3.SA...
#   -> ✅ INCLUÍDO: TEND3.SA
# Analisando [55/389]: ABCB4.SA...
#   -> ✅ INCLUÍDO: ABCB4.SA
# Analisando [56/389]: BPAN4.SA...
#   -> ✅ INCLUÍDO: BPAN4.SA
# Analisando [57/389]: AZEV4.SA...
#   -> ✅ INCLUÍDO: AZEV4.SA
# Analisando [58/389]: ELET6.SA...
#   -> ✅ INCLUÍDO: ELET6.SA
# Analisando [59/389]: IRBR3.SA...
#   -> ✅ INCLUÍDO: IRBR3.SA
# Analisando [60/389]: SYNE3.SA...
#   -> ✅ INCLUÍDO: SYNE3.SA
# Analisando [61/389]: CPFE3.SA...
#   -> ✅ INCLUÍDO: CPFE3.SA
# Analisando [62/389]: ALUP11.SA...
#   -> ✅ INCLUÍDO: ALUP11.SA
# Analisando [63/389]: NEOE3.SA...
#   -> ✅ INCLUÍDO: NEOE3.SA
# Analisando [64/389]: LAVV3.SA...
#   -> ✅ INCLUÍDO: LAVV3.SA
# Analisando [65/389]: PLPL3.SA...
#   -> ✅ INCLUÍDO: PLPL3.SA
# Analisando [66/389]: ORVR3.SA...
#   -> ✅ INCLUÍDO: ORVR3.SA
# Analisando [67/389]: BBAS3F.SA...
#   -> DESCARTADO: BBAS3F.SA não é do Brasil.
# Analisando [68/389]: PRNR3.SA...
#   -> ✅ INCLUÍDO: PRNR3.SA
# Analisando [69/389]: XPBR31.SA...
#   -> DESCARTADO: XPBR31.SA não é do Brasil.
# Analisando [70/389]: ITUB3.SA...
#   -> ✅ INCLUÍDO: ITUB3.SA
# Analisando [71/389]: MDNE3.SA...
#   -> ✅ INCLUÍDO: MDNE3.SA
# Analisando [72/389]: SAPR3.SA...
#   -> ✅ INCLUÍDO: SAPR3.SA
# Analisando [73/389]: MELK3.SA...
#   -> ✅ INCLUÍDO: MELK3.SA
# Analisando [74/389]: FIQE3.SA...
#   -> ✅ INCLUÍDO: FIQE3.SA
# Analisando [75/389]: EVEN3.SA...
#   -> ✅ INCLUÍDO: EVEN3.SA
# Analisando [76/389]: MTRE3.SA...
#   -> ✅ INCLUÍDO: MTRE3.SA
# Analisando [77/389]: BRBI11.SA...
#   -> ✅ INCLUÍDO: BRBI11.SA
# Analisando [78/389]: WIZC3.SA...
#   -> ✅ INCLUÍDO: WIZC3.SA
# Analisando [79/389]: GFSA3.SA...
#   -> ✅ INCLUÍDO: GFSA3.SA
# Analisando [80/389]: RNEW4.SA...
#   -> ✅ INCLUÍDO: RNEW4.SA
# Analisando [81/389]: PINE4.SA...
#   -> ✅ INCLUÍDO: PINE4.SA
# Analisando [82/389]: LOGG3.SA...
#   -> ✅ INCLUÍDO: LOGG3.SA
# Analisando [83/389]: BRST3.SA...
#   -> ✅ INCLUÍDO: BRST3.SA
# Analisando [84/389]: BBSE3F.SA...
#   -> DESCARTADO: BBSE3F.SA não é do Brasil.
# Analisando [85/389]: C2OI34.SA...
#   -> DESCARTADO: C2OI34.SA não é do Brasil.
# Analisando [86/389]: HBRE3.SA...
#   -> ✅ INCLUÍDO: HBRE3.SA
# Analisando [87/389]: RNEW3.SA...
#   -> ✅ INCLUÍDO: RNEW3.SA
# Analisando [88/389]: AGRO3.SA...
#   -> ✅ INCLUÍDO: AGRO3.SA
# Analisando [89/389]: TCSA3.SA...
#   -> ✅ INCLUÍDO: TCSA3.SA
# Analisando [90/389]: TAEE4.SA...
#   -> ✅ INCLUÍDO: TAEE4.SA
# Analisando [91/389]: CMIG4F.SA...
#   -> DESCARTADO: CMIG4F.SA não é do Brasil.
# Analisando [92/389]: CXSE3F.SA...
#   -> DESCARTADO: CXSE3F.SA não é do Brasil.
# Analisando [93/389]: VISA34.SA...
#   -> DESCARTADO: VISA34.SA não é do Brasil.
# Analisando [94/389]: ITSA3.SA...
#   -> ✅ INCLUÍDO: ITSA3.SA
# Analisando [95/389]: DESK3.SA...
#   -> ✅ INCLUÍDO: DESK3.SA
# Analisando [96/389]: SANB3.SA...
#   -> ✅ INCLUÍDO: SANB3.SA
# Analisando [97/389]: CMIG3.SA...
#   -> ✅ INCLUÍDO: CMIG3.SA
# Analisando [98/389]: ITSA4F.SA...
#   -> DESCARTADO: ITSA4F.SA não é do Brasil.
# Analisando [99/389]: CSAN3F.SA...
#   -> DESCARTADO: CSAN3F.SA não é do Brasil.
# Analisando [100/389]: ISAE4F.SA...
#   -> DESCARTADO: ISAE4F.SA não é do Brasil.
# Analisando [101/389]: BERK34.SA...
#   -> DESCARTADO: BERK34.SA não é do Brasil.
# Analisando [102/389]: G2DI33.SA...
#   -> DESCARTADO: G2DI33.SA não é do Brasil.
# Analisando [103/389]: SANB4.SA...
#   -> ✅ INCLUÍDO: SANB4.SA
# Analisando [104/389]: VAMO3F.SA...
#   -> DESCARTADO: VAMO3F.SA não é do Brasil.
# Analisando [105/389]: SAPR4F.SA...
#   -> DESCARTADO: SAPR4F.SA não é do Brasil.
# Analisando [106/389]: EGIE3F.SA...
#   -> DESCARTADO: EGIE3F.SA não é do Brasil.
# Analisando [107/389]: BRAP3.SA...
#   -> ✅ INCLUÍDO: BRAP3.SA
# Analisando [108/389]: BBDC4F.SA...
#   -> DESCARTADO: BBDC4F.SA não é do Brasil.
# Analisando [109/389]: ITUB4F.SA...
#   -> DESCARTADO: ITUB4F.SA não é do Brasil.
# Analisando [110/389]: TAEE11F.SA...
#   -> DESCARTADO: TAEE11F.SA não é do Brasil.
# Analisando [111/389]: TAEE3.SA...
#   -> ✅ INCLUÍDO: TAEE3.SA
# Analisando [112/389]: CPLE6F.SA...
#   -> DESCARTADO: CPLE6F.SA não é do Brasil.
# Analisando [113/389]: B3SA3F.SA...
#   -> DESCARTADO: B3SA3F.SA não é do Brasil.
# Analisando [114/389]: OIBR4.SA...
#   -> ✅ INCLUÍDO: OIBR4.SA
# Analisando [115/389]: LAND3.SA...
#   -> ✅ INCLUÍDO: LAND3.SA
# Analisando [116/389]: JPMC34.SA...
#   -> DESCARTADO: JPMC34.SA não é do Brasil.
# Analisando [117/389]: BOAC34.SA...
#   -> DESCARTADO: BOAC34.SA não é do Brasil.
# Analisando [118/389]: BMGB4F.SA...
#   -> DESCARTADO: BMGB4F.SA não é do Brasil.
# Analisando [119/389]: CSMG3F.SA...
#   -> DESCARTADO: CSMG3F.SA não é do Brasil.
# Analisando [120/389]: BBDC3F.SA...
#   -> DESCARTADO: BBDC3F.SA não é do Brasil.
# Analisando [121/389]: BRAP4F.SA...
#   -> DESCARTADO: BRAP4F.SA não é do Brasil.
# Analisando [122/389]: DIRR3F.SA...
#   -> DESCARTADO: DIRR3F.SA não é do Brasil.
# Analisando [123/389]: RENT3F.SA...
#   -> DESCARTADO: RENT3F.SA não é do Brasil.
# Analisando [124/389]: VIVT3F.SA...
#   -> DESCARTADO: VIVT3F.SA não é do Brasil.
# Analisando [125/389]: SAPR11F.SA...
#   -> DESCARTADO: SAPR11F.SA não é do Brasil.
# Analisando [126/389]: SCAR3.SA...
#   -> ✅ INCLUÍDO: SCAR3.SA
# Analisando [127/389]: TAEE4F.SA...
#   -> DESCARTADO: TAEE4F.SA não é do Brasil.
# Analisando [128/389]: AURE3F.SA...
#   -> DESCARTADO: AURE3F.SA não é do Brasil.
# Analisando [129/389]: ABCB4F.SA...
#   -> DESCARTADO: ABCB4F.SA não é do Brasil.
# Analisando [130/389]: CEBR6.SA...
#   -> ✅ INCLUÍDO: CEBR6.SA
# Analisando [131/389]: BMEB4.SA...
#   -> ✅ INCLUÍDO: BMEB4.SA
# Analisando [132/389]: ELET3F.SA...
#   -> DESCARTADO: ELET3F.SA não é do Brasil.
# Analisando [133/389]: B1AM34.SA...
#   -> DESCARTADO: B1AM34.SA não é do Brasil.
# Analisando [134/389]: MOVI3F.SA...
#   -> DESCARTADO: MOVI3F.SA não é do Brasil.
# Analisando [135/389]: ITUB3F.SA...
#   -> DESCARTADO: ITUB3F.SA não é do Brasil.
# Analisando [136/389]: SYNE3F.SA...
#   -> DESCARTADO: SYNE3F.SA não é do Brasil.
# Analisando [137/389]: PSSA3F.SA...
#   -> DESCARTADO: PSSA3F.SA não é do Brasil.
# Analisando [138/389]: JHSF3F.SA...
#   -> DESCARTADO: JHSF3F.SA não é do Brasil.
# Analisando [139/389]: TIMS3F.SA...
#   -> DESCARTADO: TIMS3F.SA não é do Brasil.
# Analisando [140/389]: BRBI11F.SA...
#   -> DESCARTADO: BRBI11F.SA não é do Brasil.
# Analisando [141/389]: SAPR3F.SA...
#   -> DESCARTADO: SAPR3F.SA não é do Brasil.
# Analisando [142/389]: CPFE3F.SA...
#   -> DESCARTADO: CPFE3F.SA não é do Brasil.
# Analisando [143/389]: BPAC11F.SA...
#   -> DESCARTADO: BPAC11F.SA não é do Brasil.
# Analisando [144/389]: FIQE3F.SA...
#   -> DESCARTADO: FIQE3F.SA não é do Brasil.
# Analisando [145/389]: BRSR6F.SA...
#   -> DESCARTADO: BRSR6F.SA não é do Brasil.
# Analisando [146/389]: SBSP3F.SA...
#   -> DESCARTADO: SBSP3F.SA não é do Brasil.
# Analisando [147/389]: ITSA3F.SA...
#   -> DESCARTADO: ITSA3F.SA não é do Brasil.
# Analisando [148/389]: AGRO3F.SA...
#   -> DESCARTADO: AGRO3F.SA não é do Brasil.
# Analisando [149/389]: IRBR3F.SA...
#   -> DESCARTADO: IRBR3F.SA não é do Brasil.
# Analisando [150/389]: EQTL3F.SA...
#   -> DESCARTADO: EQTL3F.SA não é do Brasil.
# Analisando [151/389]: CMIG3F.SA...
#   -> DESCARTADO: CMIG3F.SA não é do Brasil.
# Analisando [152/389]: RDNI3.SA...
#   -> ✅ INCLUÍDO: RDNI3.SA
# Analisando [153/389]: CURY3F.SA...
#   -> DESCARTADO: CURY3F.SA não é do Brasil.
# Analisando [154/389]: CYRE3F.SA...
#   -> DESCARTADO: CYRE3F.SA não é do Brasil.
# Analisando [155/389]: MTRE3F.SA...
#   -> DESCARTADO: MTRE3F.SA não é do Brasil.
# Analisando [156/389]: WIZC3F.SA...
#   -> DESCARTADO: WIZC3F.SA não é do Brasil.
# Analisando [157/389]: TAEE3F.SA...
#   -> DESCARTADO: TAEE3F.SA não é do Brasil.
# Analisando [158/389]: ALUP11F.SA...
#   -> DESCARTADO: ALUP11F.SA não é do Brasil.
# Analisando [159/389]: SNCI11.SA...
#   -> ✅ INCLUÍDO: SNCI11.SA
# Analisando [160/389]: CEBR3.SA...
#   -> ✅ INCLUÍDO: CEBR3.SA
# Analisando [161/389]: MELK3F.SA...
#   -> DESCARTADO: MELK3F.SA não é do Brasil.
# Analisando [162/389]: CPLE3F.SA...
#   -> DESCARTADO: CPLE3F.SA não é do Brasil.
# Analisando [163/389]: OIBR3F.SA...
#   -> DESCARTADO: OIBR3F.SA não é do Brasil.
# Analisando [164/389]: IGTI3.SA...
#   -> ✅ INCLUÍDO: IGTI3.SA
# Analisando [165/389]: ELET6F.SA...
#   -> DESCARTADO: ELET6F.SA não é do Brasil.
# Analisando [166/389]: ENGI11F.SA...
#   -> DESCARTADO: ENGI11F.SA não é do Brasil.
# Analisando [167/389]: EZTC3F.SA...
#   -> DESCARTADO: EZTC3F.SA não é do Brasil.
# Analisando [168/389]: SANB11F.SA...
#   -> DESCARTADO: SANB11F.SA não é do Brasil.
# Analisando [169/389]: GPIV33.SA...
#   -> DESCARTADO: GPIV33.SA não é do Brasil.
# Analisando [170/389]: GFSA3F.SA...
#   -> DESCARTADO: GFSA3F.SA não é do Brasil.
# Analisando [171/389]: MULT3F.SA...
#   -> DESCARTADO: MULT3F.SA não é do Brasil.
# Analisando [172/389]: BLAK34.SA...
#   -> DESCARTADO: BLAK34.SA não é do Brasil.
# Analisando [173/389]: AZTE3F.SA...
#   -> DESCARTADO: AZTE3F.SA não é do Brasil.
# Analisando [174/389]: ENEV3F.SA...
#   -> DESCARTADO: ENEV3F.SA não é do Brasil.
# Analisando [175/389]: ALOS3F.SA...
#   -> DESCARTADO: ALOS3F.SA não é do Brasil.
# Analisando [176/389]: ARML3F.SA...
#   -> DESCARTADO: ARML3F.SA não é do Brasil.
# Analisando [177/389]: IGTI11F.SA...
#   -> DESCARTADO: IGTI11F.SA não é do Brasil.
# Analisando [178/389]: OIBR4F.SA...
#   -> DESCARTADO: OIBR4F.SA não é do Brasil.
# Analisando [179/389]: BEES3.SA...
#   -> ✅ INCLUÍDO: BEES3.SA
# Analisando [180/389]: ALUP3.SA...
#   -> ✅ INCLUÍDO: ALUP3.SA
# Analisando [181/389]: INEP4.SA...
#   -> ✅ INCLUÍDO: INEP4.SA
# Analisando [182/389]: BPAC3.SA...
#   -> ✅ INCLUÍDO: BPAC3.SA
# Analisando [183/389]: RNEW11.SA...
#   -> ✅ INCLUÍDO: RNEW11.SA
# Analisando [184/389]: NEOE3F.SA...
#   -> DESCARTADO: NEOE3F.SA não é do Brasil.
# Analisando [185/389]: MDNE3F.SA...
#   -> DESCARTADO: MDNE3F.SA não é do Brasil.
# Analisando [186/389]: ALUP4.SA...
#   -> ✅ INCLUÍDO: ALUP4.SA
# Analisando [187/389]: ENGI4.SA...
#   -> ✅ INCLUÍDO: ENGI4.SA
# Analisando [188/389]: SANB3F.SA...
#   -> DESCARTADO: SANB3F.SA não é do Brasil.
# Analisando [189/389]: PLPL3F.SA...
#   -> DESCARTADO: PLPL3F.SA não é do Brasil.
# Analisando [190/389]: SANB4F.SA...
#   -> DESCARTADO: SANB4F.SA não é do Brasil.
# Analisando [191/389]: BAZA3.SA...
#   -> ✅ INCLUÍDO: BAZA3.SA
# Analisando [192/389]: LAVV3F.SA...
#   -> DESCARTADO: LAVV3F.SA não é do Brasil.
# Analisando [193/389]: BPAN4F.SA...
#   -> DESCARTADO: BPAN4F.SA não é do Brasil.
# Analisando [194/389]: ORVR3F.SA...
#   -> DESCARTADO: ORVR3F.SA não é do Brasil.
# Analisando [195/389]: INEP3.SA...
#   -> ✅ INCLUÍDO: INEP3.SA
# Analisando [196/389]: CTGP34.SA...
#   -> DESCARTADO: CTGP34.SA não é do Brasil.
# Analisando [197/389]: TEND3F.SA...
#   -> DESCARTADO: TEND3F.SA não é do Brasil.
# Analisando [198/389]: EVEN3F.SA...
#   -> DESCARTADO: EVEN3F.SA não é do Brasil.
# Analisando [199/389]: AZEV4F.SA...
#   -> DESCARTADO: AZEV4F.SA não é do Brasil.
# Analisando [200/389]: LIGT3F.SA...
#   -> DESCARTADO: LIGT3F.SA não é do Brasil.
# Analisando [201/389]: BRSR3.SA...
#   -> ✅ INCLUÍDO: BRSR3.SA
# Analisando [202/389]: L1MN34.SA...
#   -> DESCARTADO: L1MN34.SA não é do Brasil.
# Analisando [203/389]: BRAP3F.SA...
#   -> DESCARTADO: BRAP3F.SA não é do Brasil.
# Analisando [204/389]: OSXB3.SA...
#   -> ✅ INCLUÍDO: OSXB3.SA
# Analisando [205/389]: EQIX34.SA...
#   -> DESCARTADO: EQIX34.SA não é do Brasil.
# Analisando [206/389]: ATTB34.SA...
#   -> DESCARTADO: ATTB34.SA não é do Brasil.
# Analisando [207/389]: R2DF34.SA...
#   -> DESCARTADO: R2DF34.SA não é do Brasil.
# Analisando [208/389]: PDGR3F.SA...
#   -> DESCARTADO: PDGR3F.SA não é do Brasil.
# Analisando [209/389]: AVLL3.SA...
#   -> ✅ INCLUÍDO: AVLL3.SA
# Analisando [210/389]: BEES3F.SA...
#   -> DESCARTADO: BEES3F.SA não é do Brasil.
# Analisando [211/389]: RNEW4F.SA...
#   -> DESCARTADO: RNEW4F.SA não é do Brasil.
# Analisando [212/389]: COCE5.SA...
#   -> ✅ INCLUÍDO: COCE5.SA
# Analisando [213/389]: BGIP4.SA...
#   -> ✅ INCLUÍDO: BGIP4.SA
# Analisando [214/389]: CLOV34.SA...
#   -> DESCARTADO: CLOV34.SA não é do Brasil.
# Analisando [215/389]: BCSA34.SA...
#   -> DESCARTADO: BCSA34.SA não é do Brasil.
# Analisando [216/389]: PINE4F.SA...
#   -> DESCARTADO: PINE4F.SA não é do Brasil.
# Analisando [217/389]: ALUP4F.SA...
#   -> DESCARTADO: ALUP4F.SA não é do Brasil.
# Analisando [218/389]: AZEV3F.SA...
#   -> DESCARTADO: AZEV3F.SA não é do Brasil.
# Analisando [219/389]: ISAE3.SA...
#   -> ✅ INCLUÍDO: ISAE3.SA
# Analisando [220/389]: EQPA3.SA...
#   -> ✅ INCLUÍDO: EQPA3.SA
# Analisando [221/389]: EMAE4.SA...
#   -> ✅ INCLUÍDO: EMAE4.SA
# Analisando [222/389]: MILS3F.SA...
#   -> DESCARTADO: MILS3F.SA não é do Brasil.
# Analisando [223/389]: GSGI34.SA...
#   -> DESCARTADO: GSGI34.SA não é do Brasil.
# Analisando [224/389]: LOGG3F.SA...
#   -> DESCARTADO: LOGG3F.SA não é do Brasil.
# Analisando [225/389]: IGTI3F.SA...
#   -> DESCARTADO: IGTI3F.SA não é do Brasil.
# Analisando [226/389]: SRNA3F.SA...
#   -> DESCARTADO: SRNA3F.SA não é do Brasil.
# Analisando [227/389]: VERZ34.SA...
#   -> DESCARTADO: VERZ34.SA não é do Brasil.
# Analisando [228/389]: MSCD34.SA...
#   -> DESCARTADO: MSCD34.SA não é do Brasil.
# Analisando [229/389]: TELB3.SA...
#   -> ✅ INCLUÍDO: TELB3.SA
# Analisando [230/389]: BSLI3.SA...
#   -> ✅ INCLUÍDO: BSLI3.SA
# Analisando [231/389]: AXPB34.SA...
#   -> DESCARTADO: AXPB34.SA não é do Brasil.
# Analisando [232/389]: BEES4F.SA...
#   -> DESCARTADO: BEES4F.SA não é do Brasil.
# Analisando [233/389]: PRNR3F.SA...
#   -> DESCARTADO: PRNR3F.SA não é do Brasil.
# Analisando [234/389]: ISAE3F.SA...
#   -> DESCARTADO: ISAE3F.SA não é do Brasil.
# Analisando [235/389]: BRSR3F.SA...
#   -> DESCARTADO: BRSR3F.SA não é do Brasil.
# Analisando [236/389]: U2PS34.SA...
#   -> DESCARTADO: U2PS34.SA não é do Brasil.
# Analisando [237/389]: GEPA4.SA...
#   -> ✅ INCLUÍDO: GEPA4.SA
# Analisando [238/389]: BPAC5.SA...
#   -> ✅ INCLUÍDO: BPAC5.SA
# Analisando [239/389]: TCSA3F.SA...
#   -> DESCARTADO: TCSA3F.SA não é do Brasil.
# Analisando [240/389]: BRST3F.SA...
#   -> DESCARTADO: BRST3F.SA não é do Brasil.
# Analisando [241/389]: RBIF11.SA...
#   -> ✅ INCLUÍDO: RBIF11.SA
# Analisando [242/389]: BPAC3F.SA...
#   -> DESCARTADO: BPAC3F.SA não é do Brasil.
# Analisando [243/389]: BEES4.SA...
#   -> ✅ INCLUÍDO: BEES4.SA
# Analisando [244/389]: ENGI3.SA...
#   -> ✅ INCLUÍDO: ENGI3.SA
# Analisando [245/389]: DESK3F.SA...
#   -> DESCARTADO: DESK3F.SA não é do Brasil.
# Analisando [246/389]: BMEB4F.SA...
#   -> DESCARTADO: BMEB4F.SA não é do Brasil.
# Analisando [247/389]: RIGG34.SA...
#   -> DESCARTADO: RIGG34.SA não é do Brasil.
# Analisando [248/389]: RNEW3F.SA...
#   -> DESCARTADO: RNEW3F.SA não é do Brasil.
# Analisando [249/389]: BAZA3F.SA...
#   -> DESCARTADO: BAZA3F.SA não é do Brasil.
# Analisando [250/389]: ENGI3F.SA...
#   -> DESCARTADO: ENGI3F.SA não é do Brasil.
# Analisando [251/389]: CEBR5.SA...
#   -> ✅ INCLUÍDO: CEBR5.SA
# Analisando [252/389]: CLSC4.SA...
#   -> ✅ INCLUÍDO: CLSC4.SA
# Analisando [253/389]: PINE3.SA...
#   -> ✅ INCLUÍDO: PINE3.SA
# Analisando [254/389]: TELB4.SA...
#   -> ✅ INCLUÍDO: TELB4.SA
# Analisando [255/389]: ENGI4F.SA...
#   -> DESCARTADO: ENGI4F.SA não é do Brasil.
# Analisando [256/389]: CEBR6F.SA...
#   -> DESCARTADO: CEBR6F.SA não é do Brasil.
# Analisando [257/389]: CEBR3F.SA...
#   -> DESCARTADO: CEBR3F.SA não é do Brasil.
# Analisando [258/389]: IRIM11.SA...
#   -> ✅ INCLUÍDO: IRIM11.SA
# Analisando [259/389]: WFCO34.SA...
#   -> DESCARTADO: WFCO34.SA não é do Brasil.
# Analisando [260/389]: COCE5F.SA...
#   -> DESCARTADO: COCE5F.SA não é do Brasil.
# Analisando [261/389]: LBRD34.SA...
#   -> DESCARTADO: LBRD34.SA não é do Brasil.
# Analisando [262/389]: REDE3.SA...
#   -> ✅ INCLUÍDO: REDE3.SA
# Analisando [263/389]: BNBR3.SA...
#   -> ✅ INCLUÍDO: BNBR3.SA
# Analisando [264/389]: EQPA3F.SA...
#   -> DESCARTADO: EQPA3F.SA não é do Brasil.
# Analisando [265/389]: LAND3F.SA...
#   -> DESCARTADO: LAND3F.SA não é do Brasil.
# Analisando [266/389]: M2PW34.SA...
#   -> DESCARTADO: M2PW34.SA não é do Brasil.
# Analisando [267/389]: SCAR3F.SA...
#   -> DESCARTADO: SCAR3F.SA não é do Brasil.
# Analisando [268/389]: REDE3F.SA...
#   -> DESCARTADO: REDE3F.SA não é do Brasil.
# Analisando [269/389]: ALUP3F.SA...
#   -> DESCARTADO: ALUP3F.SA não é do Brasil.
# Analisando [270/389]: C2OL34.SA...
#   -> DESCARTADO: C2OL34.SA não é do Brasil.
# Analisando [271/389]: BSLI4.SA...
#   -> ✅ INCLUÍDO: BSLI4.SA
# Analisando [272/389]: HBTS5.SA...
#   -> ✅ INCLUÍDO: HBTS5.SA
# Analisando [273/389]: ENMT3.SA...
#   -> ✅ INCLUÍDO: ENMT3.SA
# Analisando [274/389]: ADMF3.SA...
#   -> ✅ INCLUÍDO: ADMF3.SA
# Analisando [275/389]: EKTR4.SA...
#   -> ✅ INCLUÍDO: EKTR4.SA
# Analisando [276/389]: N1IS34.SA...
#   -> DESCARTADO: N1IS34.SA não é do Brasil.
# Analisando [277/389]: RNEW11F.SA...
#   -> DESCARTADO: RNEW11F.SA não é do Brasil.
# Analisando [278/389]: A1EG34.SA...
#   -> DESCARTADO: A1EG34.SA não é do Brasil.
# Analisando [279/389]: HBRE3F.SA...
#   -> DESCARTADO: HBRE3F.SA não é do Brasil.
# Analisando [280/389]: O2HI34.SA...
#   -> DESCARTADO: O2HI34.SA não é do Brasil.
# Analisando [281/389]: H1SB34.SA...
#   -> DESCARTADO: H1SB34.SA não é do Brasil.
# Analisando [282/389]: BGIP4F.SA...
#   -> DESCARTADO: BGIP4F.SA não é do Brasil.
# Analisando [283/389]: P1LD34.SA...
#   -> DESCARTADO: P1LD34.SA não é do Brasil.
# Analisando [284/389]: DTCY3.SA...
#   -> ✅ INCLUÍDO: DTCY3.SA
# Analisando [285/389]: RENV11.SA...
#   -> ✅ INCLUÍDO: RENV11.SA
# Analisando [286/389]: CEEB3.SA...
#   -> ✅ INCLUÍDO: CEEB3.SA
# Analisando [287/389]: C1HT34.SA...
#   -> DESCARTADO: C1HT34.SA não é do Brasil.
# Analisando [288/389]: EMAE4F.SA...
#   -> DESCARTADO: EMAE4F.SA não é do Brasil.
# Analisando [289/389]: BSLI3F.SA...
#   -> DESCARTADO: BSLI3F.SA não é do Brasil.
# Analisando [290/389]: INEP4F.SA...
#   -> DESCARTADO: INEP4F.SA não é do Brasil.
# Analisando [291/389]: MOAR3F.SA...
#   -> DESCARTADO: MOAR3F.SA não é do Brasil.
# Analisando [292/389]: EGYR11.SA...
#   -> ✅ INCLUÍDO: EGYR11.SA
# Analisando [293/389]: S1YF34.SA...
#   -> DESCARTADO: S1YF34.SA não é do Brasil.
# Analisando [294/389]: GEPA4F.SA...
#   -> DESCARTADO: GEPA4F.SA não é do Brasil.
# Analisando [295/389]: OSXB3F.SA...
#   -> DESCARTADO: OSXB3F.SA não é do Brasil.
# Analisando [296/389]: CGAS5F.SA...
#   -> DESCARTADO: CGAS5F.SA não é do Brasil.
# Analisando [297/389]: BRSR5F.SA...
#   -> DESCARTADO: BRSR5F.SA não é do Brasil.
# Analisando [298/389]: EKTR4F.SA...
#   -> DESCARTADO: EKTR4F.SA não é do Brasil.
# Analisando [299/389]: V1OD34.SA...
#   -> DESCARTADO: V1OD34.SA não é do Brasil.
# Analisando [300/389]: AVLL3F.SA...
#   -> DESCARTADO: AVLL3F.SA não é do Brasil.
# Analisando [301/389]: FSPE11F.SA...
#   -> DESCARTADO: FSPE11F.SA não é do Brasil.
# Analisando [302/389]: BPAC5F.SA...
#   -> DESCARTADO: BPAC5F.SA não é do Brasil.
# Analisando [303/389]: P2AX34.SA...
#   -> DESCARTADO: P2AX34.SA não é do Brasil.
# Analisando [304/389]: B2AP34.SA...
#   -> DESCARTADO: B2AP34.SA não é do Brasil.
# Analisando [305/389]: BMEB3.SA...
#   -> ✅ INCLUÍDO: BMEB3.SA
# Analisando [306/389]: RDNI3F.SA...
#   -> DESCARTADO: RDNI3F.SA não é do Brasil.
# Analisando [307/389]: NEXP3.SA...
#   -> ✅ INCLUÍDO: NEXP3.SA
# Analisando [308/389]: RPAD6.SA...
#   -> ✅ INCLUÍDO: RPAD6.SA
# Analisando [309/389]: AFLT3.SA...
#   -> ✅ INCLUÍDO: AFLT3.SA
# Analisando [310/389]: BRSR5.SA...
#   -> ✅ INCLUÍDO: BRSR5.SA
# Analisando [311/389]: CLSC4F.SA...
#   -> DESCARTADO: CLSC4F.SA não é do Brasil.
# Analisando [312/389]: CGAS3F.SA...
#   -> DESCARTADO: CGAS3F.SA não é do Brasil.
# Analisando [313/389]: ENMT3F.SA...
#   -> DESCARTADO: ENMT3F.SA não é do Brasil.
# Analisando [314/389]: L1YG34.SA...
#   -> DESCARTADO: L1YG34.SA não é do Brasil.
# Analisando [315/389]: R1SG34.SA...
#   -> DESCARTADO: R1SG34.SA não é do Brasil.
# Analisando [316/389]: INEP3F.SA...
#   -> DESCARTADO: INEP3F.SA não é do Brasil.
# Analisando [317/389]: DBAG34.SA...
#   -> DESCARTADO: DBAG34.SA não é do Brasil.
# Analisando [318/389]: TELB3F.SA...
#   -> DESCARTADO: TELB3F.SA não é do Brasil.
# Analisando [319/389]: BNBR3F.SA...
#   -> DESCARTADO: BNBR3F.SA não é do Brasil.
# Analisando [320/389]: N2LY34.SA...
#   -> DESCARTADO: N2LY34.SA não é do Brasil.
# Analisando [321/389]: MSBR34.SA...
#   -> DESCARTADO: MSBR34.SA não é do Brasil.
# Analisando [322/389]: TELB4F.SA...
#   -> DESCARTADO: TELB4F.SA não é do Brasil.
# Analisando [323/389]: FSTU11F.SA...
#   -> DESCARTADO: FSTU11F.SA não é do Brasil.
# Analisando [324/389]: P1GR34.SA...
#   -> DESCARTADO: P1GR34.SA não é do Brasil.
# Analisando [325/389]: DTCY3F.SA...
#   -> DESCARTADO: DTCY3F.SA não é do Brasil.
# Analisando [326/389]: NEXT34.SA...
#   -> DESCARTADO: NEXT34.SA não é do Brasil.
# Analisando [327/389]: CLSC3F.SA...
#   -> DESCARTADO: CLSC3F.SA não é do Brasil.
# Analisando [328/389]: GSHP3F.SA...
#   -> DESCARTADO: GSHP3F.SA não é do Brasil.
# Analisando [329/389]: U1RI34.SA...
#   -> DESCARTADO: U1RI34.SA não é do Brasil.
# Analisando [330/389]: M1MC34.SA...
#   -> DESCARTADO: M1MC34.SA não é do Brasil.
# Analisando [331/389]: TRVC34.SA...
#   -> DESCARTADO: TRVC34.SA não é do Brasil.
# Analisando [332/389]: PINE3F.SA...
#   -> DESCARTADO: PINE3F.SA não é do Brasil.
# Analisando [333/389]: CPLE5F.SA...
#   -> DESCARTADO: CPLE5F.SA não é do Brasil.
# Analisando [334/389]: BSLI4F.SA...
#   -> DESCARTADO: BSLI4F.SA não é do Brasil.
# Analisando [335/389]: S1BA34.SA...
#   -> DESCARTADO: S1BA34.SA não é do Brasil.
# Analisando [336/389]: R1IN34.SA...
#   -> DESCARTADO: R1IN34.SA não é do Brasil.
# Analisando [337/389]: GEPA3F.SA...
#   -> DESCARTADO: GEPA3F.SA não é do Brasil.
# Analisando [338/389]: CEEB3F.SA...
#   -> DESCARTADO: CEEB3F.SA não é do Brasil.
# Analisando [339/389]: SCHW34.SA...
#   -> DESCARTADO: SCHW34.SA não é do Brasil.
# Analisando [340/389]: SIMN34.SA...
#   -> DESCARTADO: SIMN34.SA não é do Brasil.
# Analisando [341/389]: O1KE34.SA...
#   -> DESCARTADO: O1KE34.SA não é do Brasil.
# Analisando [342/389]: W1YC34.SA...
#   -> DESCARTADO: W1YC34.SA não é do Brasil.
# Analisando [343/389]: AFLT3F.SA...
#   -> DESCARTADO: AFLT3F.SA não é do Brasil.
# Analisando [344/389]: N1RG34.SA...
#   -> DESCARTADO: N1RG34.SA não é do Brasil.
# Analisando [345/389]: BMEB3F.SA...
#   -> DESCARTADO: BMEB3F.SA não é do Brasil.
# Analisando [346/389]: CEBR5F.SA...
#   -> DESCARTADO: CEBR5F.SA não é do Brasil.
# Analisando [347/389]: N1DA34.SA...
#   -> DESCARTADO: N1DA34.SA não é do Brasil.
# Analisando [348/389]: S1RE34.SA...
#   -> DESCARTADO: S1RE34.SA não é do Brasil.
# Analisando [349/389]: N1OV34.SA...
#   -> DESCARTADO: N1OV34.SA não é do Brasil.
# Analisando [350/389]: L2PL34.SA...
#   -> DESCARTADO: L2PL34.SA não é do Brasil.
# Analisando [351/389]: UBSG34.SA...
#   -> DESCARTADO: UBSG34.SA não é do Brasil.
# Analisando [352/389]: USBC34.SA...
#   -> DESCARTADO: USBC34.SA não é do Brasil.
# Analisando [353/389]: BMIN3F.SA...
#   -> DESCARTADO: BMIN3F.SA não é do Brasil.
# Analisando [354/389]: TLNC34.SA...
#   -> DESCARTADO: TLNC34.SA não é do Brasil.
# Analisando [355/389]: S2TA34.SA...
#   -> DESCARTADO: S2TA34.SA não é do Brasil.
# Analisando [356/389]: A2RE34.SA...
#   -> DESCARTADO: A2RE34.SA não é do Brasil.
# Analisando [357/389]: PPLA11.SA...
#   -> ✅ INCLUÍDO: PPLA11.SA
# Analisando [358/389]: A1ES34.SA...
#   -> DESCARTADO: A1ES34.SA não é do Brasil.
# Analisando [359/389]: NMRH34.SA...
#   -> DESCARTADO: NMRH34.SA não é do Brasil.
# Analisando [360/389]: ADMF3F.SA...
#   -> DESCARTADO: ADMF3F.SA não é do Brasil.
# Analisando [361/389]: BMIN4F.SA...
#   -> DESCARTADO: BMIN4F.SA não é do Brasil.
# Analisando [362/389]: A1RE34.SA...
#   -> DESCARTADO: A1RE34.SA não é do Brasil.
# Analisando [363/389]: W1EL34.SA...
#   -> DESCARTADO: W1EL34.SA não é do Brasil.
# Analisando [364/389]: NEXP3F.SA...
#   -> DESCARTADO: NEXP3F.SA não é do Brasil.
# Analisando [365/389]: W1MB34.SA...
#   -> DESCARTADO: W1MB34.SA não é do Brasil.
# Analisando [366/389]: A1WK34.SA...
#   -> DESCARTADO: A1WK34.SA não é do Brasil.
# Analisando [367/389]: BGIP3F.SA...
#   -> DESCARTADO: BGIP3F.SA não é do Brasil.
# Analisando [368/389]: C1BR34.SA...
#   -> DESCARTADO: C1BR34.SA não é do Brasil.
# Analisando [369/389]: HBTS5F.SA...
#   -> DESCARTADO: HBTS5F.SA não é do Brasil.
# Analisando [370/389]: CBEE3F.SA...
#   -> DESCARTADO: CBEE3F.SA não é do Brasil.
# Analisando [371/389]: BONY34.SA...
#   -> DESCARTADO: BONY34.SA não é do Brasil.
# Analisando [372/389]: I1VZ34.SA...
#   -> DESCARTADO: I1VZ34.SA não é do Brasil.
# Analisando [373/389]: W1MC34.SA...
#   -> DESCARTADO: W1MC34.SA não é do Brasil.
# Analisando [374/389]: A1MP34.SA...
#   -> DESCARTADO: A1MP34.SA não é do Brasil.
# Analisando [375/389]: PEAB3F.SA...
#   -> DESCARTADO: PEAB3F.SA não é do Brasil.
# Analisando [376/389]: M1UF34.SA...
#   -> DESCARTADO: M1UF34.SA não é do Brasil.
# Analisando [377/389]: EQMA3BF.SA...
#   -> DESCARTADO: EQMA3BF.SA não é do Brasil.
# Analisando [378/389]: CHME34.SA...
#   -> DESCARTADO: CHME34.SA não é do Brasil.
# Analisando [379/389]: M1AA34.SA...
#   -> DESCARTADO: M1AA34.SA não é do Brasil.
# Analisando [380/389]: WUNI34.SA...
#   -> DESCARTADO: WUNI34.SA não é do Brasil.
# Analisando [381/389]: T1MU34.SA...
#   -> DESCARTADO: T1MU34.SA não é do Brasil.
# Analisando [382/389]: J1EF34.SA...
#   -> DESCARTADO: J1EF34.SA não é do Brasil.
# Analisando [383/389]: SOND6F.SA...
#   -> DESCARTADO: SOND6F.SA não é do Brasil.
# Analisando [384/389]: CEED4F.SA...
#   -> DESCARTADO: CEED4F.SA não é do Brasil.
# Analisando [385/389]: ELET5F.SA...
#   -> DESCARTADO: ELET5F.SA não é do Brasil.
# Analisando [386/389]: N1GG34.SA...
#   -> DESCARTADO: N1GG34.SA não é do Brasil.
# Analisando [387/389]: A1LL34.SA...
#   -> DESCARTADO: A1LL34.SA não é do Brasil.
# Analisando [388/389]: T1OW34.SA...
#   -> DESCARTADO: T1OW34.SA não é do Brasil.
# Analisando [389/389]: EKTR3F.SA...
#   -> DESCARTADO: EKTR3F.SA não é do Brasil.
#
# ✅ Análise finalizada.
#
# --- Relatório Filtrado e Inclusivo ---
#    Ticker                                                                 Empresa       Setor (brapi)                     Subsetor (yfinance)   País   Market Cap                                     Logo
#  VIVT3.SA                                                  Telefônica Brasil S.A.      Communications                        Telecom Services Brazil  R$ 98.50 Bi  https://icons.brapi.dev/icons/VIVT3.svg
#  AVLL3.SA                                                         Alphaville S.A.             Finance               Real Estate - Development Brazil   R$ 0.34 Bi  https://icons.brapi.dev/icons/BRAPI.svg
#  ADMF3.SA                 CIABRASF - Cia. Brasileira de Serviços Financeiros S.A.             Finance                        Asset Management Brazil   R$ 0.22 Bi  https://icons.brapi.dev/icons/BRAPI.svg
#  HBTS5.SA                                    Companhia Habitasul de Participações             Finance                    Real Estate Services Brazil   R$ 0.17 Bi  https://icons.brapi.dev/icons/BRAPI.svg
#  GFSA3.SA                                                             Gafisa S.A.             Finance                Residential Construction Brazil   R$ 0.14 Bi  https://icons.brapi.dev/icons/GFSA3.svg
# IRIM11.SA                               Iridium Fundo De Investimento Imobiliario             Finance                      REIT - Diversified Brazil   R$ 0.13 Bi  https://icons.brapi.dev/icons/BRAPI.svg
#  RDNI3.SA                                          RNI Negócios Imobiliários S.A.             Finance               Real Estate - Development Brazil   R$ 0.10 Bi  https://icons.brapi.dev/icons/RDNI3.svg
#  TCSA3.SA                                                            Tecnisa S.A.             Finance               Real Estate - Development Brazil   R$ 0.09 Bi  https://icons.brapi.dev/icons/TCSA3.svg
# PPLA11.SA                                                PPLA Participations Ltd.             Finance                        Asset Management Brazil   R$ 0.04 Bi https://icons.brapi.dev/icons/PPLA11.svg
#  NEXP3.SA                                                Nexpe Participações S.A.             Finance                    Real Estate Services Brazil   R$ 0.01 Bi  https://icons.brapi.dev/icons/NEXP3.svg
#  PDGR3.SA                         PDG Realty S.A. Empreendimentos e Participações             Finance               Real Estate - Development Brazil   R$ 0.01 Bi  https://icons.brapi.dev/icons/PDGR3.svg
# RENV11.SA Cpv Energia Fundo De Investimento Imobiliario Responsabilidade Limitada             Finance                      REIT - Diversified Brazil   R$ 0.01 Bi https://icons.brapi.dev/icons/RENV11.svg
# EGYR11.SA                         Energy Resort Fundo De Investimento Imobiliario             Finance                      REIT - Diversified Brazil   R$ 0.00 Bi  https://icons.brapi.dev/icons/BRAPI.svg
# IGTI11.SA                                                           Iguatemi S.A.             Finance                    Real Estate Services Brazil          N/A https://icons.brapi.dev/icons/IGTI11.svg
# BRBI11.SA                                                   BRBI BR Partners S.A.             Finance                         Capital Markets Brazil          N/A https://icons.brapi.dev/icons/BRBI11.svg
# RBIF11.SA        Rio Bravo Esg FICFI Em Infraestrutura Renda Fixa Credito Privado             Finance                                         Brazil          N/A  https://icons.brapi.dev/icons/BRAPI.svg
#  TAEE3.SA                           Transmissora Aliança de Energia Elétrica S.A. Industrial Services          Utilities - Regulated Electric Brazil  R$ 11.87 Bi  https://icons.brapi.dev/icons/TAEE3.svg
#  TAEE4.SA                           Transmissora Aliança de Energia Elétrica S.A. Industrial Services          Utilities - Regulated Electric Brazil  R$ 11.87 Bi  https://icons.brapi.dev/icons/TAEE4.svg
# TAEE11.SA                           Transmissora Aliança de Energia Elétrica S.A. Industrial Services          Utilities - Regulated Electric Brazil  R$ 11.85 Bi https://icons.brapi.dev/icons/TAEE11.svg
#  RNEW3.SA                                                     Renova Energia S.A.           Utilities                   Utilities - Renewable Brazil   R$ 0.34 Bi  https://icons.brapi.dev/icons/RNEW3.svg
#
# ✅ Resultados salvos com sucesso no caminho: E:\Github\finance-manager\datasets\scanner_filtrado_final.xlsx

# %% [markdown]
# Alteraceso v2

# %%
import requests
import yfinance as yf
import pandas as pd
import os

# --- PASSO 1: CONFIGURAÇÃO DOS SETORES-ALVO ---
# A busca é focada nestes setores, incluindo sua adição.
setores_alvo = [
    "Finance",
    "Utilities",
    "Communications",
    "Industrial Services" # Adicionado conforme sua modificação
]

# --- FUNÇÃO PRINCIPAL COM A LÓGICA FINAL ---
def scanner_final_com_tipo(setores):
    """
    Busca apenas AÇÕES (type='stock') dos setores-alvo, filtrando por 
    país e incluindo a coluna 'Tipo' no resultado.
    """
    print("Iniciando scanner final focado (filtrando por tipo 'stock')...")
    try:
        url = "https://brapi.dev/api/quote/list"
        lista_completa_brapi = requests.get(url).json().get('stocks', [])
    except Exception as e:
        print(f"❌ Erro fatal ao buscar a lista da brapi: {e}")
        return {}

    # Etapa 1: Mapear tickers, setores, logos e tipos da brapi
    print("Mapeando ativos dos setores alvo...")
    tickers_para_analisar = {}
    for stock in lista_completa_brapi:
        setor_brapi = stock.get('sector')
        tipo_ativo = stock.get('type')

        # <<< NOVO FILTRO DE TIPO ADICIONADO AQUI >>>
        # Agora o script verifica o setor E se o tipo é 'stock'
        if setor_brapi in setores and tipo_ativo == 'stock':
            ticker = f"{stock.get('stock')}.SA"
            
            # Armazenamos todos os dados que vêm da brapi
            tickers_para_analisar[ticker] = {
                'setor': setor_brapi,
                'logo': stock.get('logo'),
                'tipo': tipo_ativo # Armazena o tipo para a coluna final
            }
    
    total = len(tickers_para_analisar)
    print(f"✅ Mapeamento concluído. {total} ativos do tipo 'stock' serão analisados.")

    # Etapa 2: Coleta de Dados Detalhada
    dados_finais = {}
    print("\nIniciando coleta detalhada de dados no yfinance...")
    for i, (ticker, brapi_data) in enumerate(tickers_para_analisar.items()):
        try:
            print(f"Analisando [{i+1}/{total}]: {ticker}...")
            stock = yf.Ticker(ticker)
            info = stock.info
            
            if info.get("country") != "Brazil":
                print(f"  -> DESCARTADO: {ticker} não é do Brasil.")
                continue
            
            # Coleta dos dados, incluindo a nova coluna 'Tipo'
            dados_finais[ticker] = {
                "Empresa": info.get("longName", "N/A"),
                "Setor (brapi)": brapi_data['setor'],
                "Subsetor (yfinance)": info.get("industry", "N/A"),
                "País": info.get("country", "N/A"),
                # <<< NOVA COLUNA 'TIPO' INCLUÍDA AQUI >>>
                "Tipo": brapi_data['tipo'],
                "Market Cap": info.get("marketCap"),
                "Logo": brapi_data['logo'],
            }
            print(f"  -> ✅ INCLUÍDO: {ticker}")

        except Exception as e:
            print(f"  -> ERRO: Falha ao processar {ticker}. Erro: {e}")
            continue
                
    return dados_finais

# --- EXECUÇÃO E APRESENTAÇÃO DOS RESULTADOS ---
resultados = scanner_final_com_tipo(setores_alvo)

if resultados:
    print("\n✅ Análise finalizada.")
    df_resultado = pd.DataFrame.from_dict(resultados, orient="index")
    
    df_resultado.reset_index(inplace=True)
    df_resultado.rename(columns={'index': 'Ticker'}, inplace=True)
    
    if "Market Cap" in df_resultado.columns:
         df_resultado["Market Cap Num"] = pd.to_numeric(df_resultado["Market Cap"], errors='coerce')
         df_resultado["Market Cap"] = df_resultado["Market Cap Num"].apply(
             lambda x: f"R$ {x/1_000_000_000:.2f} Bi" if pd.notna(x) and x > 0 else "N/A"
         )

    df_ordenado = df_resultado.sort_values(by=['Setor (brapi)', 'Market Cap Num'], ascending=[True, False])
    
    # Adicionando a coluna 'Tipo' na lista de colunas finais
    colunas_finais = ['Ticker', 'Empresa', 'Setor (brapi)', 'Subsetor (yfinance)', 'País', 'Tipo', 'Market Cap', 'Logo']
    df_final = df_ordenado[colunas_finais]
    
    print("\n--- Relatório Final (Apenas Ações) ---")
    print(df_final.to_string(index=False))

    # --- SALVANDO O ARQUIVO NO CAMINHO ESPECÍFICO ---
    try:
        output_folder = r"E:\Github\finance-manager\datasets"
        output_filename = "scanner_acoes_filtrado.xlsx" # Nome atualizado
        full_path = os.path.join(output_folder, output_filename)
        
        os.makedirs(output_folder, exist_ok=True)
        
        df_final.to_excel(full_path, index=False)
        print(f"\n✅ Resultados salvos com sucesso no caminho: {full_path}")
    except Exception as e:
        print(f"\n❌ Erro ao salvar o arquivo Excel: {e}")
else:
    print("\nNenhuma empresa foi encontrada para os critérios especificados.")
# Out:
# Iniciando scanner final focado (filtrando por tipo 'stock')...
# Mapeando ativos dos setores alvo...
# ✅ Mapeamento concluído. 278 ativos do tipo 'stock' serão analisados.
#
# Iniciando coleta detalhada de dados no yfinance...
# Analisando [1/278]: BBDC4.SA...
#   -> ✅ INCLUÍDO: BBDC4.SA
# Analisando [2/278]: BBAS3.SA...
#   -> ✅ INCLUÍDO: BBAS3.SA
# Analisando [3/278]: VAMO3.SA...
#   -> ✅ INCLUÍDO: VAMO3.SA
# Analisando [4/278]: B3SA3.SA...
#   -> ✅ INCLUÍDO: B3SA3.SA
# Analisando [5/278]: ITSA4.SA...
#   -> ✅ INCLUÍDO: ITSA4.SA
# Analisando [6/278]: CSAN3.SA...
#   -> ✅ INCLUÍDO: CSAN3.SA
# Analisando [7/278]: CPLE6.SA...
#   -> ✅ INCLUÍDO: CPLE6.SA
# Analisando [8/278]: RENT3.SA...
#   -> ✅ INCLUÍDO: RENT3.SA
# Analisando [9/278]: ITUB4.SA...
#   -> ✅ INCLUÍDO: ITUB4.SA
# Analisando [10/278]: MOVI3.SA...
#   -> ✅ INCLUÍDO: MOVI3.SA
# Analisando [11/278]: CMIG4.SA...
#   -> ✅ INCLUÍDO: CMIG4.SA
# Analisando [12/278]: CPLE3.SA...
#   -> ✅ INCLUÍDO: CPLE3.SA
# Analisando [13/278]: BBDC3.SA...
#   -> ✅ INCLUÍDO: BBDC3.SA
# Analisando [14/278]: ENEV3.SA...
#   -> ✅ INCLUÍDO: ENEV3.SA
# Analisando [15/278]: BBSE3.SA...
#   -> ✅ INCLUÍDO: BBSE3.SA
# Analisando [16/278]: EQTL3.SA...
#   -> ✅ INCLUÍDO: EQTL3.SA
# Analisando [17/278]: TIMS3.SA...
#   -> ✅ INCLUÍDO: TIMS3.SA
# Analisando [18/278]: BRAP4.SA...
#   -> ✅ INCLUÍDO: BRAP4.SA
# Analisando [19/278]: SRNA3.SA...
#   -> ✅ INCLUÍDO: SRNA3.SA
# Analisando [20/278]: CXSE3.SA...
#   -> ✅ INCLUÍDO: CXSE3.SA
# Analisando [21/278]: ELET3.SA...
#   -> ✅ INCLUÍDO: ELET3.SA
# Analisando [22/278]: AZTE3.SA...
#   -> ✅ INCLUÍDO: AZTE3.SA
# Analisando [23/278]: VIVT3.SA...
#   -> ✅ INCLUÍDO: VIVT3.SA
# Analisando [24/278]: MULT3.SA...
#   -> ✅ INCLUÍDO: MULT3.SA
# Analisando [25/278]: AURE3.SA...
#   -> ✅ INCLUÍDO: AURE3.SA
# Analisando [26/278]: PSSA3.SA...
#   -> ✅ INCLUÍDO: PSSA3.SA
# Analisando [27/278]: ALOS3.SA...
#   -> ✅ INCLUÍDO: ALOS3.SA
# Analisando [28/278]: CYRE3.SA...
#   -> ✅ INCLUÍDO: CYRE3.SA
# Analisando [29/278]: SAPR4.SA...
#   -> ✅ INCLUÍDO: SAPR4.SA
# Analisando [30/278]: EGIE3.SA...
#   -> ✅ INCLUÍDO: EGIE3.SA
# Analisando [31/278]: SBSP3.SA...
#   -> ✅ INCLUÍDO: SBSP3.SA
# Analisando [32/278]: JHSF3.SA...
#   -> ✅ INCLUÍDO: JHSF3.SA
# Analisando [33/278]: PDGR3.SA...
#   -> ✅ INCLUÍDO: PDGR3.SA
# Analisando [34/278]: DIRR3.SA...
#   -> ✅ INCLUÍDO: DIRR3.SA
# Analisando [35/278]: CSMG3.SA...
#   -> ✅ INCLUÍDO: CSMG3.SA
# Analisando [36/278]: MILS3.SA...
#   -> ✅ INCLUÍDO: MILS3.SA
# Analisando [37/278]: LIGT3.SA...
#   -> ✅ INCLUÍDO: LIGT3.SA
# Analisando [38/278]: BRSR6.SA...
#   -> ✅ INCLUÍDO: BRSR6.SA
# Analisando [39/278]: ARML3.SA...
#   -> ✅ INCLUÍDO: ARML3.SA
# Analisando [40/278]: ISAE4.SA...
#   -> ✅ INCLUÍDO: ISAE4.SA
# Analisando [41/278]: CURY3.SA...
#   -> ✅ INCLUÍDO: CURY3.SA
# Analisando [42/278]: AZEV3.SA...
#   -> ✅ INCLUÍDO: AZEV3.SA
# Analisando [43/278]: BMGB4.SA...
#   -> ✅ INCLUÍDO: BMGB4.SA
# Analisando [44/278]: OIBR3.SA...
#   -> ✅ INCLUÍDO: OIBR3.SA
# Analisando [45/278]: EZTC3.SA...
#   -> ✅ INCLUÍDO: EZTC3.SA
# Analisando [46/278]: TEND3.SA...
#   -> ✅ INCLUÍDO: TEND3.SA
# Analisando [47/278]: ABCB4.SA...
#   -> ✅ INCLUÍDO: ABCB4.SA
# Analisando [48/278]: BPAN4.SA...
#   -> ✅ INCLUÍDO: BPAN4.SA
# Analisando [49/278]: AZEV4.SA...
#   -> ✅ INCLUÍDO: AZEV4.SA
# Analisando [50/278]: ELET6.SA...
#   -> ✅ INCLUÍDO: ELET6.SA
# Analisando [51/278]: IRBR3.SA...
#   -> ✅ INCLUÍDO: IRBR3.SA
# Analisando [52/278]: SYNE3.SA...
#   -> ✅ INCLUÍDO: SYNE3.SA
# Analisando [53/278]: CPFE3.SA...
#   -> ✅ INCLUÍDO: CPFE3.SA
# Analisando [54/278]: NEOE3.SA...
#   -> ✅ INCLUÍDO: NEOE3.SA
# Analisando [55/278]: LAVV3.SA...
#   -> ✅ INCLUÍDO: LAVV3.SA
# Analisando [56/278]: PLPL3.SA...
#   -> ✅ INCLUÍDO: PLPL3.SA
# Analisando [57/278]: ORVR3.SA...
#   -> ✅ INCLUÍDO: ORVR3.SA
# Analisando [58/278]: BBAS3F.SA...
#   -> DESCARTADO: BBAS3F.SA não é do Brasil.
# Analisando [59/278]: PRNR3.SA...
#   -> ✅ INCLUÍDO: PRNR3.SA
# Analisando [60/278]: ITUB3.SA...
#   -> ✅ INCLUÍDO: ITUB3.SA
# Analisando [61/278]: MDNE3.SA...
#   -> ✅ INCLUÍDO: MDNE3.SA
# Analisando [62/278]: SAPR3.SA...
#   -> ✅ INCLUÍDO: SAPR3.SA
# Analisando [63/278]: MELK3.SA...
#   -> ✅ INCLUÍDO: MELK3.SA
# Analisando [64/278]: FIQE3.SA...
#   -> ✅ INCLUÍDO: FIQE3.SA
# Analisando [65/278]: EVEN3.SA...
#   -> ✅ INCLUÍDO: EVEN3.SA
# Analisando [66/278]: MTRE3.SA...
#   -> ✅ INCLUÍDO: MTRE3.SA
# Analisando [67/278]: WIZC3.SA...
#   -> ✅ INCLUÍDO: WIZC3.SA
# Analisando [68/278]: GFSA3.SA...
#   -> ✅ INCLUÍDO: GFSA3.SA
# Analisando [69/278]: RNEW4.SA...
#   -> ✅ INCLUÍDO: RNEW4.SA
# Analisando [70/278]: PINE4.SA...
#   -> ✅ INCLUÍDO: PINE4.SA
# Analisando [71/278]: LOGG3.SA...
#   -> ✅ INCLUÍDO: LOGG3.SA
# Analisando [72/278]: BRST3.SA...
#   -> ✅ INCLUÍDO: BRST3.SA
# Analisando [73/278]: BBSE3F.SA...
#   -> DESCARTADO: BBSE3F.SA não é do Brasil.
# Analisando [74/278]: HBRE3.SA...
#   -> ✅ INCLUÍDO: HBRE3.SA
# Analisando [75/278]: RNEW3.SA...
#   -> ✅ INCLUÍDO: RNEW3.SA
# Analisando [76/278]: AGRO3.SA...
#   -> ✅ INCLUÍDO: AGRO3.SA
# Analisando [77/278]: TCSA3.SA...
#   -> ✅ INCLUÍDO: TCSA3.SA
# Analisando [78/278]: TAEE4.SA...
#   -> ✅ INCLUÍDO: TAEE4.SA
# Analisando [79/278]: CMIG4F.SA...
#   -> DESCARTADO: CMIG4F.SA não é do Brasil.
# Analisando [80/278]: CXSE3F.SA...
#   -> DESCARTADO: CXSE3F.SA não é do Brasil.
# Analisando [81/278]: ITSA3.SA...
#   -> ✅ INCLUÍDO: ITSA3.SA
# Analisando [82/278]: DESK3.SA...
#   -> ✅ INCLUÍDO: DESK3.SA
# Analisando [83/278]: SANB3.SA...
#   -> ✅ INCLUÍDO: SANB3.SA
# Analisando [84/278]: CMIG3.SA...
#   -> ✅ INCLUÍDO: CMIG3.SA
# Analisando [85/278]: ITSA4F.SA...
#   -> DESCARTADO: ITSA4F.SA não é do Brasil.
# Analisando [86/278]: CSAN3F.SA...
#   -> DESCARTADO: CSAN3F.SA não é do Brasil.
# Analisando [87/278]: ISAE4F.SA...
#   -> DESCARTADO: ISAE4F.SA não é do Brasil.
# Analisando [88/278]: SANB4.SA...
#   -> ✅ INCLUÍDO: SANB4.SA
# Analisando [89/278]: VAMO3F.SA...
#   -> DESCARTADO: VAMO3F.SA não é do Brasil.
# Analisando [90/278]: SAPR4F.SA...
#   -> DESCARTADO: SAPR4F.SA não é do Brasil.
# Analisando [91/278]: EGIE3F.SA...
#   -> DESCARTADO: EGIE3F.SA não é do Brasil.
# Analisando [92/278]: BRAP3.SA...
#   -> ✅ INCLUÍDO: BRAP3.SA
# Analisando [93/278]: BBDC4F.SA...
#   -> DESCARTADO: BBDC4F.SA não é do Brasil.
# Analisando [94/278]: ITUB4F.SA...
#   -> DESCARTADO: ITUB4F.SA não é do Brasil.
# Analisando [95/278]: TAEE3.SA...
#   -> ✅ INCLUÍDO: TAEE3.SA
# Analisando [96/278]: CPLE6F.SA...
#   -> DESCARTADO: CPLE6F.SA não é do Brasil.
# Analisando [97/278]: B3SA3F.SA...
#   -> DESCARTADO: B3SA3F.SA não é do Brasil.
# Analisando [98/278]: OIBR4.SA...
#   -> ✅ INCLUÍDO: OIBR4.SA
# Analisando [99/278]: LAND3.SA...
#   -> ✅ INCLUÍDO: LAND3.SA
# Analisando [100/278]: BMGB4F.SA...
#   -> DESCARTADO: BMGB4F.SA não é do Brasil.
# Analisando [101/278]: CSMG3F.SA...
#   -> DESCARTADO: CSMG3F.SA não é do Brasil.
# Analisando [102/278]: BBDC3F.SA...
#   -> DESCARTADO: BBDC3F.SA não é do Brasil.
# Analisando [103/278]: BRAP4F.SA...
#   -> DESCARTADO: BRAP4F.SA não é do Brasil.
# Analisando [104/278]: DIRR3F.SA...
#   -> DESCARTADO: DIRR3F.SA não é do Brasil.
# Analisando [105/278]: RENT3F.SA...
#   -> DESCARTADO: RENT3F.SA não é do Brasil.
# Analisando [106/278]: VIVT3F.SA...
#   -> DESCARTADO: VIVT3F.SA não é do Brasil.
# Analisando [107/278]: SCAR3.SA...
#   -> ✅ INCLUÍDO: SCAR3.SA
# Analisando [108/278]: TAEE4F.SA...
#   -> DESCARTADO: TAEE4F.SA não é do Brasil.
# Analisando [109/278]: AURE3F.SA...
#   -> DESCARTADO: AURE3F.SA não é do Brasil.
# Analisando [110/278]: ABCB4F.SA...
#   -> DESCARTADO: ABCB4F.SA não é do Brasil.
# Analisando [111/278]: CEBR6.SA...
#   -> ✅ INCLUÍDO: CEBR6.SA
# Analisando [112/278]: BMEB4.SA...
#   -> ✅ INCLUÍDO: BMEB4.SA
# Analisando [113/278]: ELET3F.SA...
#   -> DESCARTADO: ELET3F.SA não é do Brasil.
# Analisando [114/278]: MOVI3F.SA...
#   -> DESCARTADO: MOVI3F.SA não é do Brasil.
# Analisando [115/278]: ITUB3F.SA...
#   -> DESCARTADO: ITUB3F.SA não é do Brasil.
# Analisando [116/278]: SYNE3F.SA...
#   -> DESCARTADO: SYNE3F.SA não é do Brasil.
# Analisando [117/278]: PSSA3F.SA...
#   -> DESCARTADO: PSSA3F.SA não é do Brasil.
# Analisando [118/278]: JHSF3F.SA...
#   -> DESCARTADO: JHSF3F.SA não é do Brasil.
# Analisando [119/278]: TIMS3F.SA...
#   -> DESCARTADO: TIMS3F.SA não é do Brasil.
# Analisando [120/278]: SAPR3F.SA...
#   -> DESCARTADO: SAPR3F.SA não é do Brasil.
# Analisando [121/278]: CPFE3F.SA...
#   -> DESCARTADO: CPFE3F.SA não é do Brasil.
# Analisando [122/278]: FIQE3F.SA...
#   -> DESCARTADO: FIQE3F.SA não é do Brasil.
# Analisando [123/278]: BRSR6F.SA...
#   -> DESCARTADO: BRSR6F.SA não é do Brasil.
# Analisando [124/278]: SBSP3F.SA...
#   -> DESCARTADO: SBSP3F.SA não é do Brasil.
# Analisando [125/278]: ITSA3F.SA...
#   -> DESCARTADO: ITSA3F.SA não é do Brasil.
# Analisando [126/278]: AGRO3F.SA...
#   -> DESCARTADO: AGRO3F.SA não é do Brasil.
# Analisando [127/278]: IRBR3F.SA...
#   -> DESCARTADO: IRBR3F.SA não é do Brasil.
# Analisando [128/278]: EQTL3F.SA...
#   -> DESCARTADO: EQTL3F.SA não é do Brasil.
# Analisando [129/278]: CMIG3F.SA...
#   -> DESCARTADO: CMIG3F.SA não é do Brasil.
# Analisando [130/278]: RDNI3.SA...
#   -> ✅ INCLUÍDO: RDNI3.SA
# Analisando [131/278]: CURY3F.SA...
#   -> DESCARTADO: CURY3F.SA não é do Brasil.
# Analisando [132/278]: CYRE3F.SA...
#   -> DESCARTADO: CYRE3F.SA não é do Brasil.
# Analisando [133/278]: MTRE3F.SA...
#   -> DESCARTADO: MTRE3F.SA não é do Brasil.
# Analisando [134/278]: WIZC3F.SA...
#   -> DESCARTADO: WIZC3F.SA não é do Brasil.
# Analisando [135/278]: TAEE3F.SA...
#   -> DESCARTADO: TAEE3F.SA não é do Brasil.
# Analisando [136/278]: CEBR3.SA...
#   -> ✅ INCLUÍDO: CEBR3.SA
# Analisando [137/278]: MELK3F.SA...
#   -> DESCARTADO: MELK3F.SA não é do Brasil.
# Analisando [138/278]: CPLE3F.SA...
#   -> DESCARTADO: CPLE3F.SA não é do Brasil.
# Analisando [139/278]: OIBR3F.SA...
#   -> DESCARTADO: OIBR3F.SA não é do Brasil.
# Analisando [140/278]: IGTI3.SA...
#   -> ✅ INCLUÍDO: IGTI3.SA
# Analisando [141/278]: ELET6F.SA...
#   -> DESCARTADO: ELET6F.SA não é do Brasil.
# Analisando [142/278]: EZTC3F.SA...
#   -> DESCARTADO: EZTC3F.SA não é do Brasil.
# Analisando [143/278]: GFSA3F.SA...
#   -> DESCARTADO: GFSA3F.SA não é do Brasil.
# Analisando [144/278]: MULT3F.SA...
#   -> DESCARTADO: MULT3F.SA não é do Brasil.
# Analisando [145/278]: AZTE3F.SA...
#   -> DESCARTADO: AZTE3F.SA não é do Brasil.
# Analisando [146/278]: ENEV3F.SA...
#   -> DESCARTADO: ENEV3F.SA não é do Brasil.
# Analisando [147/278]: ALOS3F.SA...
#   -> DESCARTADO: ALOS3F.SA não é do Brasil.
# Analisando [148/278]: ARML3F.SA...
#   -> DESCARTADO: ARML3F.SA não é do Brasil.
# Analisando [149/278]: OIBR4F.SA...
#   -> DESCARTADO: OIBR4F.SA não é do Brasil.
# Analisando [150/278]: BEES3.SA...
#   -> ✅ INCLUÍDO: BEES3.SA
# Analisando [151/278]: ALUP3.SA...
#   -> ✅ INCLUÍDO: ALUP3.SA
# Analisando [152/278]: INEP4.SA...
#   -> ✅ INCLUÍDO: INEP4.SA
# Analisando [153/278]: BPAC3.SA...
#   -> ✅ INCLUÍDO: BPAC3.SA
# Analisando [154/278]: NEOE3F.SA...
#   -> DESCARTADO: NEOE3F.SA não é do Brasil.
# Analisando [155/278]: MDNE3F.SA...
#   -> DESCARTADO: MDNE3F.SA não é do Brasil.
# Analisando [156/278]: ALUP4.SA...
#   -> ✅ INCLUÍDO: ALUP4.SA
# Analisando [157/278]: ENGI4.SA...
#   -> ✅ INCLUÍDO: ENGI4.SA
# Analisando [158/278]: SANB3F.SA...
#   -> DESCARTADO: SANB3F.SA não é do Brasil.
# Analisando [159/278]: PLPL3F.SA...
#   -> DESCARTADO: PLPL3F.SA não é do Brasil.
# Analisando [160/278]: SANB4F.SA...
#   -> DESCARTADO: SANB4F.SA não é do Brasil.
# Analisando [161/278]: BAZA3.SA...
#   -> ✅ INCLUÍDO: BAZA3.SA
# Analisando [162/278]: LAVV3F.SA...
#   -> DESCARTADO: LAVV3F.SA não é do Brasil.
# Analisando [163/278]: BPAN4F.SA...
#   -> DESCARTADO: BPAN4F.SA não é do Brasil.
# Analisando [164/278]: ORVR3F.SA...
#   -> DESCARTADO: ORVR3F.SA não é do Brasil.
# Analisando [165/278]: INEP3.SA...
#   -> ✅ INCLUÍDO: INEP3.SA
# Analisando [166/278]: TEND3F.SA...
#   -> DESCARTADO: TEND3F.SA não é do Brasil.
# Analisando [167/278]: EVEN3F.SA...
#   -> DESCARTADO: EVEN3F.SA não é do Brasil.
# Analisando [168/278]: AZEV4F.SA...
#   -> DESCARTADO: AZEV4F.SA não é do Brasil.
# Analisando [169/278]: LIGT3F.SA...
#   -> DESCARTADO: LIGT3F.SA não é do Brasil.
# Analisando [170/278]: BRSR3.SA...
#   -> ✅ INCLUÍDO: BRSR3.SA
# Analisando [171/278]: BRAP3F.SA...
#   -> DESCARTADO: BRAP3F.SA não é do Brasil.
# Analisando [172/278]: OSXB3.SA...
#   -> ✅ INCLUÍDO: OSXB3.SA
# Analisando [173/278]: PDGR3F.SA...
#   -> DESCARTADO: PDGR3F.SA não é do Brasil.
# Analisando [174/278]: AVLL3.SA...
#   -> ✅ INCLUÍDO: AVLL3.SA
# Analisando [175/278]: BEES3F.SA...
#   -> DESCARTADO: BEES3F.SA não é do Brasil.
# Analisando [176/278]: RNEW4F.SA...
#   -> DESCARTADO: RNEW4F.SA não é do Brasil.
# Analisando [177/278]: COCE5.SA...
#   -> ✅ INCLUÍDO: COCE5.SA
# Analisando [178/278]: BGIP4.SA...
#   -> ✅ INCLUÍDO: BGIP4.SA
# Analisando [179/278]: PINE4F.SA...
#   -> DESCARTADO: PINE4F.SA não é do Brasil.
# Analisando [180/278]: ALUP4F.SA...
#   -> DESCARTADO: ALUP4F.SA não é do Brasil.
# Analisando [181/278]: AZEV3F.SA...
#   -> DESCARTADO: AZEV3F.SA não é do Brasil.
# Analisando [182/278]: ISAE3.SA...
#   -> ✅ INCLUÍDO: ISAE3.SA
# Analisando [183/278]: EQPA3.SA...
#   -> ✅ INCLUÍDO: EQPA3.SA
# Analisando [184/278]: EMAE4.SA...
#   -> ✅ INCLUÍDO: EMAE4.SA
# Analisando [185/278]: MILS3F.SA...
#   -> DESCARTADO: MILS3F.SA não é do Brasil.
# Analisando [186/278]: LOGG3F.SA...
#   -> DESCARTADO: LOGG3F.SA não é do Brasil.
# Analisando [187/278]: IGTI3F.SA...
#   -> DESCARTADO: IGTI3F.SA não é do Brasil.
# Analisando [188/278]: SRNA3F.SA...
#   -> DESCARTADO: SRNA3F.SA não é do Brasil.
# Analisando [189/278]: TELB3.SA...
#   -> ✅ INCLUÍDO: TELB3.SA
# Analisando [190/278]: BSLI3.SA...
#   -> ✅ INCLUÍDO: BSLI3.SA
# Analisando [191/278]: BEES4F.SA...
#   -> DESCARTADO: BEES4F.SA não é do Brasil.
# Analisando [192/278]: PRNR3F.SA...
#   -> DESCARTADO: PRNR3F.SA não é do Brasil.
# Analisando [193/278]: ISAE3F.SA...
#   -> DESCARTADO: ISAE3F.SA não é do Brasil.
# Analisando [194/278]: BRSR3F.SA...
#   -> DESCARTADO: BRSR3F.SA não é do Brasil.
# Analisando [195/278]: GEPA4.SA...
#   -> ✅ INCLUÍDO: GEPA4.SA
# Analisando [196/278]: BPAC5.SA...
#   -> ✅ INCLUÍDO: BPAC5.SA
# Analisando [197/278]: TCSA3F.SA...
#   -> DESCARTADO: TCSA3F.SA não é do Brasil.
# Analisando [198/278]: BRST3F.SA...
#   -> DESCARTADO: BRST3F.SA não é do Brasil.
# Analisando [199/278]: BPAC3F.SA...
#   -> DESCARTADO: BPAC3F.SA não é do Brasil.
# Analisando [200/278]: BEES4.SA...
#   -> ✅ INCLUÍDO: BEES4.SA
# Analisando [201/278]: ENGI3.SA...
#   -> ✅ INCLUÍDO: ENGI3.SA
# Analisando [202/278]: DESK3F.SA...
#   -> DESCARTADO: DESK3F.SA não é do Brasil.
# Analisando [203/278]: BMEB4F.SA...
#   -> DESCARTADO: BMEB4F.SA não é do Brasil.
# Analisando [204/278]: RNEW3F.SA...
#   -> DESCARTADO: RNEW3F.SA não é do Brasil.
# Analisando [205/278]: BAZA3F.SA...
#   -> DESCARTADO: BAZA3F.SA não é do Brasil.
# Analisando [206/278]: ENGI3F.SA...
#   -> DESCARTADO: ENGI3F.SA não é do Brasil.
# Analisando [207/278]: CEBR5.SA...
#   -> ✅ INCLUÍDO: CEBR5.SA
# Analisando [208/278]: CLSC4.SA...
#   -> ✅ INCLUÍDO: CLSC4.SA
# Analisando [209/278]: PINE3.SA...
#   -> ✅ INCLUÍDO: PINE3.SA
# Analisando [210/278]: TELB4.SA...
#   -> ✅ INCLUÍDO: TELB4.SA
# Analisando [211/278]: ENGI4F.SA...
#   -> DESCARTADO: ENGI4F.SA não é do Brasil.
# Analisando [212/278]: CEBR6F.SA...
#   -> DESCARTADO: CEBR6F.SA não é do Brasil.
# Analisando [213/278]: CEBR3F.SA...
#   -> DESCARTADO: CEBR3F.SA não é do Brasil.
# Analisando [214/278]: COCE5F.SA...
#   -> DESCARTADO: COCE5F.SA não é do Brasil.
# Analisando [215/278]: REDE3.SA...
#   -> ✅ INCLUÍDO: REDE3.SA
# Analisando [216/278]: BNBR3.SA...
#   -> ✅ INCLUÍDO: BNBR3.SA
# Analisando [217/278]: EQPA3F.SA...
#   -> DESCARTADO: EQPA3F.SA não é do Brasil.
# Analisando [218/278]: LAND3F.SA...
#   -> DESCARTADO: LAND3F.SA não é do Brasil.
# Analisando [219/278]: SCAR3F.SA...
#   -> DESCARTADO: SCAR3F.SA não é do Brasil.
# Analisando [220/278]: REDE3F.SA...
#   -> DESCARTADO: REDE3F.SA não é do Brasil.
# Analisando [221/278]: ALUP3F.SA...
#   -> DESCARTADO: ALUP3F.SA não é do Brasil.
# Analisando [222/278]: BSLI4.SA...
#   -> ✅ INCLUÍDO: BSLI4.SA
# Analisando [223/278]: HBTS5.SA...
#   -> ✅ INCLUÍDO: HBTS5.SA
# Analisando [224/278]: ENMT3.SA...
#   -> ✅ INCLUÍDO: ENMT3.SA
# Analisando [225/278]: ADMF3.SA...
#   -> ✅ INCLUÍDO: ADMF3.SA
# Analisando [226/278]: EKTR4.SA...
#   -> ✅ INCLUÍDO: EKTR4.SA
# Analisando [227/278]: HBRE3F.SA...
#   -> DESCARTADO: HBRE3F.SA não é do Brasil.
# Analisando [228/278]: BGIP4F.SA...
#   -> DESCARTADO: BGIP4F.SA não é do Brasil.
# Analisando [229/278]: DTCY3.SA...
#   -> ✅ INCLUÍDO: DTCY3.SA
# Analisando [230/278]: CEEB3.SA...
#   -> ✅ INCLUÍDO: CEEB3.SA
# Analisando [231/278]: EMAE4F.SA...
#   -> DESCARTADO: EMAE4F.SA não é do Brasil.
# Analisando [232/278]: BSLI3F.SA...
#   -> DESCARTADO: BSLI3F.SA não é do Brasil.
# Analisando [233/278]: INEP4F.SA...
#   -> DESCARTADO: INEP4F.SA não é do Brasil.
# Analisando [234/278]: MOAR3F.SA...
#   -> DESCARTADO: MOAR3F.SA não é do Brasil.
# Analisando [235/278]: GEPA4F.SA...
#   -> DESCARTADO: GEPA4F.SA não é do Brasil.
# Analisando [236/278]: OSXB3F.SA...
#   -> DESCARTADO: OSXB3F.SA não é do Brasil.
# Analisando [237/278]: CGAS5F.SA...
#   -> DESCARTADO: CGAS5F.SA não é do Brasil.
# Analisando [238/278]: BRSR5F.SA...
#   -> DESCARTADO: BRSR5F.SA não é do Brasil.
# Analisando [239/278]: EKTR4F.SA...
#   -> DESCARTADO: EKTR4F.SA não é do Brasil.
# Analisando [240/278]: AVLL3F.SA...
#   -> DESCARTADO: AVLL3F.SA não é do Brasil.
# Analisando [241/278]: BPAC5F.SA...
#   -> DESCARTADO: BPAC5F.SA não é do Brasil.
# Analisando [242/278]: BMEB3.SA...
#   -> ✅ INCLUÍDO: BMEB3.SA
# Analisando [243/278]: RDNI3F.SA...
#   -> DESCARTADO: RDNI3F.SA não é do Brasil.
# Analisando [244/278]: NEXP3.SA...
#   -> ✅ INCLUÍDO: NEXP3.SA
# Analisando [245/278]: RPAD6.SA...
#   -> ✅ INCLUÍDO: RPAD6.SA
# Analisando [246/278]: AFLT3.SA...
#   -> ✅ INCLUÍDO: AFLT3.SA
# Analisando [247/278]: BRSR5.SA...
#   -> ✅ INCLUÍDO: BRSR5.SA
# Analisando [248/278]: CLSC4F.SA...
#   -> DESCARTADO: CLSC4F.SA não é do Brasil.
# Analisando [249/278]: CGAS3F.SA...
#   -> DESCARTADO: CGAS3F.SA não é do Brasil.
# Analisando [250/278]: ENMT3F.SA...
#   -> DESCARTADO: ENMT3F.SA não é do Brasil.
# Analisando [251/278]: INEP3F.SA...
#   -> DESCARTADO: INEP3F.SA não é do Brasil.
# Analisando [252/278]: TELB3F.SA...
#   -> DESCARTADO: TELB3F.SA não é do Brasil.
# Analisando [253/278]: BNBR3F.SA...
#   -> DESCARTADO: BNBR3F.SA não é do Brasil.
# Analisando [254/278]: TELB4F.SA...
#   -> DESCARTADO: TELB4F.SA não é do Brasil.
# Analisando [255/278]: DTCY3F.SA...
#   -> DESCARTADO: DTCY3F.SA não é do Brasil.
# Analisando [256/278]: CLSC3F.SA...
#   -> DESCARTADO: CLSC3F.SA não é do Brasil.
# Analisando [257/278]: GSHP3F.SA...
#   -> DESCARTADO: GSHP3F.SA não é do Brasil.
# Analisando [258/278]: PINE3F.SA...
#   -> DESCARTADO: PINE3F.SA não é do Brasil.
# Analisando [259/278]: CPLE5F.SA...
#   -> DESCARTADO: CPLE5F.SA não é do Brasil.
# Analisando [260/278]: BSLI4F.SA...
#   -> DESCARTADO: BSLI4F.SA não é do Brasil.
# Analisando [261/278]: GEPA3F.SA...
#   -> DESCARTADO: GEPA3F.SA não é do Brasil.
# Analisando [262/278]: CEEB3F.SA...
#   -> DESCARTADO: CEEB3F.SA não é do Brasil.
# Analisando [263/278]: AFLT3F.SA...
#   -> DESCARTADO: AFLT3F.SA não é do Brasil.
# Analisando [264/278]: BMEB3F.SA...
#   -> DESCARTADO: BMEB3F.SA não é do Brasil.
# Analisando [265/278]: CEBR5F.SA...
#   -> DESCARTADO: CEBR5F.SA não é do Brasil.
# Analisando [266/278]: BMIN3F.SA...
#   -> DESCARTADO: BMIN3F.SA não é do Brasil.
# Analisando [267/278]: ADMF3F.SA...
#   -> DESCARTADO: ADMF3F.SA não é do Brasil.
# Analisando [268/278]: BMIN4F.SA...
#   -> DESCARTADO: BMIN4F.SA não é do Brasil.
# Analisando [269/278]: NEXP3F.SA...
#   -> DESCARTADO: NEXP3F.SA não é do Brasil.
# Analisando [270/278]: BGIP3F.SA...
#   -> DESCARTADO: BGIP3F.SA não é do Brasil.
# Analisando [271/278]: HBTS5F.SA...
#   -> DESCARTADO: HBTS5F.SA não é do Brasil.
# Analisando [272/278]: CBEE3F.SA...
#   -> DESCARTADO: CBEE3F.SA não é do Brasil.
# Analisando [273/278]: PEAB3F.SA...
#   -> DESCARTADO: PEAB3F.SA não é do Brasil.
# Analisando [274/278]: EQMA3BF.SA...
#   -> DESCARTADO: EQMA3BF.SA não é do Brasil.
# Analisando [275/278]: SOND6F.SA...
#   -> DESCARTADO: SOND6F.SA não é do Brasil.
# Analisando [276/278]: CEED4F.SA...
#   -> DESCARTADO: CEED4F.SA não é do Brasil.
# Analisando [277/278]: ELET5F.SA...
#   -> DESCARTADO: ELET5F.SA não é do Brasil.
# Analisando [278/278]: EKTR3F.SA...
#   -> DESCARTADO: EKTR3F.SA não é do Brasil.
#
# ✅ Análise finalizada.
#
# --- Relatório Final (Apenas Ações) ---
#   Ticker                                                        Empresa       Setor (brapi)                     Subsetor (yfinance)   País  Tipo   Market Cap                                    Logo
# VIVT3.SA                                         Telefônica Brasil S.A.      Communications                        Telecom Services Brazil stock  R$ 98.50 Bi https://icons.brapi.dev/icons/VIVT3.svg
# TIMS3.SA                                                       TIM S.A.      Communications                        Telecom Services Brazil stock  R$ 51.57 Bi https://icons.brapi.dev/icons/TIMS3.svg
# FIQE3.SA                                 Unifique Telecomunicações S.A.      Communications                        Telecom Services Brazil stock   R$ 1.34 Bi https://icons.brapi.dev/icons/FIQE3.svg
# BRST3.SA                                                            N/A      Communications                        Telecom Services Brazil stock   R$ 1.28 Bi https://icons.brapi.dev/icons/BRST3.svg
# TELB3.SA                   Telecomunicações Brasileiras S.A. - Telebras      Communications                        Telecom Services Brazil stock   R$ 1.14 Bi https://icons.brapi.dev/icons/TELB3.svg
# TELB4.SA                   Telecomunicações Brasileiras S.A. - Telebras      Communications                        Telecom Services Brazil stock   R$ 1.14 Bi https://icons.brapi.dev/icons/TELB4.svg
# DESK3.SA                                                   Desktop S.A.      Communications                        Telecom Services Brazil stock   R$ 1.10 Bi https://icons.brapi.dev/icons/DESK3.svg
# OIBR3.SA                                                        Oi S.A.      Communications                        Telecom Services Brazil stock   R$ 0.22 Bi https://icons.brapi.dev/icons/OIBR3.svg
# OIBR4.SA                                                        Oi S.A.      Communications                        Telecom Services Brazil stock   R$ 0.22 Bi https://icons.brapi.dev/icons/OIBR4.svg
# DTCY3.SA                                 DTCOM - Direct to Company S.A.      Communications                        Telecom Services Brazil stock   R$ 0.03 Bi https://icons.brapi.dev/icons/BRAPI.svg
# ITUB4.SA                                     Itaú Unibanco Holding S.A.             Finance                        Banks - Regional Brazil stock R$ 369.26 Bi https://icons.brapi.dev/icons/ITUB4.svg
# ITUB3.SA                                     Itaú Unibanco Holding S.A.             Finance                        Banks - Regional Brazil stock R$ 369.26 Bi https://icons.brapi.dev/icons/ITUB3.svg
# BPAC3.SA                                         Banco BTG Pactual S.A.             Finance                         Capital Markets Brazil stock R$ 220.72 Bi https://icons.brapi.dev/icons/BPAC3.svg
# BPAC5.SA                                         Banco BTG Pactual S.A.             Finance                         Capital Markets Brazil stock R$ 220.72 Bi https://icons.brapi.dev/icons/BPAC5.svg
# BBDC4.SA                                            Banco Bradesco S.A.             Finance                        Banks - Regional Brazil stock R$ 163.13 Bi https://icons.brapi.dev/icons/BBDC4.svg
# BBDC3.SA                                            Banco Bradesco S.A.             Finance                        Banks - Regional Brazil stock R$ 163.13 Bi https://icons.brapi.dev/icons/BBDC3.svg
# BBAS3.SA                                           Banco do Brasil S.A.             Finance                        Banks - Regional Brazil stock R$ 124.04 Bi https://icons.brapi.dev/icons/BBAS3.svg
# ITSA4.SA                                                    Itaúsa S.A.             Finance                           Conglomerates Brazil stock R$ 118.06 Bi https://icons.brapi.dev/icons/ITSA4.svg
# ITSA3.SA                                                    Itaúsa S.A.             Finance                           Conglomerates Brazil stock R$ 118.06 Bi https://icons.brapi.dev/icons/ITSA3.svg
# SANB4.SA                                  Banco Santander (Brasil) S.A.             Finance                        Banks - Regional Brazil stock R$ 108.71 Bi https://icons.brapi.dev/icons/SANB4.svg
# SANB3.SA                                  Banco Santander (Brasil) S.A.             Finance                        Banks - Regional Brazil stock R$ 108.71 Bi https://icons.brapi.dev/icons/SANB3.svg
# B3SA3.SA                                B3 S.A. - Brasil, Bolsa, Balcão             Finance        Financial Data & Stock Exchanges Brazil stock  R$ 73.52 Bi https://icons.brapi.dev/icons/B3SA3.svg
# BBSE3.SA                               BB Seguridade Participações S.A.             Finance                 Insurance - Diversified Brazil stock  R$ 68.39 Bi https://icons.brapi.dev/icons/BBSE3.svg
# CXSE3.SA                            Caixa Seguridade Participações S.A.             Finance                 Insurance - Diversified Brazil stock  R$ 43.14 Bi https://icons.brapi.dev/icons/CXSE3.svg
# RENT3.SA                                       Localiza Rent a Car S.A.             Finance               Rental & Leasing Services Brazil stock  R$ 42.76 Bi https://icons.brapi.dev/icons/RENT3.svg
# PSSA3.SA                                              Porto Seguro S.A.             Finance                 Insurance - Diversified Brazil stock  R$ 34.78 Bi https://icons.brapi.dev/icons/PSSA3.svg
# MULT3.SA                    Multiplan Empreendimentos Imobiliários S.A.             Finance                    Real Estate Services Brazil stock  R$ 13.21 Bi https://icons.brapi.dev/icons/MULT3.svg
# ALOS3.SA                                                     Allos S.A.             Finance                    Real Estate Services Brazil stock  R$ 11.29 Bi https://icons.brapi.dev/icons/ALOS3.svg
# MELK3.SA                       Melnick Desenvolvimento Imobiliário S.A. Industrial Services                    Real Estate Services Brazil stock   R$ 0.67 Bi https://icons.brapi.dev/icons/MELK3.svg
# AZEV4.SA                                       Azevedo & Travassos S.A. Industrial Services              Engineering & Construction Brazil stock   R$ 0.32 Bi https://icons.brapi.dev/icons/AZEV4.svg
# AZEV3.SA                                       Azevedo & Travassos S.A. Industrial Services              Engineering & Construction Brazil stock   R$ 0.32 Bi https://icons.brapi.dev/icons/AZEV3.svg
# AZTE3.SA                               Azevedo & Travassos Energia S.A. Industrial Services                           Oil & Gas E&P Brazil stock   R$ 0.10 Bi https://icons.brapi.dev/icons/AZTE3.svg
# INEP3.SA                            Inepar S.A. Indústria e Construções Industrial Services          Specialty Industrial Machinery Brazil stock   R$ 0.09 Bi https://icons.brapi.dev/icons/INEP3.svg
# INEP4.SA                            Inepar S.A. Indústria e Construções Industrial Services          Specialty Industrial Machinery Brazil stock   R$ 0.09 Bi https://icons.brapi.dev/icons/INEP4.svg
# OSXB3.SA                                                OSX Brasil S.A. Industrial Services          Oil & Gas Equipment & Services Brazil stock   R$ 0.01 Bi https://icons.brapi.dev/icons/OSXB3.svg
# ELET3.SA               Centrais Elétricas Brasileiras S.A. - Eletrobrás           Utilities                   Utilities - Renewable Brazil stock  R$ 90.39 Bi https://icons.brapi.dev/icons/ELET3.svg
# ELET6.SA               Centrais Elétricas Brasileiras S.A. - Eletrobrás           Utilities                   Utilities - Renewable Brazil stock  R$ 90.39 Bi https://icons.brapi.dev/icons/ELET6.svg
# SBSP3.SA Companhia de Saneamento Básico do Estado de São Paulo - SABESP           Utilities             Utilities - Regulated Water Brazil stock  R$ 78.64 Bi https://icons.brapi.dev/icons/SBSP3.svg
# CPFE3.SA                                              CPFL Energia S.A.           Utilities          Utilities - Regulated Electric Brazil stock  R$ 46.47 Bi https://icons.brapi.dev/icons/CPFE3.svg
# EQTL3.SA                                                Equatorial S.A.           Utilities          Utilities - Regulated Electric Brazil stock  R$ 44.16 Bi https://icons.brapi.dev/icons/EQTL3.svg
# EGIE3.SA                                      Engie Brasil Energia S.A.           Utilities                   Utilities - Renewable Brazil stock  R$ 36.74 Bi https://icons.brapi.dev/icons/EGIE3.svg
# CPLE3.SA                        Companhia Paranaense de Energia - COPEL           Utilities          Utilities - Regulated Electric Brazil stock  R$ 35.30 Bi https://icons.brapi.dev/icons/CPLE3.svg
# CPLE6.SA                        Companhia Paranaense de Energia - COPEL           Utilities          Utilities - Regulated Electric Brazil stock  R$ 35.30 Bi https://icons.brapi.dev/icons/CPLE6.svg
# CMIG3.SA                   Companhia Energética de Minas Gerais - CEMIG           Utilities                 Utilities - Diversified Brazil stock  R$ 34.51 Bi https://icons.brapi.dev/icons/CMIG3.svg
# CMIG4.SA                   Companhia Energética de Minas Gerais - CEMIG           Utilities                 Utilities - Diversified Brazil stock  R$ 34.51 Bi https://icons.brapi.dev/icons/CMIG4.svg
# NEOE3.SA                                                Neoenergia S.A.           Utilities          Utilities - Regulated Electric Brazil stock  R$ 30.24 Bi https://icons.brapi.dev/icons/NEOE3.svg
# ENEV3.SA                                                     Eneva S.A.           Utilities                 Utilities - Diversified Brazil stock  R$ 25.82 Bi https://icons.brapi.dev/icons/ENEV3.svg
# ENGI4.SA                                                  Energisa S.A.           Utilities          Utilities - Regulated Electric Brazil stock  R$ 23.03 Bi https://icons.brapi.dev/icons/ENGI4.svg
# ENGI3.SA                                                  Energisa S.A.           Utilities          Utilities - Regulated Electric Brazil stock  R$ 23.03 Bi https://icons.brapi.dev/icons/ENGI3.svg
# ISAE3.SA                                        ISA Energía Brasil S.A.           Utilities Utilities - Independent Power Producers Brazil stock  R$ 16.94 Bi https://icons.brapi.dev/icons/ISAE3.svg
# ISAE4.SA                                        ISA Energía Brasil S.A.           Utilities Utilities - Independent Power Producers Brazil stock  R$ 16.94 Bi https://icons.brapi.dev/icons/ISAE4.svg
# ENMT3.SA            Energisa Mato Grosso - Distribuidora de Energia S/A           Utilities          Utilities - Regulated Electric Brazil stock  R$ 16.15 Bi https://icons.brapi.dev/icons/BRAPI.svg
# REDE3.SA                                Rede Energia Participações S.A.           Utilities          Utilities - Regulated Electric Brazil stock  R$ 13.99 Bi https://icons.brapi.dev/icons/BRAPI.svg
# CSAN3.SA                                                     Cosan S.A.           Utilities          Oil & Gas Refining & Marketing Brazil stock  R$ 12.53 Bi https://icons.brapi.dev/icons/CSAN3.svg
# EQPA3.SA                  Equatorial Pará Distribuidora de Energia S.A.           Utilities          Utilities - Regulated Electric Brazil stock  R$ 12.53 Bi https://icons.brapi.dev/icons/EQPA3.svg
# SAPR3.SA                    Companhia de Saneamento do Paraná - SANEPAR           Utilities             Utilities - Regulated Water Brazil stock  R$ 11.43 Bi https://icons.brapi.dev/icons/SAPR3.svg
# SAPR4.SA                    Companhia de Saneamento do Paraná - SANEPAR           Utilities             Utilities - Regulated Water Brazil stock  R$ 11.43 Bi https://icons.brapi.dev/icons/SAPR4.svg
# AURE3.SA                                             Auren Energia S.A.           Utilities                   Utilities - Renewable Brazil stock  R$ 10.43 Bi https://icons.brapi.dev/icons/AURE3.svg
# ALUP3.SA                                       Alupar Investimento S.A.           Utilities                   Utilities - Renewable Brazil stock  R$ 10.40 Bi https://icons.brapi.dev/icons/ALUP3.svg
# ALUP4.SA                                       Alupar Investimento S.A.           Utilities                   Utilities - Renewable Brazil stock  R$ 10.40 Bi https://icons.brapi.dev/icons/ALUP4.svg
# CSMG3.SA                        Companhia de Saneamento de Minas Gerais           Utilities             Utilities - Regulated Water Brazil stock  R$ 10.39 Bi https://icons.brapi.dev/icons/CSMG3.svg
# CEEB3.SA          Companhia de Eletricidade do Estado da Bahia - COELBA           Utilities          Utilities - Regulated Electric Brazil stock   R$ 9.85 Bi https://icons.brapi.dev/icons/BRAPI.svg
# EKTR4.SA                                             Elektro Redes S.A.           Utilities          Utilities - Regulated Electric Brazil stock   R$ 8.01 Bi https://icons.brapi.dev/icons/BRAPI.svg
# SRNA3.SA                                            Serena Energia S.A.           Utilities                   Utilities - Renewable Brazil stock   R$ 7.25 Bi https://icons.brapi.dev/icons/SRNA3.svg
# ORVR3.SA                            Orizon Valorização de Resíduos S.A.           Utilities                        Waste Management Brazil stock   R$ 5.14 Bi https://icons.brapi.dev/icons/ORVR3.svg
# CLSC4.SA                      Centrais Elétricas de Santa Catarina S.A.           Utilities          Utilities - Regulated Electric Brazil stock   R$ 3.76 Bi https://icons.brapi.dev/icons/CLSC4.svg
# LIGT3.SA                                                     Light S.A.           Utilities                   Utilities - Renewable Brazil stock   R$ 3.44 Bi https://icons.brapi.dev/icons/LIGT3.svg
# GEPA4.SA                                  Rio Paranapanema Energia S.A.           Utilities          Utilities - Regulated Electric Brazil stock   R$ 3.29 Bi https://icons.brapi.dev/icons/BRAPI.svg
# COCE5.SA                         Companhia Energética do Ceará - COELCE           Utilities          Utilities - Regulated Electric Brazil stock   R$ 2.08 Bi https://icons.brapi.dev/icons/COCE5.svg
# CEBR5.SA                         Companhia Energética de Brasília - CEB           Utilities          Utilities - Regulated Electric Brazil stock   R$ 1.42 Bi https://icons.brapi.dev/icons/CEBR5.svg
# CEBR3.SA                         Companhia Energética de Brasília - CEB           Utilities          Utilities - Regulated Electric Brazil stock   R$ 1.42 Bi https://icons.brapi.dev/icons/CEBR3.svg
# CEBR6.SA                         Companhia Energética de Brasília - CEB           Utilities          Utilities - Regulated Electric Brazil stock   R$ 1.42 Bi https://icons.brapi.dev/icons/CEBR6.svg
# EMAE4.SA                  Empresa Metropolitana de Águas e Energia S.A.           Utilities                 Utilities - Diversified Brazil stock   R$ 0.67 Bi https://icons.brapi.dev/icons/EMAE4.svg
# AFLT3.SA                  Afluente Transmissão de Energia Elétrica S.A.           Utilities          Utilities - Regulated Electric Brazil stock   R$ 0.44 Bi https://icons.brapi.dev/icons/BRAPI.svg
# RNEW4.SA                                            Renova Energia S.A.           Utilities                   Utilities - Renewable Brazil stock   R$ 0.34 Bi https://icons.brapi.dev/icons/RNEW4.svg
# RNEW3.SA                                            Renova Energia S.A.           Utilities                   Utilities - Renewable Brazil stock   R$ 0.34 Bi https://icons.brapi.dev/icons/RNEW3.svg
#
# ✅ Resultados salvos com sucesso no caminho: E:\Github\finance-manager\datasets\scanner_acoes_filtrado.xlsx

# %%
import pandas as pd

df_dados2 = pd.read_excel(r'E:\Github\finance-manager\datasets\scanner_acoes_filtrado.xlsx')

print(df_dados2)
# Out:
#        Ticker                                        Empresa   Setor (brapi)  \
# 0    VIVT3.SA                         Telefônica Brasil S.A.  Communications
# 1    TIMS3.SA                                       TIM S.A.  Communications
# 2    FIQE3.SA                 Unifique Telecomunicações S.A.  Communications
# 3    BRST3.SA                                            NaN  Communications
# 4    TELB3.SA   Telecomunicações Brasileiras S.A. - Telebras  Communications
# ..        ...                                            ...             ...
# 126  CEBR6.SA         Companhia Energética de Brasília - CEB       Utilities
# 127  EMAE4.SA  Empresa Metropolitana de Águas e Energia S.A.       Utilities
# 128  AFLT3.SA  Afluente Transmissão de Energia Elétrica S.A.       Utilities
# 129  RNEW4.SA                            Renova Energia S.A.       Utilities
# 130  RNEW3.SA                            Renova Energia S.A.       Utilities
#
#                 Subsetor (yfinance)    País   Tipo   Market Cap  \
# 0                  Telecom Services  Brazil  stock  R$ 98.50 Bi
# 1                  Telecom Services  Brazil  stock  R$ 51.57 Bi
# 2                  Telecom Services  Brazil  stock   R$ 1.34 Bi
# 3                  Telecom Services  Brazil  stock   R$ 1.28 Bi
# 4                  Telecom Services  Brazil  stock   R$ 1.14 Bi
# ..                              ...     ...    ...          ...
# 126  Utilities - Regulated Electric  Brazil  stock   R$ 1.42 Bi
# 127         Utilities - Diversified  Brazil  stock   R$ 0.67 Bi
# 128  Utilities - Regulated Electric  Brazil  stock   R$ 0.44 Bi
# 129           Utilities - Renewable  Brazil  stock   R$ 0.34 Bi
# 130           Utilities - Renewable  Brazil  stock   R$ 0.34 Bi
#
#                                         Logo
# 0    https://icons.brapi.dev/icons/VIVT3.svg
# 1    https://icons.brapi.dev/icons/TIMS3.svg
# 2    https://icons.brapi.dev/icons/FIQE3.svg
# 3    https://icons.brapi.dev/icons/BRST3.svg
# 4    https://icons.brapi.dev/icons/TELB3.svg
# ..                                       ...
# 126  https://icons.brapi.dev/icons/CEBR6.svg
# 127  https://icons.brapi.dev/icons/EMAE4.svg
# 128  https://icons.brapi.dev/icons/BRAPI.svg
# 129  https://icons.brapi.dev/icons/RNEW4.svg
# 130  https://icons.brapi.dev/icons/RNEW3.svg
#
# [131 rows x 8 columns]

# %% [markdown]
# # Transformação

# %% [markdown]
# ## Junção das empresas do csv

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, date
from dateutil.relativedelta import relativedelta

# --- PASSO 1: LER A LISTA DE ATIVOS DO SEU ARQUIVO ---
arquivo_input = r"E:\Github\finance-manager\datasets\scanner_acoes_filtrado.xlsx"

try:
    print(f"Lendo a lista de ativos do arquivo '{arquivo_input}'...")
    df_input = pd.read_excel(arquivo_input)
    
    # <<< CORREÇÃO APLICADA AQUI >>>
    # Alterado 'Categoria' para 'Setor (brapi)' para bater com o nome real da coluna no arquivo.
    colunas_esperadas = ['Ticker', 'Empresa', 'Setor (brapi)', 'País', 'Market Cap', 'Logo']
    colunas_faltantes = [col for col in colunas_esperadas if col not in df_input.columns]
    
    if colunas_faltantes:
        print("\n" + "="*50)
        print("⚠️ AVISO: Colunas Faltantes no Arquivo de Entrada!")
        print(f"O arquivo '{arquivo_input}' não possui as seguintes colunas: {colunas_faltantes}")
        print("Verifique se você está usando o arquivo correto gerado pelo script anterior.")
        print("="*50 + "\n")

    tickers_para_analisar = df_input['Ticker'].tolist()
    print(f"✅ Sucesso. {len(tickers_para_analisar)} ativos serão analisados.")

except FileNotFoundError:
    print(f"❌ ERRO: O arquivo '{arquivo_input}' não foi encontrado.")
    exit()
except Exception as e:
    print(f"❌ ERRO: Ocorreu um problema ao ler o arquivo: {e}")
    exit()

# --- PASSO 2: BUSCAR OS DADOS DETALHADOS PARA CADA TICKER DA LISTA ---
dados_detalhados_acoes = {}
print("\nIniciando a coleta de dados detalhados...")

for ticker in tickers_para_analisar:
    try:
        print(f"Analisando: {ticker}...")
        stock = yf.Ticker(ticker)
        info = stock.info
        
        info_original = df_input[df_input['Ticker'] == ticker].iloc[0]

        # --- Cálculo da Variação de 5 Anos ---
        variacao_5a = "N/A"
        try:
            end_date = date.today()
            start_date = end_date - relativedelta(years=5)
            hist_5a = stock.history(start=start_date, end=end_date)
            if not hist_5a.empty and len(hist_5a) > 1:
                preco_inicial = hist_5a['Close'].iloc[0]
                preco_final = hist_5a['Close'].iloc[-1]
                if preco_inicial > 0:
                    variacao_5a = ((preco_final / preco_inicial) - 1) * 100
        except Exception:
            variacao_5a = "N/A"

        # Coletando os dados
        dados_detalhados_acoes[ticker] = {
            # <<< CORREÇÃO APLICADA AQUI >>>
            # Lendo da coluna 'Setor (brapi)' e salvando com o mesmo nome para consistência
            "Empresa": info_original.get('Empresa', 'N/A'),
            "Setor (brapi)": info_original.get('Setor (brapi)', 'N/A'), 
            "País": info_original.get('País', 'N/A'),
            "Market Cap (R$)": info_original.get('Market Cap', 'N/A'),
            "Logo": info_original.get('Logo', 'N/A'),
            
            # Dados do yfinance
            "Data Cotação": datetime.fromtimestamp(info.get("regularMarketTime", 0)).strftime('%Y-%m-%d %H:%M:%S'),
            "Preço Atual": info.get("currentPrice", 0),
            "Preço Fechamento": info.get("previousClose", 0),
            "Volume Negociado": info.get("volume", 0),
            "P/L": info.get("trailingPE", "N/A"),
            "P/VP": info.get("priceToBook", "N/A"),
            "Dividend Yield (%)": info.get("dividendYield", 0) * 100,
            "DY 5 Anos Média (%)": info.get("fiveYearAvgDividendYield", "N/A"),
            "Dividendos 12m (R$)": info.get("trailingAnnualDividendRate", "N/A"),
            "ROE (%)": info.get("returnOnEquity", 0) * 100,
            "Margem Líquida (%)": info.get("profitMargins", 0) * 100,
            "Dívida/EBITDA": info.get("debtToEbitda", "N/A"),
            "Variação 12m (%)": info.get("52WeekChange", 0) * 100,
            "Variação 5a (%)": variacao_5a,
        }
        print(f"✅ Dados de {ticker} obtidos com sucesso.")

    except IndexError:
        print(f"❌ ERRO: O ticker '{ticker}' está na sua lista, mas não foi encontrado no arquivo Excel. Pulando.")
    except Exception as e:
        print(f"❌ Não foi possível obter dados para {ticker}. Erro: {e}")

print("\nColeta de dados finalizada.")

# --- PASSO 3: ORGANIZAR E SALVAR O NOVO RELATÓRIO DETALHADO ---
if dados_detalhados_acoes:
    df_resultado_detalhado = pd.DataFrame.from_dict(dados_detalhados_acoes, orient="index")

    colunas_para_formatar = [
        "Preço Atual", "Preço Fechamento", "P/L", "P/VP", "Dividend Yield (%)",
        "DY 5 Anos Média (%)", "Dividendos 12m (R$)", "ROE (%)",
        "Margem Líquida (%)", "Variação 12m (%)", "Variação 5a (%)"
    ]
    for col in colunas_para_formatar:
        if col in df_resultado_detalhado.columns:
            df_resultado_detalhado[col] = df_resultado_detalhado[col].apply(
                lambda x: f"{x:.2f}" if isinstance(x, (int, float)) else x
            )

    print("\n--- Tabela Comparativa de Indicadores Fundamentalistas ---")
    print(df_resultado_detalhado.to_string())

    try:
        df_resultado_detalhado.to_excel("relatorio_completo_b3.xlsx")
        print("\n✅ Relatório detalhado salvo com sucesso no arquivo 'relatorio_completo_b3.xlsx'")
    except Exception as e:
        print(f"\n❌ Erro ao salvar o novo arquivo Excel: {e}")
else:
    print("\nNenhum dado foi coletado.")
# Out:
# Lendo a lista de ativos do arquivo 'E:\Github\finance-manager\datasets\scanner_acoes_filtrado.xlsx'...
# ✅ Sucesso. 131 ativos serão analisados.
#
# Iniciando a coleta de dados detalhados...
# Analisando: VIVT3.SA...
# ✅ Dados de VIVT3.SA obtidos com sucesso.
# Analisando: TIMS3.SA...
# ✅ Dados de TIMS3.SA obtidos com sucesso.
# Analisando: FIQE3.SA...
# ✅ Dados de FIQE3.SA obtidos com sucesso.
# Analisando: BRST3.SA...
# ✅ Dados de BRST3.SA obtidos com sucesso.
# Analisando: TELB3.SA...
# ✅ Dados de TELB3.SA obtidos com sucesso.
# Analisando: TELB4.SA...
# ✅ Dados de TELB4.SA obtidos com sucesso.
# Analisando: DESK3.SA...
# ✅ Dados de DESK3.SA obtidos com sucesso.
# Analisando: OIBR3.SA...
# ✅ Dados de OIBR3.SA obtidos com sucesso.
# Analisando: OIBR4.SA...
# ✅ Dados de OIBR4.SA obtidos com sucesso.
# Analisando: DTCY3.SA...
# ✅ Dados de DTCY3.SA obtidos com sucesso.
# Analisando: ITUB4.SA...
# ✅ Dados de ITUB4.SA obtidos com sucesso.
# Analisando: ITUB3.SA...
# ✅ Dados de ITUB3.SA obtidos com sucesso.
# Analisando: BPAC3.SA...
# ✅ Dados de BPAC3.SA obtidos com sucesso.
# Analisando: BPAC5.SA...
# ✅ Dados de BPAC5.SA obtidos com sucesso.
# Analisando: BBDC4.SA...
# ✅ Dados de BBDC4.SA obtidos com sucesso.
# Analisando: BBDC3.SA...
# ✅ Dados de BBDC3.SA obtidos com sucesso.
# Analisando: BBAS3.SA...
# ✅ Dados de BBAS3.SA obtidos com sucesso.
# Analisando: ITSA4.SA...
# ✅ Dados de ITSA4.SA obtidos com sucesso.
# Analisando: ITSA3.SA...
# ✅ Dados de ITSA3.SA obtidos com sucesso.
# Analisando: SANB4.SA...
# ✅ Dados de SANB4.SA obtidos com sucesso.
# Analisando: SANB3.SA...
# ✅ Dados de SANB3.SA obtidos com sucesso.
# Analisando: B3SA3.SA...
# ✅ Dados de B3SA3.SA obtidos com sucesso.
# Analisando: BBSE3.SA...
# ✅ Dados de BBSE3.SA obtidos com sucesso.
# Analisando: CXSE3.SA...
# ✅ Dados de CXSE3.SA obtidos com sucesso.
# Analisando: RENT3.SA...
# ✅ Dados de RENT3.SA obtidos com sucesso.
# Analisando: PSSA3.SA...
# ✅ Dados de PSSA3.SA obtidos com sucesso.
# Analisando: MULT3.SA...
# ✅ Dados de MULT3.SA obtidos com sucesso.
# Analisando: ALOS3.SA...
# ✅ Dados de ALOS3.SA obtidos com sucesso.
# Analisando: BPAN4.SA...
# ✅ Dados de BPAN4.SA obtidos com sucesso.
# Analisando: CYRE3.SA...
# ✅ Dados de CYRE3.SA obtidos com sucesso.
# Analisando: BNBR3.SA...
# ✅ Dados de BNBR3.SA obtidos com sucesso.
# Analisando: CURY3.SA...
# ✅ Dados de CURY3.SA obtidos com sucesso.
# Analisando: DIRR3.SA...
# ✅ Dados de DIRR3.SA obtidos com sucesso.
# Analisando: IGTI3.SA...
# ✅ Dados de IGTI3.SA obtidos com sucesso.
# Analisando: BRAP4.SA...
# ✅ Dados de BRAP4.SA obtidos com sucesso.
# Analisando: BRAP3.SA...
# ✅ Dados de BRAP3.SA obtidos com sucesso.
# Analisando: ABCB4.SA...
# ✅ Dados de ABCB4.SA obtidos com sucesso.
# Analisando: BRSR5.SA...
# ✅ Dados de BRSR5.SA obtidos com sucesso.
# Analisando: BRSR3.SA...
# ✅ Dados de BRSR3.SA obtidos com sucesso.
# Analisando: BRSR6.SA...
# ✅ Dados de BRSR6.SA obtidos com sucesso.
# Analisando: VAMO3.SA...
# ✅ Dados de VAMO3.SA obtidos com sucesso.
# Analisando: BSLI4.SA...
# ✅ Dados de BSLI4.SA obtidos com sucesso.
# Analisando: BSLI3.SA...
# ✅ Dados de BSLI3.SA obtidos com sucesso.
# Analisando: BAZA3.SA...
# ✅ Dados de BAZA3.SA obtidos com sucesso.
# Analisando: BMEB3.SA...
# ✅ Dados de BMEB3.SA obtidos com sucesso.
# Analisando: BMEB4.SA...
# ✅ Dados de BMEB4.SA obtidos com sucesso.
# Analisando: IRBR3.SA...
# ✅ Dados de IRBR3.SA obtidos com sucesso.
# Analisando: JHSF3.SA...
# ✅ Dados de JHSF3.SA obtidos com sucesso.
# Analisando: PLPL3.SA...
# ✅ Dados de PLPL3.SA obtidos com sucesso.
# Analisando: TEND3.SA...
# ✅ Dados de TEND3.SA obtidos com sucesso.
# Analisando: BEES3.SA...
# ✅ Dados de BEES3.SA obtidos com sucesso.
# Analisando: BEES4.SA...
# ✅ Dados de BEES4.SA obtidos com sucesso.
# Analisando: EZTC3.SA...
# ✅ Dados de EZTC3.SA obtidos com sucesso.
# Analisando: MILS3.SA...
# ✅ Dados de MILS3.SA obtidos com sucesso.
# Analisando: MOVI3.SA...
# ✅ Dados de MOVI3.SA obtidos com sucesso.
# Analisando: LAVV3.SA...
# ✅ Dados de LAVV3.SA obtidos com sucesso.
# Analisando: BMGB4.SA...
# ✅ Dados de BMGB4.SA obtidos com sucesso.
# Analisando: AGRO3.SA...
# ✅ Dados de AGRO3.SA obtidos com sucesso.
# Analisando: MDNE3.SA...
# ✅ Dados de MDNE3.SA obtidos com sucesso.
# Analisando: EVEN3.SA...
# ✅ Dados de EVEN3.SA obtidos com sucesso.
# Analisando: PINE3.SA...
# ✅ Dados de PINE3.SA obtidos com sucesso.
# Analisando: PINE4.SA...
# ✅ Dados de PINE4.SA obtidos com sucesso.
# Analisando: ARML3.SA...
# ✅ Dados de ARML3.SA obtidos com sucesso.
# Analisando: WIZC3.SA...
# ✅ Dados de WIZC3.SA obtidos com sucesso.
# Analisando: LAND3.SA...
# ✅ Dados de LAND3.SA obtidos com sucesso.
# Analisando: SYNE3.SA...
# ✅ Dados de SYNE3.SA obtidos com sucesso.
# Analisando: SCAR3.SA...
# ✅ Dados de SCAR3.SA obtidos com sucesso.
# Analisando: BGIP4.SA...
# ✅ Dados de BGIP4.SA obtidos com sucesso.
# Analisando: MTRE3.SA...
# ✅ Dados de MTRE3.SA obtidos com sucesso.
# Analisando: RPAD6.SA...
# ✅ Dados de RPAD6.SA obtidos com sucesso.
# Analisando: HBRE3.SA...
# ✅ Dados de HBRE3.SA obtidos com sucesso.
# Analisando: AVLL3.SA...
# ✅ Dados de AVLL3.SA obtidos com sucesso.
# Analisando: ADMF3.SA...
# ✅ Dados de ADMF3.SA obtidos com sucesso.
# Analisando: HBTS5.SA...
# ✅ Dados de HBTS5.SA obtidos com sucesso.
# Analisando: GFSA3.SA...
# ✅ Dados de GFSA3.SA obtidos com sucesso.
# Analisando: RDNI3.SA...
# ✅ Dados de RDNI3.SA obtidos com sucesso.
# Analisando: TCSA3.SA...
# ✅ Dados de TCSA3.SA obtidos com sucesso.
# Analisando: NEXP3.SA...
# ✅ Dados de NEXP3.SA obtidos com sucesso.
# Analisando: PDGR3.SA...
# ✅ Dados de PDGR3.SA obtidos com sucesso.
# Analisando: TAEE3.SA...
# ✅ Dados de TAEE3.SA obtidos com sucesso.
# Analisando: TAEE4.SA...
# ✅ Dados de TAEE4.SA obtidos com sucesso.
# Analisando: LOGG3.SA...
# ✅ Dados de LOGG3.SA obtidos com sucesso.
# Analisando: PRNR3.SA...
# ✅ Dados de PRNR3.SA obtidos com sucesso.
# Analisando: MELK3.SA...
# ✅ Dados de MELK3.SA obtidos com sucesso.
# Analisando: AZEV4.SA...
# ✅ Dados de AZEV4.SA obtidos com sucesso.
# Analisando: AZEV3.SA...
# ✅ Dados de AZEV3.SA obtidos com sucesso.
# Analisando: AZTE3.SA...
# ✅ Dados de AZTE3.SA obtidos com sucesso.
# Analisando: INEP3.SA...
# ✅ Dados de INEP3.SA obtidos com sucesso.
# Analisando: INEP4.SA...
# ✅ Dados de INEP4.SA obtidos com sucesso.
# Analisando: OSXB3.SA...
# ✅ Dados de OSXB3.SA obtidos com sucesso.
# Analisando: ELET3.SA...
# ✅ Dados de ELET3.SA obtidos com sucesso.
# Analisando: ELET6.SA...
# ✅ Dados de ELET6.SA obtidos com sucesso.
# Analisando: SBSP3.SA...
# ✅ Dados de SBSP3.SA obtidos com sucesso.
# Analisando: CPFE3.SA...
# ✅ Dados de CPFE3.SA obtidos com sucesso.
# Analisando: EQTL3.SA...
# ✅ Dados de EQTL3.SA obtidos com sucesso.
# Analisando: EGIE3.SA...
# ✅ Dados de EGIE3.SA obtidos com sucesso.
# Analisando: CPLE3.SA...
# ✅ Dados de CPLE3.SA obtidos com sucesso.
# Analisando: CPLE6.SA...
# ✅ Dados de CPLE6.SA obtidos com sucesso.
# Analisando: CMIG3.SA...
# ✅ Dados de CMIG3.SA obtidos com sucesso.
# Analisando: CMIG4.SA...
# ✅ Dados de CMIG4.SA obtidos com sucesso.
# Analisando: NEOE3.SA...
# ✅ Dados de NEOE3.SA obtidos com sucesso.
# Analisando: ENEV3.SA...
# ✅ Dados de ENEV3.SA obtidos com sucesso.
# Analisando: ENGI4.SA...
# ✅ Dados de ENGI4.SA obtidos com sucesso.
# Analisando: ENGI3.SA...
# ✅ Dados de ENGI3.SA obtidos com sucesso.
# Analisando: ISAE3.SA...
# ✅ Dados de ISAE3.SA obtidos com sucesso.
# Analisando: ISAE4.SA...
# ✅ Dados de ISAE4.SA obtidos com sucesso.
# Analisando: ENMT3.SA...
# ✅ Dados de ENMT3.SA obtidos com sucesso.
# Analisando: REDE3.SA...
# ✅ Dados de REDE3.SA obtidos com sucesso.
# Analisando: CSAN3.SA...
# ✅ Dados de CSAN3.SA obtidos com sucesso.
# Analisando: EQPA3.SA...
# ✅ Dados de EQPA3.SA obtidos com sucesso.
# Analisando: SAPR3.SA...
# ✅ Dados de SAPR3.SA obtidos com sucesso.
# Analisando: SAPR4.SA...
# ✅ Dados de SAPR4.SA obtidos com sucesso.
# Analisando: AURE3.SA...
# ✅ Dados de AURE3.SA obtidos com sucesso.
# Analisando: ALUP3.SA...
# ✅ Dados de ALUP3.SA obtidos com sucesso.
# Analisando: ALUP4.SA...
# ✅ Dados de ALUP4.SA obtidos com sucesso.
# Analisando: CSMG3.SA...
# ✅ Dados de CSMG3.SA obtidos com sucesso.
# Analisando: CEEB3.SA...
# ✅ Dados de CEEB3.SA obtidos com sucesso.
# Analisando: EKTR4.SA...
# ✅ Dados de EKTR4.SA obtidos com sucesso.
# Analisando: SRNA3.SA...
# ✅ Dados de SRNA3.SA obtidos com sucesso.
# Analisando: ORVR3.SA...
# ✅ Dados de ORVR3.SA obtidos com sucesso.
# Analisando: CLSC4.SA...
# ✅ Dados de CLSC4.SA obtidos com sucesso.
# Analisando: LIGT3.SA...
# ✅ Dados de LIGT3.SA obtidos com sucesso.
# Analisando: GEPA4.SA...
# ✅ Dados de GEPA4.SA obtidos com sucesso.
# Analisando: COCE5.SA...
# ✅ Dados de COCE5.SA obtidos com sucesso.
# Analisando: CEBR5.SA...
# ✅ Dados de CEBR5.SA obtidos com sucesso.
# Analisando: CEBR3.SA...
# ✅ Dados de CEBR3.SA obtidos com sucesso.
# Analisando: CEBR6.SA...
# ✅ Dados de CEBR6.SA obtidos com sucesso.
# Analisando: EMAE4.SA...
# ✅ Dados de EMAE4.SA obtidos com sucesso.
# Analisando: AFLT3.SA...
# ✅ Dados de AFLT3.SA obtidos com sucesso.
# Analisando: RNEW4.SA...
# ✅ Dados de RNEW4.SA obtidos com sucesso.
# Analisando: RNEW3.SA...
# ✅ Dados de RNEW3.SA obtidos com sucesso.
#
# Coleta de dados finalizada.
#
# --- Tabela Comparativa de Indicadores Fundamentalistas ---
#                                                                  Empresa        Setor (brapi)    País Market Cap (R$)                                     Logo         Data Cotação Preço Atual Preço Fechamento  Volume Negociado     P/L   P/VP Dividend Yield (%) DY 5 Anos Média (%) Dividendos 12m (R$) ROE (%) Margem Líquida (%) Dívida/EBITDA Variação 12m (%) Variação 5a (%)
