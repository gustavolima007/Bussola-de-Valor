# %% [markdown]
# # Extraindo empresas

# %% [markdown]
# ## Extraindo todas empresas do Brasil da categoria BESST

# %%
import requests
import yfinance as yf
import pandas as pd
import os

# --- PASSO 1: CONFIGURAÇÃO DOS SETORES-ALVO ---
setores_alvo = [
    "Finance",
    "Utilities",
    "Communications",
    "Industrial Services"
]

# --- FUNÇÃO PRINCIPAL COM A LÓGICA FINAL ---
def scanner_final_com_tipo(setores):
    print("Iniciando scanner final focado (filtrando por tipo 'stock' e 'fund')...")
    try:
        url = "https://brapi.dev/api/quote/list"
        lista_completa_brapi = requests.get(url).json().get('stocks', [])
    except Exception as e:
        print(f"❌ Erro fatal ao buscar a lista da brapi: {e}")
        return {}

    print("Mapeando ativos dos setores alvo...")
    tickers_para_analisar = {}
    for stock in lista_completa_brapi:
        setor_brapi = stock.get('sector')
        tipo_ativo = stock.get('type')
        if setor_brapi in setores and tipo_ativo in ['stock', 'fund']:
            ticker = f"{stock.get('stock')}.SA"
            tickers_para_analisar[ticker] = {
                'setor': setor_brapi,
                'logo': stock.get('logo'),
                'tipo': tipo_ativo 
            }
    
    total = len(tickers_para_analisar)
    print(f"✅ Mapeamento concluído. {total} ativos dos tipos 'stock' e 'fund' serão analisados.")

    dados_finais = {}
    print("\nIniciando coleta detalhada de dados no yfinance...")
    for i, (ticker, brapi_data) in enumerate(tickers_para_analisar.items()):
        try:
            print(f"Analisando [{i+1}/{total}]: {ticker}...")
            stock = yf.Ticker(ticker)
            info = stock.info
            
            if info.get("country") != "Brazil":
                print(f"  -> DESCARTADO: {ticker} não é do Brasil.")
                continue
            
            dados_finais[ticker] = {
                "Empresa": info.get("longName", "N/A"),
                "Setor (brapi)": brapi_data['setor'],
                "Subsetor (yfinance)": info.get("industry", "N/A"),
                "País": info.get("country", "N/A"),
                "Tipo": brapi_data['tipo'],
                "Market Cap": info.get("marketCap"),
                "Logo": brapi_data['logo'],
            }
            print(f"  -> ✅ INCLUÍDO: {ticker}")

        except Exception as e:
            print(f"  -> ERRO: Falha ao processar {ticker}. Erro: {e}")
            continue
                
    return dados_finais

# --- EXECUÇÃO E APRESENTAÇÃO DOS RESULTADOS ---
resultados = scanner_final_com_tipo(setores_alvo)

if resultados:
    print("\n✅ Análise finalizada.")
    df_resultado = pd.DataFrame.from_dict(resultados, orient="index")
    
    df_resultado.reset_index(inplace=True)
    df_resultado.rename(columns={'index': 'Ticker'}, inplace=True)
    
    if "Market Cap" in df_resultado.columns:
         df_resultado["Market Cap Num"] = pd.to_numeric(df_resultado["Market Cap"], errors='coerce')
         df_resultado["Market Cap"] = df_resultado["Market Cap Num"].apply(
             lambda x: f"R$ {x/1_000_000_000:.2f} Bi" if pd.notna(x) and x > 0 else "N/A"
         )

    df_ordenado = df_resultado.sort_values(by=['Setor (brapi)', 'Market Cap Num'], ascending=[True, False])
    
    colunas_finais = ['Ticker', 'Empresa', 'Setor (brapi)', 'Subsetor (yfinance)', 'País', 'Tipo', 'Market Cap', 'Logo']
    df_final = df_ordenado[colunas_finais]
    
    print("\n--- Relatório Final (Ações e Fundos) ---")
    print(df_final.to_string(index=False))

    # --- SALVANDO O ARQUIVO NO CAMINHO ESPECÍFICO ---
    try:
        output_folder = r"E:\finance-manager\data"
        output_filename = "scanner_acoes_e_fundos_filtrado.csv"
        full_path = os.path.join(output_folder, output_filename)
        
        os.makedirs(output_folder, exist_ok=True)
        
        df_final.to_csv(full_path, index=False)
        print(f"\n✅ Resultados salvos com sucesso no caminho: {full_path}")
    except Exception as e:
        print(f"\n❌ Erro ao salvar o arquivo CSV: {e}")
else:
    print("\nNenhuma empresa foi encontrada para os critérios especificados.")
# Out:
# Iniciando scanner final focado (filtrando por tipo 'stock' e 'fund')...
# Mapeando ativos dos setores alvo...
# ✅ Mapeamento concluído. 304 ativos dos tipos 'stock' e 'fund' serão analisados.
#
# Iniciando coleta detalhada de dados no yfinance...
# Analisando [1/304]: B3SA3.SA...
#   -> ✅ INCLUÍDO: B3SA3.SA
# Analisando [2/304]: BBDC4.SA...
#   -> ✅ INCLUÍDO: BBDC4.SA
# Analisando [3/304]: ITUB4.SA...
#   -> ✅ INCLUÍDO: ITUB4.SA
# Analisando [4/304]: ITSA4.SA...
#   -> ✅ INCLUÍDO: ITSA4.SA
# Analisando [5/304]: BBAS3.SA...
#   -> ✅ INCLUÍDO: BBAS3.SA
# Analisando [6/304]: VIVT3.SA...
#   -> ✅ INCLUÍDO: VIVT3.SA
# Analisando [7/304]: CSAN3.SA...
#   -> ✅ INCLUÍDO: CSAN3.SA
# Analisando [8/304]: VAMO3.SA...
#   -> ✅ INCLUÍDO: VAMO3.SA
# Analisando [9/304]: CPLE6.SA...
#   -> ✅ INCLUÍDO: CPLE6.SA
# Analisando [10/304]: CMIG4.SA...
#   -> ✅ INCLUÍDO: CMIG4.SA
# Analisando [11/304]: ENEV3.SA...
#   -> ✅ INCLUÍDO: ENEV3.SA
# Analisando [12/304]: ARML3.SA...
#   -> ✅ INCLUÍDO: ARML3.SA
# Analisando [13/304]: MOVI3.SA...
#   -> ✅ INCLUÍDO: MOVI3.SA
# Analisando [14/304]: TIMS3.SA...
#   -> ✅ INCLUÍDO: TIMS3.SA
# Analisando [15/304]: RENT3.SA...
#   -> ✅ INCLUÍDO: RENT3.SA
# Analisando [16/304]: BPAC11.SA...
#   -> ✅ INCLUÍDO: BPAC11.SA
# Analisando [17/304]: EQTL3.SA...
#   -> ✅ INCLUÍDO: EQTL3.SA
# Analisando [18/304]: BBDC3.SA...
#   -> ✅ INCLUÍDO: BBDC3.SA
# Analisando [19/304]: AZTE3.SA...
#   -> ✅ INCLUÍDO: AZTE3.SA
# Analisando [20/304]: CPLE3.SA...
#   -> ✅ INCLUÍDO: CPLE3.SA
# Analisando [21/304]: MULT3.SA...
#   -> ✅ INCLUÍDO: MULT3.SA
# Analisando [22/304]: ELET3.SA...
#   -> ✅ INCLUÍDO: ELET3.SA
# Analisando [23/304]: SRNA3.SA...
#   -> ✅ INCLUÍDO: SRNA3.SA
# Analisando [24/304]: BBSE3.SA...
#   -> ✅ INCLUÍDO: BBSE3.SA
# Analisando [25/304]: BRAP4.SA...
#   -> ✅ INCLUÍDO: BRAP4.SA
# Analisando [26/304]: ALOS3.SA...
#   -> ✅ INCLUÍDO: ALOS3.SA
# Analisando [27/304]: AZEV4.SA...
#   -> ✅ INCLUÍDO: AZEV4.SA
# Analisando [28/304]: SBSP3.SA...
#   -> ✅ INCLUÍDO: SBSP3.SA
# Analisando [29/304]: SAPR11.SA...
#   -> ✅ INCLUÍDO: SAPR11.SA
# Analisando [30/304]: IGTI11.SA...
#   -> ✅ INCLUÍDO: IGTI11.SA
# Analisando [31/304]: CXSE3.SA...
#   -> ✅ INCLUÍDO: CXSE3.SA
# Analisando [32/304]: CYRE3.SA...
#   -> ✅ INCLUÍDO: CYRE3.SA
# Analisando [33/304]: ENGI11.SA...
#   -> ✅ INCLUÍDO: ENGI11.SA
# Analisando [34/304]: ABCB4.SA...
#   -> ✅ INCLUÍDO: ABCB4.SA
# Analisando [35/304]: SAPR4.SA...
#   -> ✅ INCLUÍDO: SAPR4.SA
# Analisando [36/304]: SANB11.SA...
#   -> ✅ INCLUÍDO: SANB11.SA
# Analisando [37/304]: JHSF3.SA...
#   -> ✅ INCLUÍDO: JHSF3.SA
# Analisando [38/304]: AURE3.SA...
#   -> ✅ INCLUÍDO: AURE3.SA
# Analisando [39/304]: TCSA3.SA...
#   -> ✅ INCLUÍDO: TCSA3.SA
# Analisando [40/304]: TEND3.SA...
#   -> ✅ INCLUÍDO: TEND3.SA
# Analisando [41/304]: CSMG3.SA...
#   -> ✅ INCLUÍDO: CSMG3.SA
# Analisando [42/304]: CURY3.SA...
#   -> ✅ INCLUÍDO: CURY3.SA
# Analisando [43/304]: TAEE11.SA...
#   -> ✅ INCLUÍDO: TAEE11.SA
# Analisando [44/304]: CPFE3.SA...
#   -> ✅ INCLUÍDO: CPFE3.SA
# Analisando [45/304]: DIRR3.SA...
#   -> ✅ INCLUÍDO: DIRR3.SA
# Analisando [46/304]: AZEV3.SA...
#   -> ✅ INCLUÍDO: AZEV3.SA
# Analisando [47/304]: MTRE3.SA...
#   -> ✅ INCLUÍDO: MTRE3.SA
# Analisando [48/304]: EGIE3.SA...
#   -> ✅ INCLUÍDO: EGIE3.SA
# Analisando [49/304]: ELET6.SA...
#   -> ✅ INCLUÍDO: ELET6.SA
# Analisando [50/304]: BRSR6.SA...
#   -> ✅ INCLUÍDO: BRSR6.SA
# Analisando [51/304]: PSSA3.SA...
#   -> ✅ INCLUÍDO: PSSA3.SA
# Analisando [52/304]: EZTC3.SA...
#   -> ✅ INCLUÍDO: EZTC3.SA
# Analisando [53/304]: LIGT3.SA...
#   -> ✅ INCLUÍDO: LIGT3.SA
# Analisando [54/304]: ISAE4.SA...
#   -> ✅ INCLUÍDO: ISAE4.SA
# Analisando [55/304]: MDNE3.SA...
#   -> ✅ INCLUÍDO: MDNE3.SA
# Analisando [56/304]: OIBR3.SA...
#   -> ✅ INCLUÍDO: OIBR3.SA
# Analisando [57/304]: MILS3.SA...
#   -> ✅ INCLUÍDO: MILS3.SA
# Analisando [58/304]: ITUB3.SA...
#   -> ✅ INCLUÍDO: ITUB3.SA
# Analisando [59/304]: PLPL3.SA...
#   -> ✅ INCLUÍDO: PLPL3.SA
# Analisando [60/304]: BPAN4.SA...
#   -> ✅ INCLUÍDO: BPAN4.SA
# Analisando [61/304]: IRBR3.SA...
#   -> ✅ INCLUÍDO: IRBR3.SA
# Analisando [62/304]: ALUP11.SA...
#   -> ✅ INCLUÍDO: ALUP11.SA
# Analisando [63/304]: LAVV3.SA...
#   -> ✅ INCLUÍDO: LAVV3.SA
# Analisando [64/304]: BBAS3F.SA...
#   -> DESCARTADO: BBAS3F.SA não é do Brasil.
# Analisando [65/304]: MELK3.SA...
#   -> ✅ INCLUÍDO: MELK3.SA
# Analisando [66/304]: SYNE3.SA...
#   -> ✅ INCLUÍDO: SYNE3.SA
# Analisando [67/304]: PDGR3.SA...
#   -> ✅ INCLUÍDO: PDGR3.SA
# Analisando [68/304]: NEOE3.SA...
#   -> ✅ INCLUÍDO: NEOE3.SA
# Analisando [69/304]: EVEN3.SA...
#   -> ✅ INCLUÍDO: EVEN3.SA
# Analisando [70/304]: AGRO3.SA...
#   -> ✅ INCLUÍDO: AGRO3.SA
# Analisando [71/304]: SAPR3.SA...
#   -> ✅ INCLUÍDO: SAPR3.SA
# Analisando [72/304]: HBRE3.SA...
#   -> ✅ INCLUÍDO: HBRE3.SA
# Analisando [73/304]: PRNR3.SA...
#   -> ✅ INCLUÍDO: PRNR3.SA
# Analisando [74/304]: PINE4.SA...
#   -> ✅ INCLUÍDO: PINE4.SA
# Analisando [75/304]: BMGB4.SA...
#   -> ✅ INCLUÍDO: BMGB4.SA
# Analisando [76/304]: ORVR3.SA...
#   -> ✅ INCLUÍDO: ORVR3.SA
# Analisando [77/304]: WIZC3.SA...
#   -> ✅ INCLUÍDO: WIZC3.SA
# Analisando [78/304]: CMIG3.SA...
#   -> ✅ INCLUÍDO: CMIG3.SA
# Analisando [79/304]: FIQE3.SA...
#   -> ✅ INCLUÍDO: FIQE3.SA
# Analisando [80/304]: INEP4.SA...
#   -> ✅ INCLUÍDO: INEP4.SA
# Analisando [81/304]: CMIG4F.SA...
#   -> DESCARTADO: CMIG4F.SA não é do Brasil.
# Analisando [82/304]: LOGG3.SA...
#   -> ✅ INCLUÍDO: LOGG3.SA
# Analisando [83/304]: GFSA3.SA...
#   -> ✅ INCLUÍDO: GFSA3.SA
# Analisando [84/304]: BRST3.SA...
#   -> ✅ INCLUÍDO: BRST3.SA
# Analisando [85/304]: VIVT3F.SA...
#   -> DESCARTADO: VIVT3F.SA não é do Brasil.
# Analisando [86/304]: DESK3.SA...
#   -> ✅ INCLUÍDO: DESK3.SA
# Analisando [87/304]: BRBI11.SA...
#   -> ✅ INCLUÍDO: BRBI11.SA
# Analisando [88/304]: RNEW3.SA...
#   -> ✅ INCLUÍDO: RNEW3.SA
# Analisando [89/304]: TAEE4.SA...
#   -> ✅ INCLUÍDO: TAEE4.SA
# Analisando [90/304]: RNEW4.SA...
#   -> ✅ INCLUÍDO: RNEW4.SA
# Analisando [91/304]: BBSE3F.SA...
#   -> DESCARTADO: BBSE3F.SA não é do Brasil.
# Analisando [92/304]: ITSA3.SA...
#   -> ✅ INCLUÍDO: ITSA3.SA
# Analisando [93/304]: SANB3.SA...
#   -> ✅ INCLUÍDO: SANB3.SA
# Analisando [94/304]: CXSE3F.SA...
#   -> DESCARTADO: CXSE3F.SA não é do Brasil.
# Analisando [95/304]: ITSA4F.SA...
#   -> DESCARTADO: ITSA4F.SA não é do Brasil.
# Analisando [96/304]: SANB4.SA...
#   -> ✅ INCLUÍDO: SANB4.SA
# Analisando [97/304]: SCAR3.SA...
#   -> ✅ INCLUÍDO: SCAR3.SA
# Analisando [98/304]: SAPR4F.SA...
#   -> DESCARTADO: SAPR4F.SA não é do Brasil.
# Analisando [99/304]: IGTI3.SA...
#   -> ✅ INCLUÍDO: IGTI3.SA
# Analisando [100/304]: TAEE3.SA...
#   -> ✅ INCLUÍDO: TAEE3.SA
# Analisando [101/304]: INEP3.SA...
#   -> ✅ INCLUÍDO: INEP3.SA
# Analisando [102/304]: BBDC4F.SA...
#   -> DESCARTADO: BBDC4F.SA não é do Brasil.
# Analisando [103/304]: ITUB4F.SA...
#   -> DESCARTADO: ITUB4F.SA não é do Brasil.
# Analisando [104/304]: CSAN3F.SA...
#   -> DESCARTADO: CSAN3F.SA não é do Brasil.
# Analisando [105/304]: TAEE11F.SA...
#   -> DESCARTADO: TAEE11F.SA não é do Brasil.
# Analisando [106/304]: B3SA3F.SA...
#   -> DESCARTADO: B3SA3F.SA não é do Brasil.
# Analisando [107/304]: ISAE4F.SA...
#   -> DESCARTADO: ISAE4F.SA não é do Brasil.
# Analisando [108/304]: EGIE3F.SA...
#   -> DESCARTADO: EGIE3F.SA não é do Brasil.
# Analisando [109/304]: LAND3.SA...
#   -> ✅ INCLUÍDO: LAND3.SA
# Analisando [110/304]: ABCB4F.SA...
#   -> DESCARTADO: ABCB4F.SA não é do Brasil.
# Analisando [111/304]: BBDC3F.SA...
#   -> DESCARTADO: BBDC3F.SA não é do Brasil.
# Analisando [112/304]: CPLE6F.SA...
#   -> DESCARTADO: CPLE6F.SA não é do Brasil.
# Analisando [113/304]: VAMO3F.SA...
#   -> DESCARTADO: VAMO3F.SA não é do Brasil.
# Analisando [114/304]: CSMG3F.SA...
#   -> DESCARTADO: CSMG3F.SA não é do Brasil.
# Analisando [115/304]: BRAP3.SA...
#   -> ✅ INCLUÍDO: BRAP3.SA
# Analisando [116/304]: TIMS3F.SA...
#   -> DESCARTADO: TIMS3F.SA não é do Brasil.
# Analisando [117/304]: BMGB4F.SA...
#   -> DESCARTADO: BMGB4F.SA não é do Brasil.
# Analisando [118/304]: CEBR3.SA...
#   -> ✅ INCLUÍDO: CEBR3.SA
# Analisando [119/304]: AURE3F.SA...
#   -> DESCARTADO: AURE3F.SA não é do Brasil.
# Analisando [120/304]: TAEE4F.SA...
#   -> DESCARTADO: TAEE4F.SA não é do Brasil.
# Analisando [121/304]: AGRO3F.SA...
#   -> DESCARTADO: AGRO3F.SA não é do Brasil.
# Analisando [122/304]: SAPR11F.SA...
#   -> DESCARTADO: SAPR11F.SA não é do Brasil.
# Analisando [123/304]: BRAP4F.SA...
#   -> DESCARTADO: BRAP4F.SA não é do Brasil.
# Analisando [124/304]: JHSF3F.SA...
#   -> DESCARTADO: JHSF3F.SA não é do Brasil.
# Analisando [125/304]: CMIG3F.SA...
#   -> DESCARTADO: CMIG3F.SA não é do Brasil.
# Analisando [126/304]: ITUB3F.SA...
#   -> DESCARTADO: ITUB3F.SA não é do Brasil.
# Analisando [127/304]: SBSP3F.SA...
#   -> DESCARTADO: SBSP3F.SA não é do Brasil.
# Analisando [128/304]: ALUP4.SA...
#   -> ✅ INCLUÍDO: ALUP4.SA
# Analisando [129/304]: EQTL3F.SA...
#   -> DESCARTADO: EQTL3F.SA não é do Brasil.
# Analisando [130/304]: SYNE3F.SA...
#   -> DESCARTADO: SYNE3F.SA não é do Brasil.
# Analisando [131/304]: BAZA3.SA...
#   -> ✅ INCLUÍDO: BAZA3.SA
# Analisando [132/304]: PSSA3F.SA...
#   -> DESCARTADO: PSSA3F.SA não é do Brasil.
# Analisando [133/304]: BEES3.SA...
#   -> ✅ INCLUÍDO: BEES3.SA
# Analisando [134/304]: ELET3F.SA...
#   -> DESCARTADO: ELET3F.SA não é do Brasil.
# Analisando [135/304]: SAPR3F.SA...
#   -> DESCARTADO: SAPR3F.SA não é do Brasil.
# Analisando [136/304]: TAEE3F.SA...
#   -> DESCARTADO: TAEE3F.SA não é do Brasil.
# Analisando [137/304]: DIRR3F.SA...
#   -> DESCARTADO: DIRR3F.SA não é do Brasil.
# Analisando [138/304]: CPFE3F.SA...
#   -> DESCARTADO: CPFE3F.SA não é do Brasil.
# Analisando [139/304]: BRSR6F.SA...
#   -> DESCARTADO: BRSR6F.SA não é do Brasil.
# Analisando [140/304]: BPAC11F.SA...
#   -> DESCARTADO: BPAC11F.SA não é do Brasil.
# Analisando [141/304]: ALUP3.SA...
#   -> ✅ INCLUÍDO: ALUP3.SA
# Analisando [142/304]: EZTC3F.SA...
#   -> DESCARTADO: EZTC3F.SA não é do Brasil.
# Analisando [143/304]: FIQE3F.SA...
#   -> DESCARTADO: FIQE3F.SA não é do Brasil.
# Analisando [144/304]: IRBR3F.SA...
#   -> DESCARTADO: IRBR3F.SA não é do Brasil.
# Analisando [145/304]: ITSA3F.SA...
#   -> DESCARTADO: ITSA3F.SA não é do Brasil.
# Analisando [146/304]: RENT3F.SA...
#   -> DESCARTADO: RENT3F.SA não é do Brasil.
# Analisando [147/304]: MOVI3F.SA...
#   -> DESCARTADO: MOVI3F.SA não é do Brasil.
# Analisando [148/304]: ALUP11F.SA...
#   -> DESCARTADO: ALUP11F.SA não é do Brasil.
# Analisando [149/304]: BMEB4.SA...
#   -> ✅ INCLUÍDO: BMEB4.SA
# Analisando [150/304]: SANB11F.SA...
#   -> DESCARTADO: SANB11F.SA não é do Brasil.
# Analisando [151/304]: CYRE3F.SA...
#   -> DESCARTADO: CYRE3F.SA não é do Brasil.
# Analisando [152/304]: MTRE3F.SA...
#   -> DESCARTADO: MTRE3F.SA não é do Brasil.
# Analisando [153/304]: WIZC3F.SA...
#   -> DESCARTADO: WIZC3F.SA não é do Brasil.
# Analisando [154/304]: ENGI4.SA...
#   -> ✅ INCLUÍDO: ENGI4.SA
# Analisando [155/304]: ARML3F.SA...
#   -> DESCARTADO: ARML3F.SA não é do Brasil.
# Analisando [156/304]: ENGI11F.SA...
#   -> DESCARTADO: ENGI11F.SA não é do Brasil.
# Analisando [157/304]: MELK3F.SA...
#   -> DESCARTADO: MELK3F.SA não é do Brasil.
# Analisando [158/304]: TCSA3F.SA...
#   -> DESCARTADO: TCSA3F.SA não é do Brasil.
# Analisando [159/304]: ELET6F.SA...
#   -> DESCARTADO: ELET6F.SA não é do Brasil.
# Analisando [160/304]: OIBR3F.SA...
#   -> DESCARTADO: OIBR3F.SA não é do Brasil.
# Analisando [161/304]: BRBI11F.SA...
#   -> DESCARTADO: BRBI11F.SA não é do Brasil.
# Analisando [162/304]: BPAC5.SA...
#   -> ✅ INCLUÍDO: BPAC5.SA
# Analisando [163/304]: EQPA3.SA...
#   -> ✅ INCLUÍDO: EQPA3.SA
# Analisando [164/304]: PINE3.SA...
#   -> ✅ INCLUÍDO: PINE3.SA
# Analisando [165/304]: AZTE3F.SA...
#   -> DESCARTADO: AZTE3F.SA não é do Brasil.
# Analisando [166/304]: CPLE3F.SA...
#   -> DESCARTADO: CPLE3F.SA não é do Brasil.
# Analisando [167/304]: MDNE3F.SA...
#   -> DESCARTADO: MDNE3F.SA não é do Brasil.
# Analisando [168/304]: MULT3F.SA...
#   -> DESCARTADO: MULT3F.SA não é do Brasil.
# Analisando [169/304]: SNCI11.SA...
#   -> ✅ INCLUÍDO: SNCI11.SA
# Analisando [170/304]: AZEV4F.SA...
#   -> DESCARTADO: AZEV4F.SA não é do Brasil.
# Analisando [171/304]: TELB3.SA...
#   -> ✅ INCLUÍDO: TELB3.SA
# Analisando [172/304]: ALOS3F.SA...
#   -> DESCARTADO: ALOS3F.SA não é do Brasil.
# Analisando [173/304]: IGTI3F.SA...
#   -> DESCARTADO: IGTI3F.SA não é do Brasil.
# Analisando [174/304]: OSXB3.SA...
#   -> ✅ INCLUÍDO: OSXB3.SA
# Analisando [175/304]: CURY3F.SA...
#   -> DESCARTADO: CURY3F.SA não é do Brasil.
# Analisando [176/304]: IGTI11F.SA...
#   -> DESCARTADO: IGTI11F.SA não é do Brasil.
# Analisando [177/304]: CEBR5.SA...
#   -> ✅ INCLUÍDO: CEBR5.SA
# Analisando [178/304]: NEOE3F.SA...
#   -> DESCARTADO: NEOE3F.SA não é do Brasil.
# Analisando [179/304]: COCE5.SA...
#   -> ✅ INCLUÍDO: COCE5.SA
# Analisando [180/304]: SANB4F.SA...
#   -> DESCARTADO: SANB4F.SA não é do Brasil.
# Analisando [181/304]: BGIP4.SA...
#   -> ✅ INCLUÍDO: BGIP4.SA
# Analisando [182/304]: BEES4.SA...
#   -> ✅ INCLUÍDO: BEES4.SA
# Analisando [183/304]: PLPL3F.SA...
#   -> DESCARTADO: PLPL3F.SA não é do Brasil.
# Analisando [184/304]: LAVV3F.SA...
#   -> DESCARTADO: LAVV3F.SA não é do Brasil.
# Analisando [185/304]: ENGI3.SA...
#   -> ✅ INCLUÍDO: ENGI3.SA
# Analisando [186/304]: SANB3F.SA...
#   -> DESCARTADO: SANB3F.SA não é do Brasil.
# Analisando [187/304]: ENEV3F.SA...
#   -> DESCARTADO: ENEV3F.SA não é do Brasil.
# Analisando [188/304]: TEND3F.SA...
#   -> DESCARTADO: TEND3F.SA não é do Brasil.
# Analisando [189/304]: GFSA3F.SA...
#   -> DESCARTADO: GFSA3F.SA não é do Brasil.
# Analisando [190/304]: BEES3F.SA...
#   -> DESCARTADO: BEES3F.SA não é do Brasil.
# Analisando [191/304]: EVEN3F.SA...
#   -> DESCARTADO: EVEN3F.SA não é do Brasil.
# Analisando [192/304]: ORVR3F.SA...
#   -> DESCARTADO: ORVR3F.SA não é do Brasil.
# Analisando [193/304]: CEBR6.SA...
#   -> ✅ INCLUÍDO: CEBR6.SA
# Analisando [194/304]: PINE4F.SA...
#   -> DESCARTADO: PINE4F.SA não é do Brasil.
# Analisando [195/304]: RDNI3.SA...
#   -> ✅ INCLUÍDO: RDNI3.SA
# Analisando [196/304]: BRAP3F.SA...
#   -> DESCARTADO: BRAP3F.SA não é do Brasil.
# Analisando [197/304]: ISAE3.SA...
#   -> ✅ INCLUÍDO: ISAE3.SA
# Analisando [198/304]: BPAN4F.SA...
#   -> DESCARTADO: BPAN4F.SA não é do Brasil.
# Analisando [199/304]: PDGR3F.SA...
#   -> DESCARTADO: PDGR3F.SA não é do Brasil.
# Analisando [200/304]: CLSC4.SA...
#   -> ✅ INCLUÍDO: CLSC4.SA
# Analisando [201/304]: MILS3F.SA...
#   -> DESCARTADO: MILS3F.SA não é do Brasil.
# Analisando [202/304]: LIGT3F.SA...
#   -> DESCARTADO: LIGT3F.SA não é do Brasil.
# Analisando [203/304]: RNEW11.SA...
#   -> ✅ INCLUÍDO: RNEW11.SA
# Analisando [204/304]: AZEV3F.SA...
#   -> DESCARTADO: AZEV3F.SA não é do Brasil.
# Analisando [205/304]: LOGG3F.SA...
#   -> DESCARTADO: LOGG3F.SA não é do Brasil.
# Analisando [206/304]: REDE3.SA...
#   -> ✅ INCLUÍDO: REDE3.SA
# Analisando [207/304]: OIBR4.SA...
#   -> ✅ INCLUÍDO: OIBR4.SA
# Analisando [208/304]: BNBR3.SA...
#   -> ✅ INCLUÍDO: BNBR3.SA
# Analisando [209/304]: ALUP4F.SA...
#   -> DESCARTADO: ALUP4F.SA não é do Brasil.
# Analisando [210/304]: RNEW4F.SA...
#   -> DESCARTADO: RNEW4F.SA não é do Brasil.
# Analisando [211/304]: BPAC3.SA...
#   -> ✅ INCLUÍDO: BPAC3.SA
# Analisando [212/304]: CGAS5.SA...
#   -> ✅ INCLUÍDO: CGAS5.SA
# Analisando [213/304]: AVLL3.SA...
#   -> ✅ INCLUÍDO: AVLL3.SA
# Analisando [214/304]: BEES4F.SA...
#   -> DESCARTADO: BEES4F.SA não é do Brasil.
# Analisando [215/304]: SRNA3F.SA...
#   -> DESCARTADO: SRNA3F.SA não é do Brasil.
# Analisando [216/304]: BSLI3.SA...
#   -> ✅ INCLUÍDO: BSLI3.SA
# Analisando [217/304]: BAZA3F.SA...
#   -> DESCARTADO: BAZA3F.SA não é do Brasil.
# Analisando [218/304]: PRNR3F.SA...
#   -> DESCARTADO: PRNR3F.SA não é do Brasil.
# Analisando [219/304]: RNEW3F.SA...
#   -> DESCARTADO: RNEW3F.SA não é do Brasil.
# Analisando [220/304]: ALUP3F.SA...
#   -> DESCARTADO: ALUP3F.SA não é do Brasil.
# Analisando [221/304]: DESK3F.SA...
#   -> DESCARTADO: DESK3F.SA não é do Brasil.
# Analisando [222/304]: ISAE3F.SA...
#   -> DESCARTADO: ISAE3F.SA não é do Brasil.
# Analisando [223/304]: BSLI4.SA...
#   -> ✅ INCLUÍDO: BSLI4.SA
# Analisando [224/304]: REDE3F.SA...
#   -> DESCARTADO: REDE3F.SA não é do Brasil.
# Analisando [225/304]: BRSR3F.SA...
#   -> DESCARTADO: BRSR3F.SA não é do Brasil.
# Analisando [226/304]: CEBR3F.SA...
#   -> DESCARTADO: CEBR3F.SA não é do Brasil.
# Analisando [227/304]: EQMA3B.SA...
#   -> ✅ INCLUÍDO: EQMA3B.SA
# Analisando [228/304]: EMAE4.SA...
#   -> ✅ INCLUÍDO: EMAE4.SA
# Analisando [229/304]: BMEB4F.SA...
#   -> DESCARTADO: BMEB4F.SA não é do Brasil.
# Analisando [230/304]: INEP3F.SA...
#   -> DESCARTADO: INEP3F.SA não é do Brasil.
# Analisando [231/304]: ENGI4F.SA...
#   -> DESCARTADO: ENGI4F.SA não é do Brasil.
# Analisando [232/304]: IRIM11.SA...
#   -> ✅ INCLUÍDO: IRIM11.SA
# Analisando [233/304]: PINE3F.SA...
#   -> DESCARTADO: PINE3F.SA não é do Brasil.
# Analisando [234/304]: RBIF11.SA...
#   -> ✅ INCLUÍDO: RBIF11.SA
# Analisando [235/304]: TELB4.SA...
#   -> ✅ INCLUÍDO: TELB4.SA
# Analisando [236/304]: BRST3F.SA...
#   -> DESCARTADO: BRST3F.SA não é do Brasil.
# Analisando [237/304]: EQPA3F.SA...
#   -> DESCARTADO: EQPA3F.SA não é do Brasil.
# Analisando [238/304]: BPAC3F.SA...
#   -> DESCARTADO: BPAC3F.SA não é do Brasil.
# Analisando [239/304]: ENGI3F.SA...
#   -> DESCARTADO: ENGI3F.SA não é do Brasil.
# Analisando [240/304]: SCAR3F.SA...
#   -> DESCARTADO: SCAR3F.SA não é do Brasil.
# Analisando [241/304]: COCE5F.SA...
#   -> DESCARTADO: COCE5F.SA não é do Brasil.
# Analisando [242/304]: BRSR3.SA...
#   -> ✅ INCLUÍDO: BRSR3.SA
# Analisando [243/304]: PEAB4.SA...
#   -> ✅ INCLUÍDO: PEAB4.SA
# Analisando [244/304]: CGAS5F.SA...
#   -> DESCARTADO: CGAS5F.SA não é do Brasil.
# Analisando [245/304]: CEBR6F.SA...
#   -> DESCARTADO: CEBR6F.SA não é do Brasil.
# Analisando [246/304]: MOAR3F.SA...
#   -> DESCARTADO: MOAR3F.SA não é do Brasil.
# Analisando [247/304]: OIBR4F.SA...
#   -> DESCARTADO: OIBR4F.SA não é do Brasil.
# Analisando [248/304]: ENMT3.SA...
#   -> ✅ INCLUÍDO: ENMT3.SA
# Analisando [249/304]: GEPA4.SA...
#   -> ✅ INCLUÍDO: GEPA4.SA
# Analisando [250/304]: RENV11.SA...
#   -> ✅ INCLUÍDO: RENV11.SA
# Analisando [251/304]: RNEW11F.SA...
#   -> DESCARTADO: RNEW11F.SA não é do Brasil.
# Analisando [252/304]: RPAD3.SA...
#   -> ✅ INCLUÍDO: RPAD3.SA
# Analisando [253/304]: INEP4F.SA...
#   -> DESCARTADO: INEP4F.SA não é do Brasil.
# Analisando [254/304]: HBRE3F.SA...
#   -> DESCARTADO: HBRE3F.SA não é do Brasil.
# Analisando [255/304]: FSTU11F.SA...
#   -> DESCARTADO: FSTU11F.SA não é do Brasil.
# Analisando [256/304]: FSPE11F.SA...
#   -> DESCARTADO: FSPE11F.SA não é do Brasil.
# Analisando [257/304]: CLSC4F.SA...
#   -> DESCARTADO: CLSC4F.SA não é do Brasil.
# Analisando [258/304]: EKTR4.SA...
#   -> ✅ INCLUÍDO: EKTR4.SA
# Analisando [259/304]: BNBR3F.SA...
#   -> DESCARTADO: BNBR3F.SA não é do Brasil.
# Analisando [260/304]: OSXB3F.SA...
#   -> DESCARTADO: OSXB3F.SA não é do Brasil.
# Analisando [261/304]: CEBR5F.SA...
#   -> DESCARTADO: CEBR5F.SA não é do Brasil.
# Analisando [262/304]: CGAS3F.SA...
#   -> DESCARTADO: CGAS3F.SA não é do Brasil.
# Analisando [263/304]: BSLI3F.SA...
#   -> DESCARTADO: BSLI3F.SA não é do Brasil.
# Analisando [264/304]: BPAC5F.SA...
#   -> DESCARTADO: BPAC5F.SA não é do Brasil.
# Analisando [265/304]: CPLE5F.SA...
#   -> DESCARTADO: CPLE5F.SA não é do Brasil.
# Analisando [266/304]: LAND3F.SA...
#   -> DESCARTADO: LAND3F.SA não é do Brasil.
# Analisando [267/304]: TELB4F.SA...
#   -> DESCARTADO: TELB4F.SA não é do Brasil.
# Analisando [268/304]: BMIN4.SA...
#   -> ✅ INCLUÍDO: BMIN4.SA
# Analisando [269/304]: NEXP3.SA...
#   -> ✅ INCLUÍDO: NEXP3.SA
# Analisando [270/304]: CGAS3.SA...
#   -> ✅ INCLUÍDO: CGAS3.SA
# Analisando [271/304]: AFLT3.SA...
#   -> ✅ INCLUÍDO: AFLT3.SA
# Analisando [272/304]: BGIP4F.SA...
#   -> DESCARTADO: BGIP4F.SA não é do Brasil.
# Analisando [273/304]: BMEB3F.SA...
#   -> DESCARTADO: BMEB3F.SA não é do Brasil.
# Analisando [274/304]: AVLL3F.SA...
#   -> DESCARTADO: AVLL3F.SA não é do Brasil.
# Analisando [275/304]: EQMA3BF.SA...
#   -> DESCARTADO: EQMA3BF.SA não é do Brasil.
# Analisando [276/304]: RDNI3F.SA...
#   -> DESCARTADO: RDNI3F.SA não é do Brasil.
# Analisando [277/304]: CLSC3F.SA...
#   -> DESCARTADO: CLSC3F.SA não é do Brasil.
# Analisando [278/304]: BSLI4F.SA...
#   -> DESCARTADO: BSLI4F.SA não é do Brasil.
# Analisando [279/304]: GEPA4F.SA...
#   -> DESCARTADO: GEPA4F.SA não é do Brasil.
# Analisando [280/304]: CEEB3F.SA...
#   -> DESCARTADO: CEEB3F.SA não é do Brasil.
# Analisando [281/304]: BMIN3F.SA...
#   -> DESCARTADO: BMIN3F.SA não é do Brasil.
# Analisando [282/304]: EKTR4F.SA...
#   -> DESCARTADO: EKTR4F.SA não é do Brasil.
# Analisando [283/304]: GEPA3F.SA...
#   -> DESCARTADO: GEPA3F.SA não é do Brasil.
# Analisando [284/304]: NEXP3F.SA...
#   -> DESCARTADO: NEXP3F.SA não é do Brasil.
# Analisando [285/304]: BRSR5F.SA...
#   -> DESCARTADO: BRSR5F.SA não é do Brasil.
# Analisando [286/304]: EGYR11.SA...
#   -> ✅ INCLUÍDO: EGYR11.SA
# Analisando [287/304]: PPLA11.SA...
#   -> ✅ INCLUÍDO: PPLA11.SA
# Analisando [288/304]: HBTS5F.SA...
#   -> DESCARTADO: HBTS5F.SA não é do Brasil.
# Analisando [289/304]: AFLT3F.SA...
#   -> DESCARTADO: AFLT3F.SA não é do Brasil.
# Analisando [290/304]: TELB3F.SA...
#   -> DESCARTADO: TELB3F.SA não é do Brasil.
# Analisando [291/304]: CBEE3F.SA...
#   -> DESCARTADO: CBEE3F.SA não é do Brasil.
# Analisando [292/304]: BMIN4F.SA...
#   -> DESCARTADO: BMIN4F.SA não é do Brasil.
# Analisando [293/304]: CEEB5F.SA...
#   -> DESCARTADO: CEEB5F.SA não é do Brasil.
# Analisando [294/304]: EMAE4F.SA...
#   -> DESCARTADO: EMAE4F.SA não é do Brasil.
# Analisando [295/304]: ELET5F.SA...
#   -> DESCARTADO: ELET5F.SA não é do Brasil.
# Analisando [296/304]: COCE3F.SA...
#   -> DESCARTADO: COCE3F.SA não é do Brasil.
# Analisando [297/304]: MERC4F.SA...
#   -> DESCARTADO: MERC4F.SA não é do Brasil.
# Analisando [298/304]: BGIP3F.SA...
#   -> DESCARTADO: BGIP3F.SA não é do Brasil.
# Analisando [299/304]: IGTI4F.SA...
#   -> DESCARTADO: IGTI4F.SA não é do Brasil.
# Analisando [300/304]: PEAB3F.SA...
#   -> DESCARTADO: PEAB3F.SA não é do Brasil.
# Analisando [301/304]: GPAR3F.SA...
#   -> DESCARTADO: GPAR3F.SA não é do Brasil.
# Analisando [302/304]: ENMT3F.SA...
#   -> DESCARTADO: ENMT3F.SA não é do Brasil.
# Analisando [303/304]: EQPA7F.SA...
#  EMAE4.SA                           Empresa Metropolitana de Águas e Energia S.A.           Utilities                 Utilities - Diversified Brazil stock   R$ 0.68 Bi  https://icons.brapi.dev/icons/EMAE4.svg
# RNEW11.SA                                                     Renova Energia S.A.           Utilities                   Utilities - Renewable Brazil  fund   R$ 0.46 Bi https://icons.brapi.dev/icons/RNEW11.svg
#  AFLT3.SA                           Afluente Transmissão de Energia Elétrica S.A.           Utilities          Utilities - Regulated Electric Brazil stock   R$ 0.44 Bi  https://icons.brapi.dev/icons/BRAPI.svg
#  RNEW4.SA                                                     Renova Energia S.A.           Utilities                   Utilities - Renewable Brazil stock   R$ 0.34 Bi  https://icons.brapi.dev/icons/RNEW4.svg
#  RNEW3.SA                                                     Renova Energia S.A.           Utilities                   Utilities - Renewable Brazil stock   R$ 0.31 Bi  https://icons.brapi.dev/icons/RNEW3.svg
#
# ✅ Resultados salvos com sucesso no caminho: E:\finance-manager\data\scanner_acoes_e_fundos_filtrado.csv

# %%
# import pandas as pd

# df_dados2 = pd.read_excel(r'E:\Github\finance-manager\datasets\scanner_acoes_filtrado.xlsx')

# print(df_dados2)

# %% [markdown]
# # Transformação

# %%
import yfinance as yf
import pandas as pd
import os
from datetime import datetime, date
from dateutil.relativedelta import relativedelta
import warnings

# --- PASSO 1: LER A LISTA DE ATIVOS DO SEU ARQUIVO ---
arquivo_input = r"E:\finance-manager\data\scanner_acoes_e_fundos_filtrado.csv"

try:
    print(f"Lendo a lista de ativos do arquivo '{arquivo_input}'...")
    df_input = pd.read_csv(arquivo_input)
    colunas_esperadas = ['Ticker', 'Empresa', 'Setor (brapi)', 'País', 'Tipo', 'Market Cap', 'Logo']
    colunas_faltantes = [col for col in colunas_esperadas if col not in df_input.columns]
    if colunas_faltantes:
        print(f"\n⚠️ AVISO: Colunas Faltantes no Arquivo de Entrada: {colunas_faltantes}\n")

    tickers_para_analisar = df_input['Ticker'].tolist()
    print(f"✅ Sucesso. {len(tickers_para_analisar)} ativos serão analisados.")

except FileNotFoundError:
    print(f"❌ ERRO: O arquivo '{arquivo_input}' não foi encontrado.")
    exit()
except Exception as e:
    print(f"❌ ERRO: Ocorreu um problema ao ler o arquivo: {e}")
    exit()

# --- PASSO 2: BUSCAR OS DADOS DETALHADOS COM LÓGICA CONDICIONAL ---
dados_detalhados_acoes = {}
print("\nIniciando a coleta de dados detalhados com análise especialista...")

for ticker in tickers_para_analisar:
    try:
        print(f"Analisando: {ticker}...")
        stock = yf.Ticker(ticker)
        info = stock.info
        history = stock.history(period="2y")  # Dados históricos para crescimento

        if len(history) < 2:
            warnings.warn(f"⚠️ AVISO: Dados históricos insuficientes para {ticker}. Crescimento Preço será 0.")
        
        info_original = df_input[df_input['Ticker'] == ticker].iloc[0]
        setor_principal = info_original.get('Setor (brapi)', 'N/A')

        # --- DADOS COMUNS A TODOS OS SETORES ---
        dy_pela_taxa = "N/A"
        try:
            taxa_anual_div = info.get("trailingAnnualDividendRate")
            preco_atual = info.get("currentPrice")
            if taxa_anual_div is not None and preco_atual is not None and preco_atual > 0:
                dy_pela_taxa = (taxa_anual_div / preco_atual) * 100
        except Exception as e:
            warnings.warn(f"⚠️ AVISO: Erro ao calcular DY para {ticker}: {e}")
            dy_pela_taxa = "N/A"

        # Crescimento estimado (Lynch) baseado em preço histórico
        growth_price = (history['Close'].iloc[-1] / history['Close'].iloc[0] - 1) * 100 if len(history) > 1 else 0

        dados_base = {
            "Empresa": info_original.get('Empresa', 'N/A'),
            "Setor (brapi)": setor_principal, 
            "Tipo": info_original.get('Tipo', 'N/A'),
            "Market Cap (R$)": info_original.get('Market Cap', 'N/A'),
            "Logo": info_original.get('Logo', 'N/A'),
            "Preço Atual": info.get("currentPrice", 0),
            "P/L": info.get("trailingPE", "N/A"),
            "P/VP": info.get("priceToBook", "N/A"),
            "DY (Taxa 12m, %)": dy_pela_taxa,
            "DY 5 Anos Média (%)": info.get("fiveYearAvgDividendYield", "N/A"),
            "Último Dividendo (R$)": info.get("lastDividendValue", "N/A"),
            "Data Últ. Div.": pd.to_datetime(info.get("lastDividendDate"), unit='s') if info.get("lastDividendDate") else "N/A",
            "Data Ex-Div.": pd.to_datetime(info.get("exDividendDate"), unit='s') if info.get("exDividendDate") else "N/A",
            "Payout Ratio (%)": info.get("payoutRatio", 0) * 100,
            "Crescimento Preço (%)": growth_price,
        }
        
        # <<< LÓGICA CONDICIONAL "ESPECIALISTA" REINTRODUZIDA AQUI >>>
        if setor_principal == 'Finance':
            print("  -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.")
            dados_especificos = {
                "ROE (%)": info.get("returnOnEquity", 0) * 100,
                "Dívida Total": "N/A",
                "Dívida/EBITDA": "N/A",
            }
        else:
            print("  -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.")
            total_debt = info.get('totalDebt', None)
            ebitda = info.get('ebitda', None)
            divida_ebitda = "N/A"
            if total_debt is not None and ebitda is not None and ebitda != 0:
                divida_ebitda = total_debt / ebitda
            else:
                warnings.warn(f"⚠️ AVISO: Dados insuficientes para Dívida/EBITDA em {ticker}.")

            dados_especificos = {
                "ROE (%)": info.get("returnOnEquity", 0) * 100,
                "Dívida Total": total_debt,
                "Dívida/EBITDA": divida_ebitda,
            }
        
        # Unindo os dicionários de dados
        dados_detalhados_acoes[ticker] = {**dados_base, **dados_especificos}
        print(f"✅ Dados de {ticker} obtidos com sucesso.")

    except Exception as e:
        print(f"❌ ERRO: Não foi possível obter dados para {ticker}. Erro: {e}")
        warnings.warn(f"⚠️ AVISO: Falha na coleta de dados para {ticker}. Verifique a conexão ou disponibilidade no yfinance.")

# --- PASSO 3: ORGANIZAR E SALVAR ---
if dados_detalhados_acoes:
    df_resultado_detalhado = pd.DataFrame.from_dict(dados_detalhados_acoes, orient="index")
    
    # Formatação da 'Dívida Total'
    if "Dívida Total" in df_resultado_detalhado.columns:
        df_resultado_detalhado["Dívida Total"] = df_resultado_detalhado["Dívida Total"].apply(
            lambda x: f"R$ {x/1_000_000_000:.2f} Bi" if pd.notna(x) and isinstance(x, (int, float)) and x != 0 else "N/A"
        )
    
    colunas_numericas = ["Preço Atual", "P/L", "P/VP"]
    for col in colunas_numericas:
        if col in df_resultado_detalhado.columns:
            df_resultado_detalhado[col] = df_resultado_detalhado[col].apply(
                lambda x: f"{x:.2f}" if isinstance(x, (int, float)) else x
            )
            
    colunas_percentual = ["DY (Taxa 12m, %)", "DY 5 Anos Média (%)", "ROE (%)", "Payout Ratio (%)", "Crescimento Preço (%)"]
    for col in colunas_percentual:
        if col in df_resultado_detalhado.columns:
            df_resultado_detalhado[col] = df_resultado_detalhado[col].apply(
                lambda x: f"{x:.2f}%" if isinstance(x, (int, float)) else x
            )

    colunas_moeda = ["Último Dividendo (R$)"]
    for col in colunas_moeda:
         if col in df_resultado_detalhado.columns:
            df_resultado_detalhado[col] = df_resultado_detalhado[col].apply(
                lambda x: f"R$ {x:.2f}" if isinstance(x, (int, float)) else x
            )
    
    colunas_data = ["Data Últ. Div.", "Data Ex-Div."]
    for col in colunas_data:
        if col in df_resultado_detalhado.columns:
            df_resultado_detalhado[col] = pd.to_datetime(df_resultado_detalhado[col], errors='coerce').dt.strftime('%d-%m-%Y')

    print("\n--- Tabela Comparativa de Indicadores (Análise Especialista) ---")
    print(df_resultado_detalhado.to_string())

    try:
        output_folder = r"E:\finance-manager\data"
        output_filename = "relatorio_analise_b3.csv"
        full_path = os.path.join(output_folder, output_filename)
        os.makedirs(output_folder, exist_ok=True)
        df_resultado_detalhado.to_csv(full_path)
        print(f"\n✅ Relatório detalhado salvo com sucesso no caminho: {full_path}")
    except Exception as e:
        print(f"❌ Erro ao salvar o novo arquivo CSV: {e}")
        warnings.warn(f"⚠️ AVISO: Falha ao salvar o arquivo. Verifique permissões ou espaço em disco.")
else:
    print("\nNenhum dado foi coletado.")
    warnings.warn("⚠️ AVISO: Nenhum dado foi coletado. Verifique os tickers ou a conexão com o yfinance.")
# Out:
# Lendo a lista de ativos do arquivo 'E:\finance-manager\data\scanner_acoes_e_fundos_filtrado.csv'...
# ✅ Sucesso. 145 ativos serão analisados.
#
# Iniciando a coleta de dados detalhados com análise especialista...
# Analisando: VIVT3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de VIVT3.SA obtidos com sucesso.
# Analisando: TIMS3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de TIMS3.SA obtidos com sucesso.
# Analisando: FIQE3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de FIQE3.SA obtidos com sucesso.
# Analisando: BRST3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de BRST3.SA obtidos com sucesso.
# Analisando: DESK3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de DESK3.SA obtidos com sucesso.
# Analisando: TELB4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de TELB4.SA obtidos com sucesso.
# Analisando: TELB3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de TELB3.SA obtidos com sucesso.
# Analisando: OIBR3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de OIBR3.SA obtidos com sucesso.
# Analisando: OIBR4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de OIBR4.SA obtidos com sucesso.
# Analisando: ITUB3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de ITUB3.SA obtidos com sucesso.
# Analisando: ITUB4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de ITUB4.SA obtidos com sucesso.
# Analisando: BPAC3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BPAC3.SA obtidos com sucesso.
# Analisando: BPAC5.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BPAC5.SA obtidos com sucesso.
# Analisando: BBDC3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BBDC3.SA obtidos com sucesso.
# Analisando: BBDC4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BBDC4.SA obtidos com sucesso.
# Analisando: BPAC11.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BPAC11.SA obtidos com sucesso.
# Analisando: SANB11.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de SANB11.SA obtidos com sucesso.
# Analisando: BBAS3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BBAS3.SA obtidos com sucesso.
# Analisando: ITSA4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de ITSA4.SA obtidos com sucesso.
# Analisando: ITSA3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de ITSA3.SA obtidos com sucesso.
# Analisando: SANB3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de SANB3.SA obtidos com sucesso.
# Analisando: SANB4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de SANB4.SA obtidos com sucesso.
# Analisando: B3SA3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de B3SA3.SA obtidos com sucesso.
# Analisando: BBSE3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BBSE3.SA obtidos com sucesso.
# Analisando: CXSE3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de CXSE3.SA obtidos com sucesso.
# Analisando: RENT3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de RENT3.SA obtidos com sucesso.
# Analisando: PSSA3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de PSSA3.SA obtidos com sucesso.
# Analisando: MULT3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de MULT3.SA obtidos com sucesso.
# Analisando: ALOS3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de ALOS3.SA obtidos com sucesso.
# Analisando: BPAN4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BPAN4.SA obtidos com sucesso.
# Analisando: CYRE3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de CYRE3.SA obtidos com sucesso.
# Analisando: BNBR3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BNBR3.SA obtidos com sucesso.
# Analisando: CURY3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de CURY3.SA obtidos com sucesso.
# Analisando: DIRR3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de DIRR3.SA obtidos com sucesso.
# Analisando: IGTI3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de IGTI3.SA obtidos com sucesso.
# Analisando: BRAP3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BRAP3.SA obtidos com sucesso.
# Analisando: BRAP4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BRAP4.SA obtidos com sucesso.
# Analisando: ABCB4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de ABCB4.SA obtidos com sucesso.
# Analisando: BRSR6.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BRSR6.SA obtidos com sucesso.
# Analisando: BRSR3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BRSR3.SA obtidos com sucesso.
# Analisando: VAMO3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de VAMO3.SA obtidos com sucesso.
# Analisando: BAZA3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BAZA3.SA obtidos com sucesso.
# Analisando: BSLI3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BSLI3.SA obtidos com sucesso.
# Analisando: BSLI4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BSLI4.SA obtidos com sucesso.
# Analisando: BMEB4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BMEB4.SA obtidos com sucesso.
# Analisando: IRBR3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de IRBR3.SA obtidos com sucesso.
# Analisando: JHSF3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de JHSF3.SA obtidos com sucesso.
# Analisando: PLPL3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de PLPL3.SA obtidos com sucesso.
# Analisando: EZTC3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de EZTC3.SA obtidos com sucesso.
# Analisando: TEND3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de TEND3.SA obtidos com sucesso.
# Analisando: BEES4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BEES4.SA obtidos com sucesso.
# Analisando: BEES3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BEES3.SA obtidos com sucesso.
# Analisando: MILS3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de MILS3.SA obtidos com sucesso.
# Analisando: LAVV3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de LAVV3.SA obtidos com sucesso.
# Analisando: MOVI3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de MOVI3.SA obtidos com sucesso.
# Analisando: BMGB4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BMGB4.SA obtidos com sucesso.
# Analisando: AGRO3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de AGRO3.SA obtidos com sucesso.
# Analisando: MDNE3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de MDNE3.SA obtidos com sucesso.
# Analisando: EVEN3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de EVEN3.SA obtidos com sucesso.
# Analisando: PINE3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de PINE3.SA obtidos com sucesso.
# Analisando: PINE4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de PINE4.SA obtidos com sucesso.
# Analisando: WIZC3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de WIZC3.SA obtidos com sucesso.
# Analisando: ARML3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de ARML3.SA obtidos com sucesso.
# Analisando: SCAR3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de SCAR3.SA obtidos com sucesso.
# Analisando: SYNE3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de SYNE3.SA obtidos com sucesso.
# Analisando: LAND3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de LAND3.SA obtidos com sucesso.
# Analisando: PEAB4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de PEAB4.SA obtidos com sucesso.
# Analisando: BGIP4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BGIP4.SA obtidos com sucesso.
# Analisando: MTRE3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de MTRE3.SA obtidos com sucesso.
# Analisando: RPAD3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de RPAD3.SA obtidos com sucesso.
# Analisando: SNCI11.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de SNCI11.SA obtidos com sucesso.
# Analisando: HBRE3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de HBRE3.SA obtidos com sucesso.
# Analisando: AVLL3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de AVLL3.SA obtidos com sucesso.
# Analisando: GFSA3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de GFSA3.SA obtidos com sucesso.
# Analisando: IRIM11.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de IRIM11.SA obtidos com sucesso.
# Analisando: TCSA3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de TCSA3.SA obtidos com sucesso.
# Analisando: RDNI3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de RDNI3.SA obtidos com sucesso.
# Analisando: BMIN4.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BMIN4.SA obtidos com sucesso.
# Analisando: PPLA11.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de PPLA11.SA obtidos com sucesso.
# Analisando: NEXP3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de NEXP3.SA obtidos com sucesso.
# Analisando: PDGR3.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de PDGR3.SA obtidos com sucesso.
# Analisando: RENV11.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de RENV11.SA obtidos com sucesso.
# Analisando: EGYR11.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de EGYR11.SA obtidos com sucesso.
# Analisando: IGTI11.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de IGTI11.SA obtidos com sucesso.
# Analisando: BRBI11.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de BRBI11.SA obtidos com sucesso.
# Analisando: RBIF11.SA...
#   -> Setor 'Finance' detectado. Métricas de dívida industrial não aplicáveis.
# ✅ Dados de RBIF11.SA obtidos com sucesso.
# Analisando: TAEE11.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de TAEE11.SA obtidos com sucesso.
# Analisando: TAEE3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de TAEE3.SA obtidos com sucesso.
# Analisando: TAEE4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de TAEE4.SA obtidos com sucesso.
# Analisando: LOGG3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de LOGG3.SA obtidos com sucesso.
# Analisando: PRNR3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de PRNR3.SA obtidos com sucesso.
# Analisando: MELK3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de MELK3.SA obtidos com sucesso.
# Analisando: AZEV3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de AZEV3.SA obtidos com sucesso.
# Analisando: AZEV4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de AZEV4.SA obtidos com sucesso.
# Analisando: AZTE3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de AZTE3.SA obtidos com sucesso.
# Analisando: INEP3.SA...
# C:\Users\Atlas Core\AppData\Local\Temp\ipykernel_9292\1911416789.py:94: UserWarning: ⚠️ AVISO: Dados insuficientes para Dívida/EBITDA em AZTE3.SA.
#   warnings.warn(f"⚠️ AVISO: Dados insuficientes para Dívida/EBITDA em {ticker}.")
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de INEP3.SA obtidos com sucesso.
# Analisando: INEP4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de INEP4.SA obtidos com sucesso.
# Analisando: OSXB3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de OSXB3.SA obtidos com sucesso.
# Analisando: ELET3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de ELET3.SA obtidos com sucesso.
# Analisando: ELET6.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de ELET6.SA obtidos com sucesso.
# Analisando: SBSP3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de SBSP3.SA obtidos com sucesso.
# Analisando: CPFE3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de CPFE3.SA obtidos com sucesso.
# Analisando: EQTL3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de EQTL3.SA obtidos com sucesso.
# Analisando: EGIE3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de EGIE3.SA obtidos com sucesso.
# Analisando: CPLE3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de CPLE3.SA obtidos com sucesso.
# Analisando: CPLE6.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de CPLE6.SA obtidos com sucesso.
# Analisando: CMIG4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de CMIG4.SA obtidos com sucesso.
# Analisando: CMIG3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de CMIG3.SA obtidos com sucesso.
# Analisando: NEOE3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de NEOE3.SA obtidos com sucesso.
# Analisando: ENEV3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de ENEV3.SA obtidos com sucesso.
# Analisando: ENGI4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de ENGI4.SA obtidos com sucesso.
# Analisando: ENGI3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de ENGI3.SA obtidos com sucesso.
# Analisando: ENGI11.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de ENGI11.SA obtidos com sucesso.
# Analisando: ISAE4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de ISAE4.SA obtidos com sucesso.
# Analisando: ENMT3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de ENMT3.SA obtidos com sucesso.
# Analisando: ISAE3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de ISAE3.SA obtidos com sucesso.
# Analisando: CGAS3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de CGAS3.SA obtidos com sucesso.
# Analisando: CGAS5.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de CGAS5.SA obtidos com sucesso.
# Analisando: ALUP11.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de ALUP11.SA obtidos com sucesso.
# Analisando: REDE3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de REDE3.SA obtidos com sucesso.
# Analisando: CSAN3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de CSAN3.SA obtidos com sucesso.
# Analisando: EQPA3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de EQPA3.SA obtidos com sucesso.
# Analisando: SAPR3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de SAPR3.SA obtidos com sucesso.
# Analisando: SAPR11.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de SAPR11.SA obtidos com sucesso.
# Analisando: SAPR4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de SAPR4.SA obtidos com sucesso.
# Analisando: AURE3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de AURE3.SA obtidos com sucesso.
# Analisando: CSMG3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de CSMG3.SA obtidos com sucesso.
# Analisando: ALUP4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de ALUP4.SA obtidos com sucesso.
# Analisando: ALUP3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de ALUP3.SA obtidos com sucesso.
# Analisando: EKTR4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de EKTR4.SA obtidos com sucesso.
# Analisando: SRNA3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de SRNA3.SA obtidos com sucesso.
# Analisando: ORVR3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de ORVR3.SA obtidos com sucesso.
# Analisando: EQMA3B.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de EQMA3B.SA obtidos com sucesso.
# Analisando: CLSC4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de CLSC4.SA obtidos com sucesso.
# Analisando: GEPA4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de GEPA4.SA obtidos com sucesso.
# Analisando: LIGT3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de LIGT3.SA obtidos com sucesso.
# Analisando: COCE5.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de COCE5.SA obtidos com sucesso.
# Analisando: CEBR3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de CEBR3.SA obtidos com sucesso.
# Analisando: CEBR5.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de CEBR5.SA obtidos com sucesso.
# Analisando: CEBR6.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de CEBR6.SA obtidos com sucesso.
# Analisando: EMAE4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de EMAE4.SA obtidos com sucesso.
# Analisando: RNEW11.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de RNEW11.SA obtidos com sucesso.
# Analisando: AFLT3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de AFLT3.SA obtidos com sucesso.
# Analisando: RNEW4.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de RNEW4.SA obtidos com sucesso.
# Analisando: RNEW3.SA...
#   -> Setor Industrial/Serviços detectado. Coletando métricas de dívida.
# ✅ Dados de RNEW3.SA obtidos com sucesso.
#
# --- Tabela Comparativa de Indicadores (Análise Especialista) ---
#                                                                            Empresa        Setor (brapi)   Tipo Market Cap (R$)                                      Logo Preço Atual     P/L    P/VP DY (Taxa 12m, %) DY 5 Anos Média (%) Último Dividendo (R$) Data Últ. Div. Data Ex-Div. Payout Ratio (%) Crescimento Preço (%)  ROE (%) Dívida Total Dívida/EBITDA
# LIGT3.SA                                                                Light S.A.            Utilities  stock      R$ 3.26 Bi   https://icons.brapi.dev/icons/LIGT3.svg        6.46    0.99    0.43            0.00%               7.04%                   N/A            NaN   28-04-2022            0.00%               -32.00%   57.77%  R$ 10.28 Bi      3.651145
# COCE5.SA                                    Companhia Energética do Ceará - COELCE            Utilities  stock      R$ 2.14 Bi   https://icons.brapi.dev/icons/COCE5.svg       26.88   10.80    0.40            0.00%               3.31%               R$ 1.50     01-11-2021   30-04-2025           39.66%               -53.25%    7.83%   R$ 5.97 Bi      3.407192
# CEBR3.SA                                    Companhia Energética de Brasília - CEB            Utilities  stock      R$ 1.47 Bi   https://icons.brapi.dev/icons/CEBR3.svg       19.32    8.05    1.25            5.95%                 N/A              R$ 11.58     15-10-2021   02-05-2025           64.97%                45.26%   17.46%   R$ 0.00 Bi       0.02036
# CEBR5.SA                                    Companhia Energética de Brasília - CEB            Utilities  stock      R$ 1.43 Bi   https://icons.brapi.dev/icons/CEBR5.svg       19.55    8.15    1.26            5.88%                 N/A              R$ 11.58     15-10-2021   02-05-2025           64.97%                39.74%   17.46%   R$ 0.00 Bi       0.02036
# CEBR6.SA                                    Companhia Energética de Brasília - CEB            Utilities  stock      R$ 1.42 Bi   https://icons.brapi.dev/icons/CEBR6.svg       21.05    8.77    1.36            5.46%                 N/A              R$ 12.74     15-10-2021   02-05-2025           71.47%                48.87%   17.46%   R$ 0.00 Bi       0.02036
# EMAE4.SA                             Empresa Metropolitana de Águas e Energia S.A.            Utilities  stock      R$ 0.68 Bi   https://icons.brapi.dev/icons/EMAE4.svg       30.49   16.48    0.91            2.75%               5.50%               R$ 0.79     09-04-2024   24-09-2024           88.24%               -50.78%    5.69%          N/A           0.0
# RNEW11.SA                                                      Renova Energia S.A.            Utilities   fund      R$ 0.46 Bi  https://icons.brapi.dev/icons/RNEW11.svg        2.60     N/A    0.14            0.00%                 N/A                   N/A            NaN   02-05-2016            0.00%               -41.98%  -13.83%   R$ 1.17 Bi     44.055493
# AFLT3.SA                             Afluente Transmissão de Energia Elétrica S.A.            Utilities  stock      R$ 0.44 Bi   https://icons.brapi.dev/icons/BRAPI.svg        7.01   14.60    1.72            3.05%               3.29%               R$ 0.19     06-12-2021   26-12-2024           44.59%               -24.54%   11.81%   R$ 0.03 Bi      0.733163
# RNEW4.SA                                                       Renova Energia S.A.            Utilities  stock      R$ 0.34 Bi   https://icons.brapi.dev/icons/RNEW4.svg        0.89     N/A    0.05            0.00%                 N/A               R$ 0.69     02-05-2016   02-05-2016            0.00%               -74.86%  -13.83%   R$ 1.17 Bi     44.055493
# RNEW3.SA                                                       Renova Energia S.A.            Utilities  stock      R$ 0.31 Bi   https://icons.brapi.dev/icons/RNEW3.svg        0.85     N/A    0.05            0.00%                 N/A                   N/A            NaN   02-05-2016            0.00%               -74.40%  -13.83%   R$ 1.17 Bi     44.055493
#
# ✅ Relatório detalhado salvo com sucesso no caminho: E:\finance-manager\data\relatorio_analise_b3.csv

# %%
# import pandas as pd

# df_dados = pd.read_excel(r'E:\Github\finance-manager\datasets\relatorio_completo_b3.xlsx')

# print(df_dados.head(2))
