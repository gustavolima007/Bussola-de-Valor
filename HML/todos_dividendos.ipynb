# %%
import os
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
from dotenv import load_dotenv
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Carrega variáveis do .env
load_dotenv()

# Caminho do arquivo CSV com os tickers
csv_path = os.getenv("FILTERED_COMPANIES_PATH")

# Lê o CSV e extrai os tickers
df = pd.read_csv(csv_path)
tickers = df['Ticker'].dropna().unique().tolist()

# Define o período de 7 anos
end_date = datetime.today()
start_date = end_date - timedelta(days=7*365)

todos_dividendos = []

for ticker in tickers:
    try:
        acao = yf.Ticker(ticker)
        dividendos = acao.dividends

        # Remove timezone do índice
        dividendos.index = dividendos.index.tz_localize(None)

        # Filtra dividendos dos últimos 7 anos
        dividendos = dividendos[dividendos.index >= start_date]

        if not dividendos.empty:
            df_div = dividendos.reset_index()
            df_div.columns = ['Data', 'Valor']
            df_div['Ticker'] = ticker.replace('.SA', '')
            todos_dividendos.append(df_div)

            print(f"✅ Dividendos coletados para {ticker}")
        else:
            print(f"⚠️ Sem dividendos recentes para {ticker}")
    except Exception as e:
        print(f"❌ Erro ao processar {ticker}: {e}")

# Junta tudo em um único DataFrame
df_final = pd.concat(todos_dividendos, ignore_index=True)

# Salva em um único CSV
df_final.to_csv("todos_dividendos.csv", index=False)

print("🏁 Finalizado! Dividendos salvos em todos_dividendos.csv")
# Out:
# ✅ Dividendos coletados para VIVT3.SA
# ✅ Dividendos coletados para TIMS3.SA
# ✅ Dividendos coletados para FIQE3.SA
# ✅ Dividendos coletados para BRST3.SA
# ✅ Dividendos coletados para DESK3.SA
# ⚠️ Sem dividendos recentes para TELB4.SA
# ⚠️ Sem dividendos recentes para TELB3.SA
# ⚠️ Sem dividendos recentes para OIBR3.SA
# ⚠️ Sem dividendos recentes para OIBR4.SA
# ✅ Dividendos coletados para ITUB3.SA
# ✅ Dividendos coletados para ITUB4.SA
# ✅ Dividendos coletados para BPAC3.SA
# ✅ Dividendos coletados para BPAC5.SA
# ✅ Dividendos coletados para BBDC3.SA
# ✅ Dividendos coletados para BBDC4.SA
# ✅ Dividendos coletados para BPAC11.SA
# ✅ Dividendos coletados para SANB11.SA
# ✅ Dividendos coletados para BBAS3.SA
# ✅ Dividendos coletados para ITSA4.SA
# ✅ Dividendos coletados para ITSA3.SA
# ✅ Dividendos coletados para SANB3.SA
# ✅ Dividendos coletados para SANB4.SA
# ✅ Dividendos coletados para B3SA3.SA
# ✅ Dividendos coletados para BBSE3.SA
# ✅ Dividendos coletados para CXSE3.SA
# ✅ Dividendos coletados para RENT3.SA
# ✅ Dividendos coletados para PSSA3.SA
# ✅ Dividendos coletados para MULT3.SA
# ✅ Dividendos coletados para ALOS3.SA
# ✅ Dividendos coletados para BPAN4.SA
# ✅ Dividendos coletados para CYRE3.SA
# ✅ Dividendos coletados para BNBR3.SA
# ✅ Dividendos coletados para MELK3.SA
# ⚠️ Sem dividendos recentes para AZEV3.SA
# ⚠️ Sem dividendos recentes para AZEV4.SA
# ⚠️ Sem dividendos recentes para AZTE3.SA
# ⚠️ Sem dividendos recentes para INEP3.SA
# ⚠️ Sem dividendos recentes para INEP4.SA
# ⚠️ Sem dividendos recentes para OSXB3.SA
# ✅ Dividendos coletados para ELET3.SA
# ✅ Dividendos coletados para ELET6.SA
# ✅ Dividendos coletados para SBSP3.SA
# ✅ Dividendos coletados para CPFE3.SA
# ✅ Dividendos coletados para EQTL3.SA
# ✅ Dividendos coletados para EGIE3.SA
# ✅ Dividendos coletados para CPLE3.SA
# ✅ Dividendos coletados para CPLE6.SA
# ✅ Dividendos coletados para CMIG4.SA
# ✅ Dividendos coletados para CMIG3.SA
# ✅ Dividendos coletados para NEOE3.SA
# ⚠️ Sem dividendos recentes para ENEV3.SA
# ✅ Dividendos coletados para ENGI4.SA
# ✅ Dividendos coletados para ENGI3.SA
# ✅ Dividendos coletados para ENGI11.SA
# ✅ Dividendos coletados para ISAE4.SA
# ✅ Dividendos coletados para ENMT3.SA
# ✅ Dividendos coletados para ISAE3.SA
# ✅ Dividendos coletados para CGAS3.SA
# ✅ Dividendos coletados para CGAS5.SA
# ✅ Dividendos coletados para ALUP11.SA
# ✅ Dividendos coletados para REDE3.SA
# ✅ Dividendos coletados para CSAN3.SA
# ✅ Dividendos coletados para EQPA3.SA
# ✅ Dividendos coletados para SAPR3.SA
# ✅ Dividendos coletados para SAPR11.SA
# ✅ Dividendos coletados para SAPR4.SA
# ✅ Dividendos coletados para AURE3.SA
# ✅ Dividendos coletados para CSMG3.SA
# ✅ Dividendos coletados para ALUP4.SA
# ✅ Dividendos coletados para ALUP3.SA
# ✅ Dividendos coletados para EKTR4.SA
# ⚠️ Sem dividendos recentes para SRNA3.SA
# ⚠️ Sem dividendos recentes para ORVR3.SA
# ✅ Dividendos coletados para EQMA3B.SA
# ✅ Dividendos coletados para CLSC4.SA
# ✅ Dividendos coletados para GEPA4.SA
# ✅ Dividendos coletados para LIGT3.SA
# ✅ Dividendos coletados para COCE5.SA
# ✅ Dividendos coletados para CEBR3.SA
# ✅ Dividendos coletados para CEBR5.SA
# ✅ Dividendos coletados para CEBR6.SA
# ✅ Dividendos coletados para EMAE4.SA
# ⚠️ Sem dividendos recentes para RNEW11.SA
# ✅ Dividendos coletados para AFLT3.SA
# ⚠️ Sem dividendos recentes para RNEW4.SA
# ⚠️ Sem dividendos recentes para RNEW3.SA
# 🏁 Finalizado! Dividendos salvos em todos_dividendos.csv

# %%
# Define o período de 7 anos
end_date = datetime.today()
start_date = end_date - timedelta(days=7*365)

# Lista para acumular todos os dividendos
todos_dividendos = []

# Loop para baixar dividendos de cada empresa
for ticker in tickers:
    try:
        acao = yf.Ticker(ticker)
        dividendos = acao.dividends

        # Filtra dividendos dos últimos 7 anos
        dividendos = dividendos[dividendos.index >= start_date]

        if not dividendos.empty:
            df_div = dividendos.reset_index()
            df_div.columns = ['Data', 'Valor']
            df_div['Ticker'] = ticker.replace('.SA', '')
            todos_dividendos.append(df_div)

            print(f"✅ Dividendos coletados para {ticker}")
        else:
            print(f"⚠️ Sem dividendos recentes para {ticker}")
    except Exception as e:
        print(f"❌ Erro ao processar {ticker}: {e}")
# Out:
# ❌ Erro ao processar VIVT3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar TIMS3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar FIQE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BRST3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar DESK3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar TELB4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar TELB3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar OIBR3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar OIBR4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ITUB3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ITUB4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BPAC3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BPAC5.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BBDC3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BBDC4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BPAC11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar SANB11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BBAS3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ITSA4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ITSA3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar SANB3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar SANB4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar B3SA3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BBSE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CXSE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar RENT3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar PSSA3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar MULT3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ALOS3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BPAN4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CYRE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BNBR3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CURY3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar DIRR3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar IGTI3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BRAP3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BRAP4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ABCB4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BRSR6.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BRSR3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar VAMO3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BAZA3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BSLI3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BSLI4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BMEB4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar IRBR3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar JHSF3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar PLPL3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar EZTC3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar TEND3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BEES4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BEES3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar MILS3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar LAVV3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar MOVI3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BMGB4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar AGRO3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar MDNE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar EVEN3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar PINE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar PINE4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar WIZC3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ARML3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar SCAR3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar SYNE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar LAND3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar PEAB4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BGIP4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar MTRE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar RPAD3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar SNCI11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar HBRE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar AVLL3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar GFSA3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar IRIM11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar TCSA3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar RDNI3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BMIN4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar PPLA11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar NEXP3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar PDGR3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar RENV11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar EGYR11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar IGTI11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar BRBI11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar RBIF11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar TAEE11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar TAEE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar TAEE4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar LOGG3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar PRNR3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar MELK3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar AZEV3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar AZEV4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar AZTE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar INEP3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar INEP4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar OSXB3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ELET3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ELET6.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar SBSP3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CPFE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar EQTL3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar EGIE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CPLE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CPLE6.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CMIG4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CMIG3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar NEOE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ENEV3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ENGI4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ENGI3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ENGI11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ISAE4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ENMT3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ISAE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CGAS3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CGAS5.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ALUP11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar REDE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CSAN3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar EQPA3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar SAPR3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar SAPR11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar SAPR4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar AURE3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CSMG3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ALUP4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ALUP3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar EKTR4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar SRNA3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar ORVR3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar EQMA3B.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CLSC4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar GEPA4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar LIGT3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar COCE5.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CEBR3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CEBR5.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar CEBR6.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar EMAE4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar RNEW11.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar AFLT3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar RNEW4.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
# ❌ Erro ao processar RNEW3.SA: Invalid comparison between dtype=datetime64[ns, America/Sao_Paulo] and datetime
